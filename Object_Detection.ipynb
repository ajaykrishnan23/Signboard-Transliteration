# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
file_id = '11fhGsVSgpafumqlu627WgWkOyl2nLnfd'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile("real_Image_dataset_Detection.tar.7z")

# %%
!7z x real_Image_dataset_Detection.tar.7z
# !tar -xvf /content/real_Image_dataset_Detection.tar
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
#   0M Scan
# ERROR: No more files
# real_Image_dataset_Detection.tar.7z
#
#
#
# System ERROR:
# Unknown error -2147024872
# real_Image_dataset_Detection/
# real_Image_dataset_Detection/readme.txt
# real_Image_dataset_Detection/Image/
# real_Image_dataset_Detection/Image/166.jpg
# real_Image_dataset_Detection/Image/21.jpg
# real_Image_dataset_Detection/Image/158. keralahouse_beefsaahil11.jpg
# real_Image_dataset_Detection/Image/239.jpg
# real_Image_dataset_Detection/Image/243.jpg
# real_Image_dataset_Detection/Image/289.jpg
# real_Image_dataset_Detection/Image/15.jpg
# real_Image_dataset_Detection/Image/283.jpg
# real_Image_dataset_Detection/Image/260.jpg
# real_Image_dataset_Detection/Image/285.jpg
# real_Image_dataset_Detection/Image/pathik-hotel-by-pass-choraha-indore-lodging-services-25wt7lv.jpg
# real_Image_dataset_Detection/Image/281.jpg
# real_Image_dataset_Detection/Image/210. 595291a7b4ce8a3750530dec_59267d9f9a22727e7f52d080_1498583463954.jpg
# real_Image_dataset_Detection/Image/341. 15092450197_3dc5a760d3_b.jpg
# real_Image_dataset_Detection/Image/314.jpg
# real_Image_dataset_Detection/Image/72.jpg
# real_Image_dataset_Detection/Image/117. main-qimg-4f7c25fd3f68c21a80f74e7344215eee.jpg
# real_Image_dataset_Detection/Image/152.jpg
# real_Image_dataset_Detection/Image/61.jpg
# real_Image_dataset_Detection/Image/263.jpg
# real_Image_dataset_Detection/Image/133.jpg
# real_Image_dataset_Detection/Image/184.jpg
# real_Image_dataset_Detection/Image/101.jpg
# real_Image_dataset_Detection/Image/109. khajuraho_station.jpg
# real_Image_dataset_Detection/Image/495. delhi-paranthe-wali-gali.jpg
# real_Image_dataset_Detection/Image/57.jpg
# real_Image_dataset_Detection/Image/234.jpg
# real_Image_dataset_Detection/Image/117.jpg
# real_Image_dataset_Detection/Image/38.jpg
# real_Image_dataset_Detection/Image/172.jpg
# real_Image_dataset_Detection/Image/256.jpg
# real_Image_dataset_Detection/Image/163. gali-paranthe-wali.jpg
# real_Image_dataset_Detection/Image/123. p1020013.jpg
# real_Image_dataset_Detection/Image/77.jpg
# real_Image_dataset_Detection/Image/111.jpg
# real_Image_dataset_Detection/Image/272.jpg
# real_Image_dataset_Detection/Image/240. temple-entrance-door-sign-english-and-hindi-languages-india_btx6gupxel_thumbnail-full01.jpg
# real_Image_dataset_Detection/Image/114.jpg
# real_Image_dataset_Detection/Image/120. 1478080632_rotates_shareiq_1213_1478078172.9512.jpg
# real_Image_dataset_Detection/Image/103. gurgaon_1460298928.jpg
# real_Image_dataset_Detection/Image/82.jpg
# real_Image_dataset_Detection/Image/161. nlu-450x338.jpg
# real_Image_dataset_Detection/Image/494. national-zoo-sign1_1413278727_540x540.jpg
# real_Image_dataset_Detection/Image/262.jpg
# real_Image_dataset_Detection/Image/315.jpg
# real_Image_dataset_Detection/Image/270. palika-bazaar.jpg
# real_Image_dataset_Detection/Image/165.jpg
# real_Image_dataset_Detection/Image/218.jpg
# real_Image_dataset_Detection/Image/17. ghaziabad-hindustan-febuary-ghaziabad-tuesday-welcome-febuary_050296d0-29b7-11e6-a271-92fd27615944.jpg
# real_Image_dataset_Detection/Image/282.jpg
# real_Image_dataset_Detection/Image/259.jpg
# real_Image_dataset_Detection/Image/226.jpg
# real_Image_dataset_Detection/Image/24. sharda-ukil-school-of-art-janpath-delhi-fashion-designing-institutes-0k9l9
152. 28177310_3e1bf624-1bdc-43fe-a8d5-52b75cd96970.jpg
# real_Image_dataset_Detection/Image/54.jpg
# real_Image_dataset_Detection/Image/117. name-stone.jpg
# real_Image_dataset_Detection/Image/22.jpg
# real_Image_dataset_Detection/Image/280.jpg
# real_Image_dataset_Detection/Image/249.jpg
# real_Image_dataset_Detection/Image/305.jpg
# real_Image_dataset_Detection/Image/197.jpg
# real_Image_dataset_Detection/Image/20.jpg
# real_Image_dataset_Detection/Image/104.jpg
# real_Image_dataset_Detection/Image/206.jpg
# real_Image_dataset_Detection/Image/211.jpg
# real_Image_dataset_Detection/Image/44.jpg
# real_Image_dataset_Detection/Annotation/
# real_Image_dataset_Detection/Annotation/104. aa-cover-5dfhaeu9i4at0o046ruj9vl6v7-20161221105554.medi.txt
# real_Image_dataset_Detection/Annotation/103.txt
# real_Image_dataset_Detection/Annotation/103. gurgaon_1460298928.txt
# real_Image_dataset_Detection/Annotation/102.txt
# real_Image_dataset_Detection/Annotation/102. indiatve36df4_patelnagar.txt
# real_Image_dataset_Detection/Annotation/102. img_20150110_183248.txt
# real_Image_dataset_Detection/Annotation/101.txt
# real_Image_dataset_Detection/Annotation/100.txt
# real_Image_dataset_Detection/Annotation/98.txt
# real_Image_dataset_Detection/Annotation/97.txt
# real_Image_dataset_Detection/Annotation/96.txt
# real_Image_dataset_Detection/Annotation/95.txt
# real_Image_dataset_Detection/Annotation/94.txt
# real_Image_dataset_Detection/Annotation/93.txt
# real_Image_dataset_Detection/Annotation/93. 1200px-rithaladelhi.txt
# real_Image_dataset_Detection/Annotation/92.txt
# real_Image_dataset_Detection/Annotation/91.txt
# real_Image_dataset_Detection/Annotation/90.txt
# real_Image_dataset_Detection/Annotation/89.txt
# real_Image_dataset_Detection/Annotation/88.txt
# real_Image_dataset_Detection/Annotation/87.txt
# real_Image_dataset_Detection/Annotation/86.txt
# real_Image_dataset_Detection/Annotation/85.txt
# real_Image_dataset_Detection/Annotation/84.txt
# real_Image_dataset_Detection/Annotation/83.txt
# real_Image_dataset_Detection/Annotation/82.txt
# real_Image_dataset_Detection/Annotation/81.txt
# real_Image_dataset_Detection/Annotation/80.txt
# real_Image_dataset_Detection/Annotation/79.txt
# real_Image_dataset_Detection/Annotation/78.txt
# real_Image_dataset_Detection/Annotation/77.txt
# real_Image_dataset_Detection/Annotation/76.txt
# real_Image_dataset_Detection/Annotation/76. pitampuradelhi.txt
# real_Image_dataset_Detection/Annotation/75.txt
# real_Image_dataset_Detection/Annotation/74.txt
# real_Image_dataset_Detection/Annotation/73.txt
# real_Image_dataset_Detection/Annotation/72.txt
# real_Image_dataset_Detection/Annotation/71.txt
# real_Image_dataset_Detection/Annotation/70.txt
# real_Image_dataset_Detection/Annotation/68.txt
# real_Image_dataset_Detection/Annotation/67.txt
# real_Image_dataset_Detection/Annotation/65.txt
# real_Image_dataset_Detection/Annotation/65. laxmi_nagar_metro_st._sign_board.txt
# real_Image_dataset_Detection/Annotation/64.txt
# real_Image_dataset_Detection/Annotation/63.txt
# real_Image_dataset_Detection/Annotation/62.txt
# real_Image_dataset_Detection/Annotation/62. jantar-mantar-delhi-206694.txt
# real_Image_dataset_Detection/Annotation/61.txt
# real_Image_dataset_Detection/Annotation/61. delhi-highcourt_1504878068.txt
# real_Image_dataset_Detection/Annotation/60.txt
# real_Image_dataset_Detection/Annotation/59.txt
# real_Image_dataset_Detection/Annotation/58.txt
# real_Image_dataset_Detection/Annotation/57.txt
# real_Image_dataset_Detection/Annotation/56.txt
# real_Image_dataset_Detection/Annotation/55.txt
# real_Image_dataset_Detection/Annotation/54.txt
# real_Image_dataset_Detection/Annotation/53.txt
# real_Image_dataset_Detection/Annotation/52.txt
# real_Image_dataset_Detection/Annotation/51.txt
# real_Image_dataset_Detection/Annotation/50.txt
# real_Image_dataset_Detection/Annotation/48.txt
# real_Image_dataset_Detection/Annotation/47.txt
# real_Image_dataset_Detection/Annotation/46. videoblocks-india-tourism-delhi-sign-hindi-and-english-nighttime-new-delhi-india_rx3i43x6g_thumbnail-full01.txt
# real_Image_dataset_Detection/Annotation/46.txt
# real_Image_dataset_Detection/Annotation/45.txt
# real_Image_dataset_Detection/Annotation/45. gurgaon_1460298928.txt
# real_Image_dataset_Detection/Annotation/44.txt
# real_Image_dataset_Detection/Annotation/43.txt
# real_Image_dataset_Detection/Annotation/43. palika-bazar.txt
# real_Image_dataset_Detection/Annotation/42.txt
# real_Image_dataset_Detection/Annotation/40.txt
# real_Image_dataset_Detection/Annotation/39.txt
# real_Image_dataset_Detection/Annotation/38.txt
# real_Image_dataset_Detection/Annotation/37.txt
# real_Image_dataset_Detection/Annotation/36.txt
# real_Image_dataset_Detection/Annotation/34.txt
# real_Image_dataset_Detection/Annotation/33.txt
# real_Image_dataset_Detection/Annotation/32.txt
# real_Image_dataset_Detection/Annotation/31.txt
# real_Image_dataset_Detection/Annotation/30.txt
# real_Image_dataset_Detection/Annotation/29.txt
# real_Image_dataset_Detection/Annotation/28.txt
# real_Image_dataset_Detection/Annotation/27.txt
# real_Image_dataset_Detection/Annotation/26.txt
# real_Image_dataset_Detection/Annotation/25.txt
# real_Image_dataset_Detection/Annotation/24.txt
# real_Image_dataset_Detection/Annotation/24. sharda-ukil-school-of-art-janpath-delhi-fashion-designing-institutes-0k9l9.txt
# real_Image_dataset_Detection/Annotation/23.txt
# real_Image_dataset_Detection/Annotation/22.txt
# real_Image_dataset_Detection/Annotation/21.txt
# real_Image_dataset_Detection/Annotation/20. videoblocks-road-sign-leading-to-main-bazar-hindi-and-english-new-delhi-india_shkd7v7ax_thumbnail-full01.txt
# real_Image_dataset_Detection/Annotation/20.txt
# real_Image_dataset_Detection/Annotation/19.txt
# real_Image_dataset_Detection/Annotation/18.txt
# real_Image_dataset_Detection/Annotation/18. janpath-market.txt
# real_Image_dataset_Detection/Annotation/17.txt
# real_Image_dataset_Detection/Annotation/17. ghaziabad-hindustan-febuary-ghaziabad-tuesday-welcome-febuary_050296d0-29b7-11e6-a271-92fd27615944.txt
# real_Image_dataset_Detection/Annotation/16.txt
# real_Image_dataset_Detection/Annotation/16. news_id_3162.txt
# real_Image_dataset_Detection/Annotation/16. _13527880332.txt
# real_Image_dataset_Detection/Annotation/15.txt
# real_Image_dataset_Detection/Annotation/15. niti-aayog-1493557223.txt
# real_Image_dataset_Detection/Annotation/15. img00407-20110717-1423.txt
# real_Image_dataset_Detection/Annotation/14.txt
# real_Image_dataset_Detection/Annotation/13.txt
# real_Image_dataset_Detection/Annotation/12.txt
# real_Image_dataset_Detection/Annotation/12. img201709231226442656225.txt
# real_Image_dataset_Detection/Annotation/12. delhi-metro-billboards.txt
# real_Image_dataset_Detection/Annotation/11.txt
# real_Image_dataset_Detection/Annotation/11. nyoooz_hindi1902_1507879752.txt
# real_Image_dataset_Detection/Annotation/11. national-museum.txt
# real_Image_dataset_Detection/Annotation/11. india_delhi_metro_rail_flickr_linuskendal_750_572_80_s.txt
# real_Image_dataset_Detection/Annotation/11. dsc_0018.txt
# real_Image_dataset_Detection/Annotation/11. caption.txt
# real_Image_dataset_Detection/Annotation/10.txt
# real_Image_dataset_Detection/Annotation/9. videoblocks-janpath-market-street-sign-hindi-and-english-new-delhi-india_sxqpwcxtx_thumbnail-full01.txt
# real_Image_dataset_Detection/Annotation/9.txt
# real_Image_dataset_Detection/Annotation/8.txt
# real_Image_dataset_Detection/Annotation/7.txt
# real_Image_dataset_Detection/Annotation/7. 016.txt
# real_Image_dataset_Detection/Annotation/6.txt
# real_Image_dataset_Detection/Annotation/5.txt
# real_Image_dataset_Detection/Annotation/5. img_6600.txt
# real_Image_dataset_Detection/Annotation/4.txt
# real_Image_dataset_Detection/Annotation/3.txt
# real_Image_dataset_Detection/Annotation/2.txt
# real_Image_dataset_Detection/Annotation/1.txt
# real_Image_dataset_Detection/Annotation/0.txt
# real_Image_dataset_Detection/Annotation/172.txt
# real_Image_dataset_Detection/Annotation/171.txt
# real_Image_dataset_Detection/Annotation/170.txt
# real_Image_dataset_Detection/Annotation/170. img_4941.txt
# real_Image_dataset_Detection/Annotation/170. guest-from-kerala-protested-outside-house-state_4146a3f6-7d6a-11e5-ba56-8cfa9414553d.txt
# real_Image_dataset_Detection/Annotation/169.txt
# real_Image_dataset_Detection/Annotation/168.txt
# real_Image_dataset_Detection/Annotation/167.txt
# real_Image_dataset_Detection/Annotation/166.txt
# real_Image_dataset_Detection/Annotation/166. 698797-delhi-hc.txt
# real_Image_dataset_Detection/Annotation/165.txt
# real_Image_dataset_Detection/Annotation/165. 300px-barrackpore_railway_station_%281%29.txt
# real_Image_dataset_Detection/Annotation/164.txt
# real_Image_dataset_Detection/Annotation/164. 12243201_10153720744566585_194230972898132752_n.txt
# real_Image_dataset_Detection/Annotation/164. 52b9304db02d31499e48e18b58608e20--henry-miller-madhya-pradesh.txt
# real_Image_dataset_Detection/Annotation/163.txt
# real_Image_dataset_Detection/Annotation/163. gali-paranthe-wali.txt
# real_Image_dataset_Detection/Annotation/162.txt
# real_Image_dataset_Detection/Annotation/162. firing-near-resteraunt-near-karol-bagh-metro-station.txt
# real_Image_dataset_Detection/Annotation/162. 113-640x360.txt
# real_Image_dataset_Detection/Annotation/161.txt
# real_Image_dataset_Detection/Annotation/161. nlu-450x338.txt
# real_Image_dataset_Detection/Annotation/160.txt
# real_Image_dataset_Detection/Annotation/160. 1-57-1507091095-261079-khaskhabar.txt
# real_Image_dataset_Detection/Annotation/159.txt
# real_Image_dataset_Detection/Annotation/158. ugc-1-759.txt
# real_Image_dataset_Detection/Annotation/158.txt
# real_Image_dataset_Detection/Annotation/158. keralahouse_beefsaahil11.txt
# real_Image_dataset_Detection/Annotation/157.txt
# real_Image_dataset_Detection/Annotation/156.txt
# real_Image_dataset_Detection/Annotation/155.txt
# real_Image_dataset_Detection/Annotation/154.txt
# real_Image_dataset_Detection/Annotation/153.txt
# real_Image_dataset_Detection/Annotation/152.txt
# real_Image_dataset_Detection/Annotation/152. hardlook-759.txt
# real_Image_dataset_Detection/Annotation/152. 28177310_3e1bf624-1bdc-43fe-a8d5-52b75cd96970.txt
# real_Image_dataset_Detection/Annotation/151. up-bjp-leaders-15237.txt
# real_Image_dataset_Detection/Annotation/151.txt
# real_Image_dataset_Detection/Annotation/151. national-archiv.txt
# real_Image_dataset_Detection/Annotation/150.txt
# real_Image_dataset_Detection/Annotation/150. 20151112_132030.txt
# real_Image_dataset_Detection/Annotation/149.txt
# real_Image_dataset_Detection/Annotation/149. hi369559685.txt
# real_Image_dataset_Detection/Annotation/149. 1200px-chinchwad_railway_station.txt
# real_Image_dataset_Detection/Annotation/148.txt
# real_Image_dataset_Detection/Annotation/147.txt
# real_Image_dataset_Detection/Annotation/147. eef31413b9324b59a1645f6a683132091983543.txt
# real_Image_dataset_Detection/Annotation/146.txt
# real_Image_dataset_Detection/Annotation/145.txt
# real_Image_dataset_Detection/Annotation/145. kanha-tiger-reserve.txt
# real_Image_dataset_Detection/Annotation/144.txt
# real_Image_dataset_Detection/Annotation/143.txt
# real_Image_dataset_Detection/Annotation/142.txt
# real_Image_dataset_Detection/Annotation/142. maxresdefault.txt
# real_Image_dataset_Detection/Annotation/142. 1*zvna5tlu7by4lpmb3cd90w.txt
# real_Image_dataset_Detection/Annotation/141.txt
# real_Image_dataset_Detection/Annotation/140.txt
# real_Image_dataset_Detection/Annotation/140. tibetan-1024x768.txt
# real_Image_dataset_Detection/Annotation/139. ugc759.txt
# real_Image_dataset_Detection/Annotation/139.txt
# real_Image_dataset_Detection/Annotation/139. 20141009_133738-e1512027263118.txt
# real_Image_dataset_Detection/Annotation/138.txt
# real_Image_dataset_Detection/Annotation/137.txt
# real_Image_dataset_Detection/Annotation/136. untitled-272.txt
# real_Image_dataset_Detection/Annotation/136.txt
# real_Image_dataset_Detection/Annotation/136. rbi-announces-f4755.txt
# real_Image_dataset_Detection/Annotation/135.txt
# real_Image_dataset_Detection/Annotation/134. img_2361.txt
# real_Image_dataset_Detection/Annotation/133.txt
# real_Image_dataset_Detection/Annotation/133. 06102011266.txt
# real_Image_dataset_Detection/Annotation/133. 4ff978e80f4b71d69a80ae4420f24d9f--new-delhi-ticket.txt
# real_Image_dataset_Detection/Annotation/132.txt
# real_Image_dataset_Detection/Annotation/132. india_welcome.txt
# real_Image_dataset_Detection/Annotation/132. 300px-pitampuradelhi.txt
# real_Image_dataset_Detection/Annotation/131.txt
# real_Image_dataset_Detection/Annotation/131. citi-maas6-1024x768.txt
# real_Image_dataset_Detection/Annotation/130.txt
# real_Image_dataset_Detection/Annotation/129.txt
# real_Image_dataset_Detection/Annotation/129. narsinghpur.txt
# real_Image_dataset_Detection/Annotation/129. iri23042013.txt
# real_Image_dataset_Detection/Annotation/128.txt
# real_Image_dataset_Detection/Annotation/128. metro_3.txt
# real_Image_dataset_Detection/Annotation/128. 1499669776_national_gallery_of_modern_art_delhi__282_29.txt
# real_Image_dataset_Detection/Annotation/127.txt
# real_Image_dataset_Detection/Annotation/126.txt
# real_Image_dataset_Detection/Annotation/126. img_3086.txt
# real_Image_dataset_Detection/Annotation/126. heritage-line-1_14_1495-1.txt
# real_Image_dataset_Detection/Annotation/125.txt
# real_Image_dataset_Detection/Annotation/124.txt
# real_Image_dataset_Detection/Annotation/124. outside-patel-chowk-metro.txt
# real_Image_dataset_Detection/Annotation/123.txt
# real_Image_dataset_Detection/Annotation/123. tropic-of-cancer-sponsored-by-the-government-of-madhya-pradesh.txt
# real_Image_dataset_Detection/Annotation/123. p1020013.txt
# real_Image_dataset_Detection/Annotation/122.txt
# real_Image_dataset_Detection/Annotation/122. img_3824.txt
# real_Image_dataset_Detection/Annotation/122. img1909930368.txt
# real_Image_dataset_Detection/Annotation/121.txt
# real_Image_dataset_Detection/Annotation/120.txt
# real_Image_dataset_Detection/Annotation/120. laxmi_nagar_metro_st._sign_board.txt
# real_Image_dataset_Detection/Annotation/120. 1478080632_rotates_shareiq_1213_1478078172.9512.txt
# real_Image_dataset_Detection/Annotation/119. img_9800-1.txt
# real_Image_dataset_Detection/Annotation/119. 21991845.txt
# real_Image_dataset_Detection/Annotation/118.txt
# real_Image_dataset_Detection/Annotation/118. delhi-high-court-7591-2.txt
# real_Image_dataset_Detection/Annotation/117.txt
# real_Image_dataset_Detection/Annotation/117. name-stone.txt
# real_Image_dataset_Detection/Annotation/117. main-qimg-09d0ff2a125cd775813beb37429ecc14-c.txt
# real_Image_dataset_Detection/Annotation/117. main-qimg-4f7c25fd3f68c21a80f74e7344215eee.txt
# real_Image_dataset_Detection/Annotation/116.txt
# real_Image_dataset_Detection/Annotation/115.txt
# real_Image_dataset_Detection/Annotation/114.txt
# real_Image_dataset_Detection/Annotation/114. palika-bazaar-delhi.txt
# real_Image_dataset_Detection/Annotation/114. lodhi-or-lodi-garden-new-delhi-popular-tourist-place-for-greenery-lovers-2-728.txt
# real_Image_dataset_Detection/Annotation/114. delhi-high-court-new.txt
# real_Image_dataset_Detection/Annotation/113.txt
# real_Image_dataset_Detection/Annotation/112.txt
# real_Image_dataset_Detection/Annotation/112. 657892-634346-616442-ngt-national-green-tribunal-101217.txt
# real_Image_dataset_Detection/Annotation/111.txt
# real_Image_dataset_Detection/Annotation/110.txt
# real_Image_dataset_Detection/Annotation/109. rajpath.txt
# real_Image_dataset_Detection/Annotation/109. khajuraho_station.txt
# real_Image_dataset_Detection/Annotation/108.txt
# real_Image_dataset_Detection/Annotation/107.txt
# real_Image_dataset_Detection/Annotation/106.txt
# real_Image_dataset_Detection/Annotation/105.txt
# real_Image_dataset_Detection/Annotation/105. parshvanath-and-adinath-khajuraho-temple-images.txt
# real_Image_dataset_Detection/Annotation/104.txt
# real_Image_dataset_Detection/Annotation/104. election-commission.txt
# real_Image_dataset_Detection/Annotation/295.txt
# real_Image_dataset_Detection/Annotation/294.txt
# real_Image_dataset_Detection/Annotation/294. temple-direction-sign-arrow-pointing-english-and-hindi-languages_sf3rupq4x_thumbnail-full01.txt
# real_Image_dataset_Detection/Annotation/293.txt
# real_Image_dataset_Detection/Annotation/292.txt
# real_Image_dataset_Detection/Annotation/291.txt
# real_Image_dataset_Detection/Annotation/290.txt
# real_Image_dataset_Detection/Annotation/289.txt
# real_Image_dataset_Detection/Annotation/287.txt
# real_Image_dataset_Detection/Annotation/286.txt
# real_Image_dataset_Detection/Annotation/285.txt
# real_Image_dataset_Detection/Annotation/284.txt
# real_Image_dataset_Detection/Annotation/283.txt
# real_Image_dataset_Detection/Annotation/282.txt
# real_Image_dataset_Detection/Annotation/281.txt
# real_Image_dataset_Detection/Annotation/280.txt
# real_Image_dataset_Detection/Annotation/279.txt
# real_Image_dataset_Detection/Annotation/278.txt
# real_Image_dataset_Detection/Annotation/277.txt
# real_Image_dataset_Detection/Annotation/276.txt
# real_Image_dataset_Detection/Annotation/276. 1-16337-26276.txt
# real_Image_dataset_Detection/Annotation/275.txt
# real_Image_dataset_Detection/Annotation/274.txt
# real_Image_dataset_Detection/Annotation/273.txt
# real_Image_dataset_Detection/Annotation/273. main-qimg-09d0ff2a125cd775813beb37429ecc14-c.txt
# real_Image_dataset_Detection/Annotation/272.txt
# real_Image_dataset_Detection/Annotation/271.txt
# real_Image_dataset_Detection/Annotation/270.txt
# real_Image_dataset_Detection/Annotation/270. palika-bazaar.txt
# real_Image_dataset_Detection/Annotation/269.txt
# real_Image_dataset_Detection/Annotation/268.txt
# real_Image_dataset_Detection/Annotation/267.txt
# real_Image_dataset_Detection/Annotation/266.txt
# real_Image_dataset_Detection/Annotation/265.txt
# real_Image_dataset_Detection/Annotation/264.txt
# real_Image_dataset_Detection/Annotation/264. himachal-bhawan1.txt
# real_Image_dataset_Detection/Annotation/263.txt
# real_Image_dataset_Detection/Annotation/262.txt
# real_Image_dataset_Detection/Annotation/261.txt
# real_Image_dataset_Detection/Annotation/260.txt
# real_Image_dataset_Detection/Annotation/259.txt
# real_Image_dataset_Detection/Annotation/258.txt
# real_Image_dataset_Detection/Annotation/257.txt
# real_Image_dataset_Detection/Annotation/256.txt
# real_Image_dataset_Detection/Annotation/255.txt
# real_Image_dataset_Detection/Annotation/254.txt
# real_Image_dataset_Detection/Annotation/253.txt
# real_Image_dataset_Detection/Annotation/252.txt
# real_Image_dataset_Detection/Annotation/251.txt
# real_Image_dataset_Detection/Annotation/250.txt
# real_Image_dataset_Detection/Annotation/249.txt
# real_Image_dataset_Detection/Annotation/248.txt
# real_Image_dataset_Detection/Annotation/246.txt
# real_Image_dataset_Detection/Annotation/245.txt
# real_Image_dataset_Detection/Annotation/244.txt
# real_Image_dataset_Detection/Annotation/243.txt
# real_Image_dataset_Detection/Annotation/242.txt
# real_Image_dataset_Detection/Annotation/241.txt
# real_Image_dataset_Detection/Annotation/240.txt
# real_Image_dataset_Detection/Annotation/240. temple-entrance-door-sign-english-and-hindi-languages-india_btx6gupxel_thumbnail-full01.txt
# real_Image_dataset_Detection/Annotation/239.txt
# real_Image_dataset_Detection/Annotation/238.txt
# real_Image_dataset_Detection/Annotation/237.txt
# real_Image_dataset_Detection/Annotation/236.txt
# real_Image_dataset_Detection/Annotation/235.txt
# real_Image_dataset_Detection/Annotation/234.txt
# real_Image_dataset_Detection/Annotation/233.txt
# real_Image_dataset_Detection/Annotation/233. delhi-zoo_1476867625.txt
# real_Image_dataset_Detection/Annotation/232.txt
# real_Image_dataset_Detection/Annotation/231.txt
# real_Image_dataset_Detection/Annotation/230.txt
# real_Image_dataset_Detection/Annotation/229.txt
# real_Image_dataset_Detection/Annotation/228.txt
# real_Image_dataset_Detection/Annotation/227.txt
# real_Image_dataset_Detection/Annotation/226.txt
# real_Image_dataset_Detection/Annotation/225.txt
# real_Image_dataset_Detection/Annotation/224.txt
# real_Image_dataset_Detection/Annotation/223.txt
# real_Image_dataset_Detection/Annotation/222.txt
# real_Image_dataset_Detection/Annotation/221.txt
# real_Image_dataset_Detection/Annotation/220.txt
# real_Image_dataset_Detection/Annotation/219.txt
# real_Image_dataset_Detection/Annotation/218.txt
# real_Image_dataset_Detection/Annotation/217.txt
# real_Image_dataset_Detection/Annotation/216.txt
# real_Image_dataset_Detection/Annotation/216. delhi-jahanpanah-city-forest.txt
# real_Image_dataset_Detection/Annotation/215.txt
# real_Image_dataset_Detection/Annotation/214.txt
# real_Image_dataset_Detection/Annotation/213.txt
# real_Image_dataset_Detection/Annotation/212.txt
# real_Image_dataset_Detection/Annotation/211.txt
# real_Image_dataset_Detection/Annotation/210.txt
# real_Image_dataset_Detection/Annotation/210. 595291a7b4ce8a3750530dec_59267d9f9a22727e7f52d080_1498583463954.txt
# real_Image_dataset_Detection/Annotation/209.txt
# real_Image_dataset_Detection/Annotation/208.txt
# real_Image_dataset_Detection/Annotation/207.txt
# real_Image_dataset_Detection/Annotation/206.txt
# real_Image_dataset_Detection/Annotation/205.txt
# real_Image_dataset_Detection/Annotation/204.txt
# real_Image_dataset_Detection/Annotation/203.txt
# real_Image_dataset_Detection/Annotation/202.txt
# real_Image_dataset_Detection/Annotation/201.txt
# real_Image_dataset_Detection/Annotation/200.txt
# real_Image_dataset_Detection/Annotation/199.txt
# real_Image_dataset_Detection/Annotation/198.txt
# real_Image_dataset_Detection/Annotation/197.txt
# real_Image_dataset_Detection/Annotation/196.txt
# real_Image_dataset_Detection/Annotation/195.txt
# real_Image_dataset_Detection/Annotation/194.txt
# real_Image_dataset_Detection/Annotation/193.txt
# real_Image_dataset_Detection/Annotation/192. delhi-high-court-7591.txt
# real_Image_dataset_Detection/Annotation/191.txt
# real_Image_dataset_Detection/Annotation/189.txt
# real_Image_dataset_Detection/Annotation/188.txt
# real_Image_dataset_Detection/Annotation/187.txt
# real_Image_dataset_Detection/Annotation/185.txt
# real_Image_dataset_Detection/Annotation/184.txt
# real_Image_dataset_Detection/Annotation/183.txt
# real_Image_dataset_Detection/Annotation/182.txt
# real_Image_dataset_Detection/Annotation/181.txt
# real_Image_dataset_Detection/Annotation/180.txt
# real_Image_dataset_Detection/Annotation/179.txt
# real_Image_dataset_Detection/Annotation/178.txt
# real_Image_dataset_Detection/Annotation/177.txt
# real_Image_dataset_Detection/Annotation/176.txt
# real_Image_dataset_Detection/Annotation/175.txt
# real_Image_dataset_Detection/Annotation/174.txt
# real_Image_dataset_Detection/Annotation/173.txt
# real_Image_dataset_Detection/Annotation/Thana-Ram-Janm-Bhoomi-1472884793-1499243551_835x547.txt
# real_Image_dataset_Detection/Annotation/pathik-hotel-by-pass-choraha-indore-lodging-services-25wt7lv.txt
# real_Image_dataset_Detection/Annotation/Pandit-Kulfi-1.txt
# real_Image_dataset_Detection/Annotation/panchavati-gaurav-to-add-50-outl-807e888a81.txt
# real_Image_dataset_Detection/Annotation/13116615_1804919146396837_824128706_n.txt
# real_Image_dataset_Detection/Annotation/499. veg-gulati_1427545555m.txt
# real_Image_dataset_Detection/Annotation/495. delhi-paranthe-wali-gali.txt
# real_Image_dataset_Detection/Annotation/494. national-zoo-sign1_1413278727_540x540.txt
# real_Image_dataset_Detection/Annotation/487. videoblocks-entry-for-differently-abled-sign-disabled-handicapped-entrance-delhi-india_bpbk2zyy6g_thumbnail-full01.txt
# real_Image_dataset_Detection/Annotation/484. 29.national%20museum.txt
# real_Image_dataset_Detection/Annotation/475. picsart03170990089.txt
# real_Image_dataset_Detection/Annotation/441. picsart010908623962.txt
# real_Image_dataset_Detection/Annotation/427. 2018_3$largeimg18_mar_2018_231139550.txt
# real_Image_dataset_Detection/Annotation/341. 15092450197_3dc5a760d3_b.txt
# real_Image_dataset_Detection/Annotation/325.txt
# real_Image_dataset_Detection/Annotation/324.txt
# real_Image_dataset_Detection/Annotation/323.txt
# real_Image_dataset_Detection/Annotation/322.txt
# real_Image_dataset_Detection/Annotation/321.txt
# real_Image_dataset_Detection/Annotation/319.txt
# real_Image_dataset_Detection/Annotation/318.txt
# real_Image_dataset_Detection/Annotation/317.txt
# real_Image_dataset_Detection/Annotation/316.txt
# real_Image_dataset_Detection/Annotation/315.txt
# real_Image_dataset_Detection/Annotation/314.txt
# real_Image_dataset_Detection/Annotation/313.txt
# real_Image_dataset_Detection/Annotation/312.txt
# real_Image_dataset_Detection/Annotation/312. akbar-road.txt
# real_Image_dataset_Detection/Annotation/311.txt
# real_Image_dataset_Detection/Annotation/310.txt
# real_Image_dataset_Detection/Annotation/309.txt
# real_Image_dataset_Detection/Annotation/308.txt
# real_Image_dataset_Detection/Annotation/307.txt
# real_Image_dataset_Detection/Annotation/306.txt
# real_Image_dataset_Detection/Annotation/305.txt
# real_Image_dataset_Detection/Annotation/304.txt
# real_Image_dataset_Detection/Annotation/303.txt
# real_Image_dataset_Detection/Annotation/302.txt
# real_Image_dataset_Detection/Annotation/301.txt
# real_Image_dataset_Detection/Annotation/300.txt
# real_Image_dataset_Detection/Annotation/299.txt
# real_Image_dataset_Detection/Annotation/298.txt
# real_Image_dataset_Detection/Annotation/297.txt
# real_Image_dataset_Detection/Annotation/296.txt

# %%
# %cat real_Image_dataset_Detection/readme.txt
# Out:
# - This dataset consists of 428 real images in the image folder. Annotation corresponding to image presents in Annotation folder.
# - The Annotation for the image has the same name that of the image just with the difference of extension. For example, if the image name is "1.jpg" then the corresponding annotation will be "1.txt".
# - The format for the storage of the annotation file is as such.
# - The no. of the line in annotation line denotes no of bounding box presents.
# - A single line represents a single bounding box. format is as follow x1, x2, x3, x4, y1, y2, y3, y4, groundTruth::Language. Where (x1,y1) is the top left, (x2,y2) is top right, (x3,y3) bottom right, (x4,y4) bottom left.
# - the order of point is in the clockwise order starting from the top-left points.
# - if the text is not recognizable or ground truth is not known, the ## is used for that representation.
# - For all of the image in the ground, truth is considered as ## only.
# - Though in most of the bounding box Hindi is the language in some cases English is also present. Language other than Hindi and English is considered as "other."

# %%
from google.colab.patches import cv2_imshow
import cv2
img = cv2.imread("real_Image_dataset_Detection/Image/0.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=715x500 at 0x7F735A41DEF0>

# %%
# %cat real_Image_dataset_Detection/Annotation/0.txt
# Out:
# 122,294,295,126,207,214,277,270,##::HINDI
# 291,469,472,303,213,221,283,287,##::HINDI
# 464,581,581,473,214,221,287,281,##::HINDI

# %%
# !git clone https://github.com/sergiomsilva/alpr-unconstrained
# %cd alpr-unconstrained/darknet/
# !make
# Out:
# Cloning into 'alpr-unconstrained'...
# remote: Enumerating objects: 290, done.
# remote: Total 290 (delta 0), reused 0 (delta 0), pack-reused 290
# Receiving objects: 100% (290/290), 2.62 MiB | 16.34 MiB/s, done.
# Resolving deltas: 100% (91/91), done.
# /content/alpr-unconstrained/darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/data.c -o obj/data.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/network.c -o obj/network.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/parser.c -o obj/parser.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/box.c -o obj/box.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/logistic_layer.c -o obj/logistic_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/l2norm_layer.c -o obj/l2norm_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/yolo_layer.c -o obj/yolo_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./src/iseg_layer.c -o obj/iseg_layer.o
# gcc -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -shared obj/gemm.o obj/utils.o obj/cuda.o obj/deconvolutional_layer.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/detection_layer.o obj/route_layer.o obj/upsample_layer.o obj/box.o obj/normalization_layer.o obj/avgpool_layer.o obj/layer.o obj/local_layer.o obj/shortcut_layer.o obj/logistic_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/crnn_layer.o obj/demo.o obj/batchnorm_layer.o obj/region_layer.o obj/reorg_layer.o obj/tree.o obj/lstm_layer.o obj/l2norm_layer.o obj/yolo_layer.o obj/iseg_layer.o -o libdarknet.so -lm -pthread
# ar rcs libdarknet.a obj/gemm.o obj/utils.o obj/cuda.o obj/deconvolutional_layer.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/detection_layer.o obj/route_layer.o obj/upsample_layer.o obj/box.o obj/normalization_layer.o obj/avgpool_layer.o obj/layer.o obj/local_layer.o obj/shortcut_layer.o obj/logistic_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/crnn_layer.o obj/demo.o obj/batchnorm_layer.o obj/region_layer.o obj/reorg_layer.o obj/tree.o obj/lstm_layer.o obj/l2norm_layer.o obj/yolo_layer.o obj/iseg_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/lsd.c -o obj/lsd.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/super.c -o obj/super.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/art.c -o obj/art.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/tag.c -o obj/tag.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/go.c -o obj/go.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/segmenter.c -o obj/segmenter.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/regressor.c -o obj/regressor.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/coco.c -o obj/coco.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/detector.c -o obj/detector.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/instance-segmenter.c -o obj/instance-segmenter.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast -c ./examples/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -fopenmp -Ofast obj/captcha.o obj/lsd.o obj/super.o obj/art.o obj/tag.o obj/cifar.o obj/go.o obj/rnn.o obj/segmenter.o obj/regressor.o obj/classifier.o obj/coco.o obj/yolo.o obj/detector.o obj/nightmare.o obj/instance-segmenter.o obj/darknet.o libdarknet.a -o darknet -lm -pthread  libdarknet.a

# %%
import os
os.getcwd()
# Out:
# '/content/alpr-unconstrained/darknet'

# %%
# %cd ..
# %mkdir models
# Out:
# /content/alpr-unconstrained

# %%
# !python create-model.py eccv models/eccv-model-scracth
# Out:
# Using TensorFlow backend.
# Creating model eccv
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-21 11:57:58.082237: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-21 11:57:58.084176: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x12f4a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-21 11:57:58.084215: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-21 11:57:58.089579: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-21 11:57:58.256152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 11:57:58.257113: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x12f4bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-21 11:57:58.257148: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-21 11:57:58.258372: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 11:57:58.258962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-21 11:57:58.259295: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-21 11:57:58.260797: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-21 11:57:58.262463: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-21 11:57:58.262829: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-21 11:57:58.264286: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-21 11:57:58.286446: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-21 11:57:58.289675: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-21 11:57:58.289797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 11:57:58.290482: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 11:57:58.291007: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-21 11:57:58.294780: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-21 11:57:58.296042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-21 11:57:58.296072: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-21 11:57:58.296083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-21 11:57:58.297304: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 11:57:58.297941: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-21 11:57:58.298495: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-03-21 11:57:58.298542: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Finished
# Saving at models/eccv-model-scracth

# %%
# !mkdir samples/training_samples

# %%
# !mv /content/real_Image_dataset_Detection/Image/*.jpg /content/alpr-unconstrained/samples/training_samples
# !mv /content/real_Image_dataset_Detection/Annotation/*.txt /content/alpr-unconstrained/samples/training_samples

# %%
# %%writefile /content/alpr-unconstrained/license-plate-detection.py

import sys, os
import keras
import cv2
import traceback

from src.keras_utils 			import load_model
from glob 						import glob
from os.path 					import splitext, basename
from src.utils 					import im2single
from src.keras_utils 			import load_model, detect_lp
from src.label 					import Shape, writeShapes


def adjust_pts(pts,lroi):
	return pts*lroi.wh().reshape((2,1)) + lroi.tl().reshape((2,1))


if __name__ == '__main__':

	try:
		
		input_dir  = sys.argv[1]
		output_dir = input_dir

		lp_threshold = .5

		wpod_net_path = sys.argv[2]
		wpod_net = load_model(wpod_net_path)

		imgs_paths = glob('%s/*' % input_dir)

		print 'Searching for license plates using WPOD-NET'

		for i,img_path in enumerate(imgs_paths):

			print '\t Processing %s' % img_path

			bname = splitext(basename(img_path))[0]
			Ivehicle = cv2.imread(img_path)

			ratio = float(max(Ivehicle.shape[:2]))/min(Ivehicle.shape[:2])
			side  = int(ratio*288.)
			bound_dim = min(side + (side%(2**4)),608)
			print "\t\tBound dim: %d, ratio: %f" % (bound_dim,ratio)

			Llp,LlpImgs,_ = detect_lp(wpod_net,im2single(Ivehicle),bound_dim,2**4,(240,80),lp_threshold)

			if len(LlpImgs):
				Ilp = LlpImgs[0]
				Ilp = cv2.cvtColor(Ilp, cv2.COLOR_BGR2GRAY)
				Ilp = cv2.cvtColor(Ilp, cv2.COLOR_GRAY2BGR)

				s = Shape(Llp[0].pts)

				cv2.imwrite('%s/%s_lp.png' % (output_dir,bname),Ilp*255.)
				writeShapes('%s/%s_lp.txt' % (output_dir,bname),[s])

	except:
		traceback.print_exc()
		sys.exit(1)

	sys.exit(0)
# Out:
# Overwriting /content/alpr-unconstrained/license-plate-detection.py

# %%
# %%writefile /content/alpr-unconstrained/src/label.py

import numpy as np

from os.path import isfile


class Label:

	def __init__(self,cl=-1,tl=np.array([0.,0.]),br=np.array([0.,0.]),prob=None):
		self.__tl 	= tl
		self.__br 	= br
		self.__cl 	= cl
		self.__prob = prob

	def __str__(self):
		return 'Class: %d, top_left(x:%f,y:%f), bottom_right(x:%f,y:%f)' % (self.__cl, self.__tl[0], self.__tl[1], self.__br[0], self.__br[1])

	def copy(self):
		return Label(self.__cl,self.__tl,self.__br)

	def wh(self): return self.__br-self.__tl

	def cc(self): return self.__tl + self.wh()/2

	def tl(self): return self.__tl
 
	def br(self): return self.__br

	def tr(self): return np.array([self.__br[0],self.__tl[1]])

	def bl(self): return np.array([self.__tl[0],self.__br[1]])

	def cl(self): return self.__cl

	def area(self): return np.prod(self.wh())

	def prob(self): return self.__prob

	def set_class(self,cl):
		self.__cl = cl

	def set_tl(self,tl):
		self.__tl = tl

	def set_br(self,br):
		self.__br = br

	def set_wh(self,wh):
		cc = self.cc()
		self.__tl = cc - .5*wh
		self.__br = cc + .5*wh

	def set_prob(self,prob):
		self.__prob = prob


def lread(file_path,label_type=Label):

	if not isfile(file_path):
		return []

	objs = []
	with open(file_path,'r') as fd:
		for line in fd:
			v 		= line.strip().split()
			cl 		= int(v[0])
			ccx,ccy = float(v[1]),float(v[2])
			w,h 	= float(v[3]),float(v[4])
			prob 	= float(v[5]) if len(v) == 6 else None

			cc 	= np.array([ccx,ccy])
			wh 	= np.array([w,h])

			objs.append(label_type(cl,cc-wh/2,cc+wh/2,prob=prob))

	return objs

def lwrite(file_path,labels,write_probs=True):
	with open(file_path,'w') as fd:
		for l in labels:
			cc,wh,cl,prob = (l.cc(),l.wh(),l.cl(),l.prob())
			if prob != None and write_probs:
				fd.write('%d %f %f %f %f %f\n' % (cl,cc[0],cc[1],wh[0],wh[1],prob))
			else:
				fd.write('%d %f %f %f %f\n' % (cl,cc[0],cc[1],wh[0],wh[1]))


def dknet_label_conversion(R,img_width,img_height):
	WH = np.array([img_width,img_height],dtype=float)
	L  = []
	for r in R:
		center = np.array(r[2][:2])/WH
		wh2 = (np.array(r[2][2:])/WH)*.5
		L.append(Label(ord(r[0]),tl=center-wh2,br=center+wh2,prob=r[1]))
	return L


class Shape():

	def __init__(self,pts=np.zeros((2,0)),max_sides=4,text=''):
		self.pts = pts
		self.max_sides = max_sides
		self.text = text

	def isValid(self):
		return self.pts.shape[1] > 2

	def write(self,fp):
		fp.write('%d,' % self.pts.shape[1])
		ptsarray = self.pts.flatten()
		fp.write(''.join([('%f,' % value) for value in ptsarray]))
		fp.write('%s,' % self.text)
		fp.write('\n')

	def read(self,line):
		data 		= line.strip().split(',')
		ss 			= 4
		values 		= data[:ss*2]
		text 		= data[-1].split("::")[-1]
		self.pts 	= np.array([float(value) for value in values]).reshape((2,ss))
		self.text   = text

def readShapes(path,obj_type=Shape):
	shapes = []
	with open(path) as fp:
		for line in fp:
			shape = obj_type()
			shape.read(line)
			shapes.append(shape)
	return shapes

def writeShapes(path,shapes):
	if len(shapes):
		with open(path,'w') as fp:
			for shape in shapes:
				if shape.isValid():
					shape.write(fp)
# Out:
# Overwriting /content/alpr-unconstrained/src/label.py

# %%
# !python train-detector.py --model /content/alpr-unconstrained/models/eccv-model-scracth --name my-trained-model \
 --train-dir samples/training_samples/ --output-dir /content/alpr-unconstrained/models/my-trained-model -op Adam -lr .0001 -its 30000 -bs 64
# Out:
# Streaming output truncated to the last 5000 lines.
# Iter. 15415 (of 30000)
# 	Loss: 29.733173
# Iter. 15416 (of 30000)
# 	Loss: 31.924881
# Iter. 15417 (of 30000)
# 	Loss: 34.444233
# Iter. 15418 (of 30000)
# 	Loss: 39.035851
# Iter. 15419 (of 30000)
# 	Loss: 31.254578
# Iter. 15420 (of 30000)
# 	Loss: 32.630802
# Iter. 15421 (of 30000)
# 	Loss: 38.957874
# Iter. 15422 (of 30000)
# 	Loss: 33.837276
# Iter. 15423 (of 30000)
# 	Loss: 34.023109
# Iter. 15424 (of 30000)
# 	Loss: 25.958385
# Iter. 15425 (of 30000)
# 	Loss: 36.280739
# Iter. 15426 (of 30000)
# 	Loss: 26.760426
# Iter. 15427 (of 30000)
# 	Loss: 39.736996
# Iter. 15428 (of 30000)
# 	Loss: 29.455748
# Iter. 15429 (of 30000)
# 	Loss: 27.316872
# Iter. 15430 (of 30000)
# 	Loss: 31.142454
# Iter. 15431 (of 30000)
# 	Loss: 33.284351
# Iter. 15432 (of 30000)
# 	Loss: 31.106785
# Iter. 15433 (of 30000)
# 	Loss: 33.196941
# Iter. 15434 (of 30000)
# 	Loss: 36.840878
# Iter. 15435 (of 30000)
# 	Loss: 34.150078
# Iter. 15436 (of 30000)
# 	Loss: 29.012606
# Iter. 15437 (of 30000)
# 	Loss: 33.913815
# Iter. 15438 (of 30000)
# 	Loss: 30.133339
# Iter. 15439 (of 30000)
# 	Loss: 36.890427
# Iter. 15440 (of 30000)
# 	Loss: 30.008747
# Iter. 15441 (of 30000)
# 	Loss: 32.578182
# Iter. 15442 (of 30000)
# 	Loss: 41.736343
# Iter. 15443 (of 30000)
# 	Loss: 36.908325
# Iter. 15444 (of 30000)
# 	Loss: 31.806025
# Iter. 15445 (of 30000)
# 	Loss: 30.595829
# Iter. 15446 (of 30000)
# 	Loss: 31.223845
# Iter. 15447 (of 30000)
# 	Loss: 24.440506
# Iter. 15448 (of 30000)
# Iter. 15978 (of 30000)
# 	Loss: 29.296652
# Iter. 15979 (of 30000)
# 	Loss: 32.934361
# Iter. 15980 (of 30000)
# 	Loss: 29.025631
# Iter. 15981 (of 30000)
# 	Loss: 36.973087
# Iter. 15982 (of 30000)
# 	Loss: 34.844627
# Iter. 15983 (of 30000)
# 	Loss: 27.465508
# Iter. 15984 (of 30000)
# 	Loss: 34.513821
# Iter. 15985 (of 30000)
# 	Loss: 34.249210
# Iter. 15986 (of 30000)
# 	Loss: 32.080963
# Iter. 15987 (of 30000)
# 	Loss: 35.776672
# Iter. 15988 (of 30000)
# 	Loss: 31.132492
# Iter. 15989 (of 30000)
# 	Loss: 34.955223
# Iter. 15990 (of 30000)
# 	Loss: 32.067543
# Iter. 15991 (of 30000)
# 	Loss: 37.958923
# Iter. 15992 (of 30000)
# 	Loss: 27.319096
# Iter. 15993 (of 30000)
# 	Loss: 35.292267
# Iter. 15994 (of 30000)
# 	Loss: 38.683205
# Iter. 15995 (of 30000)
# 	Loss: 35.453709
# Iter. 15996 (of 30000)
# 	Loss: 30.954458
# Iter. 15997 (of 30000)
# 	Loss: 30.464935
# Iter. 15998 (of 30000)
# 	Loss: 28.996452
# Iter. 15999 (of 30000)
# 	Loss: 37.357941
# Iter. 16000 (of 30000)
# 	Loss: 33.049934
# Saving model (/content/alpr-unconstrained/models/my-trained-model/my-trained-model_backup)
# Iter. 16001 (of 30000)
# 	Loss: 36.652493
# Iter. 16002 (of 30000)
# 	Loss: 33.266708
# Iter. 16003 (of 30000)
# 	Loss: 33.034325
# Iter. 16004 (of 30000)
# 	Loss: 36.292473
# Iter. 16005 (of 30000)
# 	Loss: 33.919548
# Iter. 16006 (of 30000)
# 	Loss: 31.868416
# Iter. 16007 (of 30000)
# 	Loss: 37.316666
# Iter. 16008 (of 30000)
# 	Loss: 31.320917
# Iter. 16009 (of 30000)
# 	Loss: 38.051426
# Iter. 16010 (of 30000)
# 	Loss: 33.209541
# Iter. 16011 (of 30000)
# 	Loss: 33.301350
# Iter. 16012 (of 30000)
# 	Loss: 33.483025
# Iter. 16013 (of 30000)
# 	Loss: 37.225788
# Iter. 16014 (of 30000)
# 	Loss: 34.602379
# Iter. 16015 (of 30000)
# 	Loss: 30.814434
# Iter. 16016 (of 30000)
# 	Loss: 32.979950
# Iter. 16017 (of 30000)
# 	Loss: 35.591606
# Iter. 16018 (of 30000)
# 	Loss: 35.078094
# Iter. 16019 (of 30000)
# 	Loss: 31.976776
# Iter. 16020 (of 30000)
# 	Loss: 42.322311
# Iter. 16021 (of 30000)
# 	Loss: 32.026066
# Iter. 16022 (of 30000)
# 	Loss: 32.265846
# Iter. 16023 (of 30000)
# 	Loss: 32.753883
# Iter. 16024 (of 30000)
# 	Loss: 34.265957
# Iter. 16025 (of 30000)
# 	Loss: 33.308910
# Iter. 16026 (of 30000)
# 	Loss: 34.384956
# Iter. 16027 (of 30000)
# 	Loss: 35.854568
# Iter. 16028 (of 30000)
# 	Loss: 32.286373
# Iter. 16029 (of 30000)
# Iter. 16082 (of 30000)
# 	Loss: 31.783939
# Iter. 16083 (of 30000)
# 	Loss: 32.623657
# Iter. 16084 (of 30000)
# 	Loss: 31.463448
# Iter. 16085 (of 30000)
# 	Loss: 31.562029
# Iter. 16086 (of 30000)
# 	Loss: 32.933350
# Iter. 16087 (of 30000)
# 	Loss: 31.712172
# Iter. 16088 (of 30000)
# 	Loss: 36.498032
# Iter. 16089 (of 30000)
# 	Loss: 38.196388
# Iter. 16090 (of 30000)
# 	Loss: 41.847813
# Iter. 16091 (of 30000)
# 	Loss: 35.614742
# Iter. 16092 (of 30000)
# 	Loss: 34.082054
# Iter. 16093 (of 30000)
# 	Loss: 29.141014
# Iter. 16094 (of 30000)
# 	Loss: 33.220634
# Iter. 16095 (of 30000)
# 	Loss: 31.602661
# Iter. 16096 (of 30000)
# 	Loss: 29.031349
# Iter. 16097 (of 30000)
# 	Loss: 33.618229
# Iter. 16098 (of 30000)
# 	Loss: 29.550016
# Iter. 16099 (of 30000)
# 	Loss: 35.840988
# Iter. 16100 (of 30000)
# 	Loss: 30.555092
# Iter. 16101 (of 30000)
# 	Loss: 31.784214
# Iter. 16102 (of 30000)
# 	Loss: 34.284485
# Iter. 16103 (of 30000)
# 	Loss: 30.609173
# Iter. 16104 (of 30000)
# 	Loss: 36.342655
# Iter. 16105 (of 30000)
# 	Loss: 30.208864
# Iter. 16106 (of 30000)
# 	Loss: 30.059143
# Iter. 16107 (of 30000)
# 	Loss: 33.574684
# Iter. 16108 (of 30000)
# 	Loss: 33.981705
# Iter. 16109 (of 30000)
# 	Loss: 32.761944
# Iter. 16110 (of 30000)
# 	Loss: 33.783508
# Iter. 16111 (of 30000)
# 	Loss: 34.281448
# Iter. 16112 (of 30000)
# 	Loss: 29.157671
# Iter. 16113 (of 30000)
# 	Loss: 30.676510
# Iter. 16114 (of 30000)
# 	Loss: 36.334274
# Iter. 16115 (of 30000)
# 	Loss: 36.616714
# Iter. 16116 (of 30000)
# 	Loss: 37.349476
# Iter. 16117 (of 30000)
# 	Loss: 33.588547
# Iter. 16118 (of 30000)
# 	Loss: 29.499567
# Iter. 16119 (of 30000)
# 	Loss: 32.278641
# Iter. 16120 (of 30000)
# 	Loss: 32.121490
# Iter. 16121 (of 30000)
# 	Loss: 30.703327
# Iter. 16122 (of 30000)
# 	Loss: 32.699360
# Iter. 16123 (of 30000)
# 	Loss: 33.061096
# Iter. 16124 (of 30000)
# 	Loss: 28.343884
# Iter. 16125 (of 30000)
# 	Loss: 34.610741
# Iter. 16126 (of 30000)
# 	Loss: 30.962109
# Iter. 16127 (of 30000)
# 	Loss: 32.491207
# Iter. 16128 (of 30000)
# 	Loss: 34.430256
# Iter. 16129 (of 30000)
# 	Loss: 35.338173
# Iter. 16130 (of 30000)
# 	Loss: 27.362194
# Iter. 16131 (of 30000)
# 	Loss: 34.006378
# Iter. 16132 (of 30000)
# 	Loss: 35.493866
# Iter. 16133 (of 30000)
# 	Loss: 31.370163
# Iter. 16134 (of 30000)
# 	Loss: 35.028656
# Iter. 16188 (of 30000)
# 	Loss: 32.240673
# Iter. 16189 (of 30000)
# 	Loss: 33.007626
# Iter. 16190 (of 30000)
# 	Loss: 36.625248
# Iter. 16191 (of 30000)
# 	Loss: 33.748138
# Iter. 16192 (of 30000)
# 	Loss: 33.620819
# Iter. 16193 (of 30000)
# 	Loss: 37.131229
# Iter. 16194 (of 30000)
# 	Loss: 30.743195
# Iter. 16195 (of 30000)
# 	Loss: 38.408512
# Iter. 16196 (of 30000)
# 	Loss: 32.114891
# Iter. 16197 (of 30000)
# 	Loss: 28.526735
# Iter. 16198 (of 30000)
# 	Loss: 33.845295
# Iter. 16199 (of 30000)
# 	Loss: 37.383911
# Iter. 16200 (of 30000)
# 	Loss: 31.010592
# Iter. 16201 (of 30000)
# 	Loss: 33.027172
# Iter. 16202 (of 30000)
# 	Loss: 30.733000
# Iter. 16203 (of 30000)
# 	Loss: 32.877201
# Iter. 16204 (of 30000)
# 	Loss: 32.940598
# Iter. 16205 (of 30000)
# 	Loss: 32.896538
# Iter. 16206 (of 30000)
# 	Loss: 36.857864
# Iter. 16207 (of 30000)
# 	Loss: 33.455826
# Iter. 16208 (of 30000)
# 	Loss: 34.683273
# Iter. 16209 (of 30000)
# 	Loss: 30.650684
# Iter. 16210 (of 30000)
# 	Loss: 32.289833
# Iter. 16211 (of 30000)
# 	Loss: 35.000961
# Iter. 16212 (of 30000)
# 	Loss: 34.979671
# Iter. 16213 (of 30000)
# 	Loss: 30.684780
# Iter. 16214 (of 30000)
# 	Loss: 36.199936
# Iter. 16215 (of 30000)
# 	Loss: 32.972885
# Iter. 16216 (of 30000)
# 	Loss: 33.370285
# Iter. 16217 (of 30000)
# 	Loss: 31.209238
# Iter. 16218 (of 30000)
# 	Loss: 32.044838
# Iter. 16219 (of 30000)
# 	Loss: 36.738842
# Iter. 16220 (of 30000)
# 	Loss: 40.693489
# Iter. 16221 (of 30000)
# 	Loss: 32.721539
# Iter. 16222 (of 30000)
# 	Loss: 34.318062
# Iter. 16223 (of 30000)
# 	Loss: 30.736988
# Iter. 16224 (of 30000)
# 	Loss: 35.978645
# Iter. 16225 (of 30000)
# 	Loss: 29.795959
# Iter. 16226 (of 30000)
# 	Loss: 35.409302
# Iter. 16227 (of 30000)
# 	Loss: 32.199905
# Iter. 16228 (of 30000)
# 	Loss: 34.489380
# Iter. 16229 (of 30000)
# 	Loss: 38.663067
# Iter. 16230 (of 30000)
# 	Loss: 31.626165
# Iter. 16231 (of 30000)
# 	Loss: 26.629517
# Iter. 16232 (of 30000)
# 	Loss: 33.504707
# Iter. 16233 (of 30000)
# 	Loss: 36.995407
# Iter. 16234 (of 30000)
# 	Loss: 30.998783
# Iter. 16235 (of 30000)
# 	Loss: 30.920006
# Iter. 16236 (of 30000)
# 	Loss: 32.280293
# Iter. 16237 (of 30000)
# 	Loss: 38.409996
# Iter. 16238 (of 30000)
# 	Loss: 31.447968
# Iter. 16239 (of 30000)
# 	Loss: 33.485893
# Iter. 16240 (of 30000)
# 	Loss: 34.402580
# 	Loss: 33.978966
# Iter. 16506 (of 30000)
# 	Loss: 34.197990
# Iter. 16507 (of 30000)
# 	Loss: 29.708834
# Iter. 16508 (of 30000)
# 	Loss: 37.740910
# Iter. 16509 (of 30000)
# 	Loss: 34.013271
# Iter. 16510 (of 30000)
# 	Loss: 30.295715
# Iter. 16511 (of 30000)
# 	Loss: 33.371468
# Iter. 16512 (of 30000)
# 	Loss: 35.361893
# Iter. 16513 (of 30000)
# 	Loss: 32.872929
# Iter. 16514 (of 30000)
# 	Loss: 38.274849
# Iter. 16515 (of 30000)
# 	Loss: 32.584919
# Iter. 16516 (of 30000)
# 	Loss: 29.290195
# Iter. 16517 (of 30000)
# 	Loss: 35.401619
# Iter. 16518 (of 30000)
# 	Loss: 30.325130
# Iter. 16519 (of 30000)
# 	Loss: 33.347157
# Iter. 16520 (of 30000)
# 	Loss: 32.441639
# Iter. 16521 (of 30000)
# 	Loss: 33.356964
# Iter. 16522 (of 30000)
# 	Loss: 34.115623
# Iter. 16523 (of 30000)
# 	Loss: 36.500206
# Iter. 16524 (of 30000)
# 	Loss: 31.275648
# Iter. 16525 (of 30000)
# 	Loss: 28.148678
# Iter. 16526 (of 30000)
# 	Loss: 31.062275
# Iter. 16527 (of 30000)
# 	Loss: 30.152958
# Iter. 16528 (of 30000)
# 	Loss: 34.344727
# Iter. 16529 (of 30000)
# 	Loss: 33.065948
# Iter. 16530 (of 30000)
# 	Loss: 33.904846
# Iter. 16531 (of 30000)
# 	Loss: 36.278168
# Iter. 16532 (of 30000)
# 	Loss: 32.705051
# Iter. 16533 (of 30000)
# 	Loss: 35.510517
# Iter. 16534 (of 30000)
# 	Loss: 31.178123
# Iter. 16535 (of 30000)
# 	Loss: 34.412979
# Iter. 16536 (of 30000)
# 	Loss: 26.788914
# Iter. 16537 (of 30000)
# 	Loss: 33.649254
# Iter. 16538 (of 30000)
# 	Loss: 27.311945
# Iter. 16539 (of 30000)
# 	Loss: 32.091354
# Iter. 16540 (of 30000)
# 	Loss: 27.300833
# Iter. 16541 (of 30000)
# 	Loss: 28.137669
# Iter. 16542 (of 30000)
# 	Loss: 29.917068
# Iter. 16543 (of 30000)
# 	Loss: 32.140385
# Iter. 16544 (of 30000)
# 	Loss: 34.337830
# Iter. 16545 (of 30000)
# 	Loss: 33.689980
# Iter. 16546 (of 30000)
# 	Loss: 35.668869
# Iter. 16547 (of 30000)
# 	Loss: 32.136536
# Iter. 16548 (of 30000)
# 	Loss: 35.140968
# Iter. 16549 (of 30000)
# 	Loss: 29.001225
# Iter. 16550 (of 30000)
# 	Loss: 27.239323
# Iter. 16551 (of 30000)
# 	Loss: 29.515766
# Iter. 16552 (of 30000)
# 	Loss: 31.129726
# Iter. 16553 (of 30000)
# 	Loss: 38.111233
# Iter. 16554 (of 30000)
# 	Loss: 28.609196
# Iter. 16555 (of 30000)
# 	Loss: 28.897400
# Iter. 16556 (of 30000)
# 	Loss: 33.093307
# Iter. 16557 (of 30000)
# 	Loss: 31.926361
# Iter. 16558 (of 30000)
# 	Loss: 35.194901
# Iter. 16559 (of 30000)
# 	Loss: 31.625854
# Iter. 16560 (of 30000)
# 	Loss: 29.708519
# Iter. 16561 (of 30000)
# 	Loss: 32.778435
# Iter. 16562 (of 30000)
# 	Loss: 37.072105
# Iter. 16563 (of 30000)
# 	Loss: 32.636875
# Iter. 16564 (of 30000)
# 	Loss: 32.115906
# Iter. 16565 (of 30000)
# 	Loss: 26.067181
# Iter. 16566 (of 30000)
# 	Loss: 28.847782
# Iter. 16567 (of 30000)
# 	Loss: 35.430004
# Iter. 16568 (of 30000)
# 	Loss: 31.062721
# Iter. 16569 (of 30000)
# 	Loss: 33.793022
# Iter. 16570 (of 30000)
# 	Loss: 31.493134
# Iter. 16571 (of 30000)
# 	Loss: 38.298805
# Iter. 16572 (of 30000)
# 	Loss: 32.841560
# Iter. 16573 (of 30000)
# 	Loss: 40.429237
# Iter. 16574 (of 30000)
# 	Loss: 37.351540
# Iter. 16575 (of 30000)
# 	Loss: 35.659504
# Iter. 16576 (of 30000)
# 	Loss: 30.914253
# Iter. 16577 (of 30000)
# 	Loss: 34.353107
# Iter. 16578 (of 30000)
# 	Loss: 35.417084
# Iter. 16579 (of 30000)
# 	Loss: 29.410933
# Iter. 16580 (of 30000)
# 	Loss: 35.332161
# Iter. 16581 (of 30000)
# 	Loss: 38.536324
# Iter. 16582 (of 30000)
# 	Loss: 31.444288
# Iter. 16583 (of 30000)
# 	Loss: 35.575394
# Iter. 16584 (of 30000)
# 	Loss: 33.252678
# Iter. 16585 (of 30000)
# 	Loss: 29.247522
# Iter. 16586 (of 30000)
# 	Loss: 34.642735
# Iter. 16587 (of 30000)
# 	Loss: 37.026817
# Iter. 16588 (of 30000)
# 	Loss: 33.221302
# Iter. 16589 (of 30000)
# 	Loss: 31.494377
# Iter. 16590 (of 30000)
# 	Loss: 30.223053
# Iter. 16591 (of 30000)
# 	Loss: 30.896961
# Iter. 16592 (of 30000)
# 	Loss: 34.622921
# Iter. 16593 (of 30000)
# 	Loss: 36.662964
# Iter. 16594 (of 30000)
# 	Loss: 31.580465
# Iter. 16595 (of 30000)
# 	Loss: 35.409569
# Iter. 16596 (of 30000)
# 	Loss: 35.976711
# Iter. 16597 (of 30000)
# 	Loss: 32.578690
# Iter. 16598 (of 30000)
# 	Loss: 37.974197
# Iter. 16599 (of 30000)
# 	Loss: 33.085594
# Iter. 16600 (of 30000)
# 	Loss: 33.610245
# Iter. 16601 (of 30000)
# 	Loss: 43.924820
# Iter. 16602 (of 30000)
# 	Loss: 38.364601
# Iter. 16603 (of 30000)
# 	Loss: 34.702499
# Iter. 16604 (of 30000)
# 	Loss: 31.689711
# Iter. 16605 (of 30000)
# 	Loss: 35.687447
# Iter. 16606 (of 30000)
# 	Loss: 35.804745
# Iter. 16607 (of 30000)
# 	Loss: 32.798256
# Iter. 16608 (of 30000)
# 	Loss: 35.788116
# Iter. 16609 (of 30000)
# 	Loss: 33.224648
# Iter. 16610 (of 30000)
# 	Loss: 40.664711
# ...
# Iter. 17570 (of 30000)
# 	Loss: 32.291969
# Iter. 17571 (of 30000)
# 	Loss: 35.281376
# Iter. 17572 (of 30000)
# 	Loss: 32.858925
# Iter. 17573 (of 30000)
# 	Loss: 31.812939
# Iter. 17574 (of 30000)
# 	Loss: 27.801216
# Iter. 17575 (of 30000)
# 	Loss: 32.489983
# Iter. 17576 (of 30000)
# 	Loss: 35.491081
# Iter. 17577 (of 30000)
# 	Loss: 32.850307
# Iter. 17578 (of 30000)
# 	Loss: 35.659782
# Iter. 17579 (of 30000)
# 	Loss: 39.613781
# Iter. 17580 (of 30000)
# 	Loss: 29.686970
# Iter. 17581 (of 30000)
# 	Loss: 35.116093
# Iter. 17582 (of 30000)
# 	Loss: 30.526274
# Iter. 17583 (of 30000)
# 	Loss: 35.199211
# Iter. 17584 (of 30000)
# 	Loss: 35.058201
# Iter. 17585 (of 30000)
# 	Loss: 32.849136
# Iter. 17586 (of 30000)
# 	Loss: 30.826363
# Iter. 17587 (of 30000)
# 	Loss: 39.656445
# Iter. 17588 (of 30000)
# 	Loss: 29.075363
# Iter. 17589 (of 30000)
# 	Loss: 28.587086
# Iter. 17590 (of 30000)
# 	Loss: 34.632675
# Iter. 17591 (of 30000)
# 	Loss: 27.437212
# Iter. 17592 (of 30000)
# 	Loss: 31.105732
# Iter. 17593 (of 30000)
# 	Loss: 28.201101
# Iter. 17594 (of 30000)
# 	Loss: 31.933878
# Iter. 17595 (of 30000)
# 	Loss: 38.355415
# Iter. 17596 (of 30000)
# 	Loss: 33.893501
# Iter. 17597 (of 30000)
# 	Loss: 32.280540
# Iter. 17598 (of 30000)
# 	Loss: 30.125858
# Iter. 17599 (of 30000)
# 	Loss: 30.469810
# Iter. 17600 (of 30000)
# 	Loss: 30.980234
# Iter. 17601 (of 30000)
# 	Loss: 26.710140
# Iter. 17602 (of 30000)
# 	Loss: 37.766514
# Iter. 17603 (of 30000)
# 	Loss: 33.333500
# Iter. 17604 (of 30000)
# 	Loss: 29.474163
# Iter. 17605 (of 30000)
# 	Loss: 35.117878
# Iter. 17606 (of 30000)
# 	Loss: 32.694855
# Iter. 17607 (of 30000)
# 	Loss: 28.006723
# Iter. 17608 (of 30000)
# 	Loss: 29.410196
# Iter. 17609 (of 30000)
# 	Loss: 30.356266
# Iter. 17610 (of 30000)
# 	Loss: 28.987080
# Iter. 17611 (of 30000)
# 	Loss: 33.077538
# Iter. 17612 (of 30000)
# 	Loss: 31.998756
# Iter. 17613 (of 30000)
# 	Loss: 34.741859
# Iter. 17614 (of 30000)
# 	Loss: 38.330704
# Iter. 17615 (of 30000)
# 	Loss: 39.049324
# Iter. 17616 (of 30000)
# 	Loss: 26.216915
# Iter. 17617 (of 30000)
# 	Loss: 35.779175
# Iter. 17618 (of 30000)
# 	Loss: 32.805763
# Iter. 17619 (of 30000)
# 	Loss: 30.168167
# Iter. 17620 (of 30000)
# 	Loss: 34.696648
# Iter. 17621 (of 30000)
# 	Loss: 36.524033
# Iter. 17622 (of 30000)
# 	Loss: 31.123276
# Iter. 17623 (of 30000)
# 	Loss: 33.933926
# Iter. 17624 (of 30000)
# 	Loss: 38.860653
# Iter. 17625 (of 30000)
# 	Loss: 32.318741
# Iter. 17626 (of 30000)
# 	Loss: 27.140484
# Iter. 17627 (of 30000)
# 	Loss: 40.516563
# Iter. 17628 (of 30000)
# 	Loss: 39.205017
# Iter. 17629 (of 30000)
# 	Loss: 30.007229
# Iter. 17630 (of 30000)
# 	Loss: 32.504173
# Iter. 17631 (of 30000)
# 	Loss: 33.197914
# Iter. 17632 (of 30000)
# 	Loss: 35.116589
# Iter. 17633 (of 30000)
# 	Loss: 39.428825
# Iter. 17634 (of 30000)
# 	Loss: 27.827457
# Iter. 17635 (of 30000)
# 	Loss: 30.605415
# Iter. 17636 (of 30000)
# 	Loss: 30.992254
# Iter. 17637 (of 30000)
# 	Loss: 35.814819
# Iter. 17638 (of 30000)
# 	Loss: 37.378784
# Iter. 17639 (of 30000)
# 	Loss: 31.511307
# Iter. 17640 (of 30000)
# 	Loss: 31.148050
# Iter. 17641 (of 30000)
# 	Loss: 27.856995
# Iter. 17642 (of 30000)
# 	Loss: 44.012043
# Iter. 17643 (of 30000)
# 	Loss: 47.026482
# Iter. 17644 (of 30000)
# 	Loss: 36.671844
# Iter. 17645 (of 30000)
# 	Loss: 46.143314
# Iter. 17646 (of 30000)
# 	Loss: 35.043606
# Iter. 17647 (of 30000)
# 	Loss: 31.176634
# Iter. 17648 (of 30000)
# 	Loss: 37.034882
# Iter. 17649 (of 30000)
# 	Loss: 29.581856
# Iter. 17650 (of 30000)
# 	Loss: 32.990360
# Iter. 17651 (of 30000)
# 	Loss: 36.421219
# Iter. 17652 (of 30000)
# 	Loss: 32.232422
# Iter. 17653 (of 30000)
# 	Loss: 35.029442
# Iter. 17654 (of 30000)
# 	Loss: 33.110218
# Iter. 17655 (of 30000)
# 	Loss: 32.918465
# Iter. 17656 (of 30000)
# 	Loss: 33.832378
# Iter. 17657 (of 30000)
# 	Loss: 35.743858
# Iter. 17658 (of 30000)
# 	Loss: 39.359531
# Iter. 17659 (of 30000)
# 	Loss: 35.556496
# Iter. 17660 (of 30000)
# 	Loss: 37.277523
# Iter. 17661 (of 30000)
# 	Loss: 34.007607
# Iter. 17662 (of 30000)
# 	Loss: 32.081154
# Iter. 17663 (of 30000)
# 	Loss: 29.774845
# Iter. 17664 (of 30000)
# 	Loss: 31.542183
# Iter. 17665 (of 30000)
# 	Loss: 31.636734
# Iter. 17666 (of 30000)
# 	Loss: 38.604622
# Iter. 17667 (of 30000)
# 	Loss: 34.773666
# Iter. 17668 (of 30000)
# 	Loss: 37.316864
# Iter. 17669 (of 30000)
# 	Loss: 35.009766
# Iter. 17670 (of 30000)
# 	Loss: 37.459850
# Iter. 17671 (of 30000)
# 	Loss: 34.148941
# Iter. 17672 (of 30000)
# 	Loss: 31.889126
# Iter. 17673 (of 30000)
# 	Loss: 29.026115
# Iter. 17674 (of 30000)
# 	Loss: 37.626575
# Iter. 17675 (of 30000)
# 	Loss: 36.505783
# Iter. 17676 (of 30000)
# 	Loss: 30.056530
# Iter. 17677 (of 30000)
# 	Loss: 32.829372
# Iter. 17678 (of 30000)
# 	Loss: 35.828461
# Iter. 17679 (of 30000)
# 	Loss: 32.808296
# Iter. 17680 (of 30000)
# 	Loss: 31.834965
# Iter. 17681 (of 30000)
# 	Loss: 30.233351
# Iter. 17682 (of 30000)
# 	Loss: 32.174202
# Iter. 17683 (of 30000)
# 	Loss: 36.548355
# Iter. 17684 (of 30000)
# 	Loss: 36.321823
# Iter. 17685 (of 30000)
# 	Loss: 29.535324
# Iter. 17686 (of 30000)
# 	Loss: 34.243340
# Iter. 17687 (of 30000)
# 	Loss: 30.492748
# Iter. 17688 (of 30000)
# 	Loss: 32.275154
# Iter. 17689 (of 30000)
# 	Loss: 32.857445
# Iter. 17690 (of 30000)
# 	Loss: 34.579025
# Iter. 17691 (of 30000)
# 	Loss: 31.185698
# Iter. 17692 (of 30000)
# 	Loss: 34.230762
# Iter. 17693 (of 30000)
# 	Loss: 34.312786
# Iter. 17694 (of 30000)
# 	Loss: 31.615372
# Iter. 17695 (of 30000)
# 	Loss: 39.060379
# Iter. 17696 (of 30000)
# 	Loss: 37.796753
# Iter. 17697 (of 30000)
# 	Loss: 34.476543
# Iter. 17698 (of 30000)
# 	Loss: 27.102325
# Iter. 17699 (of 30000)
# 	Loss: 29.273653
# Iter. 17700 (of 30000)
# 	Loss: 32.455666
# Iter. 17701 (of 30000)
# 	Loss: 29.356184
# Iter. 17702 (of 30000)
# 	Loss: 35.757080
# Iter. 17703 (of 30000)
# 	Loss: 32.895306
# Iter. 17704 (of 30000)
# 	Loss: 32.530785
# Iter. 17705 (of 30000)
# 	Loss: 28.444485
# Iter. 17706 (of 30000)
# 	Loss: 32.419334
# Iter. 17707 (of 30000)
# 	Loss: 33.864887
# Iter. 17708 (of 30000)
# 	Loss: 36.548836
# Iter. 17709 (of 30000)
# 	Loss: 32.442104
# Iter. 17710 (of 30000)
# 	Loss: 38.216652
# Iter. 17711 (of 30000)
# 	Loss: 32.160557
# Iter. 17712 (of 30000)
# 	Loss: 33.748573
# Iter. 17713 (of 30000)
# 	Loss: 28.042753
# Iter. 17714 (of 30000)
# 	Loss: 38.904438
# Iter. 17715 (of 30000)
# 	Loss: 31.385601
# Iter. 17716 (of 30000)
# 	Loss: 33.593506
# Iter. 17717 (of 30000)
# 	Loss: 35.541260
# Iter. 17718 (of 30000)
# 	Loss: 36.340546
# Iter. 17719 (of 30000)
# 	Loss: 33.950611
# Iter. 17720 (of 30000)
# 	Loss: 34.263191
# Iter. 17721 (of 30000)
# 	Loss: 38.096146
# Iter. 17722 (of 30000)
# 	Loss: 30.320694
# Iter. 17723 (of 30000)
# 	Loss: 42.563210
# Iter. 17724 (of 30000)
# 	Loss: 33.659378
# Iter. 17725 (of 30000)
# 	Loss: 36.175205
# Iter. 17726 (of 30000)
# 	Loss: 33.674854
# Iter. 17727 (of 30000)
# 	Loss: 33.098114
# Iter. 17728 (of 30000)
# 	Loss: 34.804310
# Iter. 17729 (of 30000)
# 	Loss: 32.976639
# Iter. 17730 (of 30000)
# 	Loss: 37.551918
# Iter. 17731 (of 30000)
# 	Loss: 28.981092
# Iter. 17732 (of 30000)
# 	Loss: 32.952877
# Iter. 17733 (of 30000)
# 	Loss: 35.153976
# Iter. 17734 (of 30000)
# 	Loss: 31.075247
# Iter. 17735 (of 30000)
# 	Loss: 36.147667
# Iter. 17736 (of 30000)
# 	Loss: 37.263851
# Iter. 17737 (of 30000)
# 	Loss: 34.192917
# Iter. 17738 (of 30000)
# 	Loss: 28.338903
# Iter. 17739 (of 30000)
# 	Loss: 37.820656
# Iter. 17740 (of 30000)
# 	Loss: 33.147095
# Iter. 17741 (of 30000)
# 	Loss: 30.328014
# Iter. 17742 (of 30000)
# 	Loss: 31.478075
# Iter. 17743 (of 30000)
# 	Loss: 30.932011
# Iter. 17744 (of 30000)
# 	Loss: 30.571575
# Iter. 17745 (of 30000)
# 	Loss: 32.802879
# Iter. 17746 (of 30000)
# 	Loss: 35.402245
# Iter. 17747 (of 30000)
# 	Loss: 34.670547
# Iter. 17748 (of 30000)
# 	Loss: 33.690880
# Iter. 17749 (of 30000)
# 	Loss: 31.661726
# Iter. 17750 (of 30000)
# 	Loss: 32.669151
# Iter. 17751 (of 30000)
# 	Loss: 25.694920
# Iter. 17752 (of 30000)
# 	Loss: 31.592148
# Iter. 17753 (of 30000)
# 	Loss: 36.559509
# Iter. 17754 (of 30000)
# 	Loss: 28.858910
# Iter. 17755 (of 30000)
# 	Loss: 32.281113
# Iter. 17756 (of 30000)
# 	Loss: 35.441292
# Iter. 17757 (of 30000)
# 	Loss: 30.737656
# Iter. 17758 (of 30000)
# 	Loss: 37.150791
# Iter. 17759 (of 30000)
# 	Loss: 34.507923
# Iter. 17760 (of 30000)
# 	Loss: 31.370045
# Iter. 17761 (of 30000)
# 	Loss: 33.389862
# Iter. 17762 (of 30000)
# 	Loss: 37.754768
# Iter. 17763 (of 30000)
# 	Loss: 41.151253
# Iter. 17764 (of 30000)
# 	Loss: 34.222710
# Iter. 17765 (of 30000)
# 	Loss: 30.310970
# Iter. 17766 (of 30000)
# 	Loss: 38.476139
# Iter. 17767 (of 30000)
# 	Loss: 35.082794
# Iter. 17768 (of 30000)
# 	Loss: 35.618584
# Iter. 17769 (of 30000)
# 	Loss: 36.829750
# Iter. 17770 (of 30000)
# 	Loss: 30.485685
# Iter. 17771 (of 30000)
# 	Loss: 34.218327
# Iter. 17772 (of 30000)
# 	Loss: 40.921219
# Iter. 17773 (of 30000)
# 	Loss: 36.820023
# Iter. 17774 (of 30000)
# 	Loss: 41.426826
# Iter. 17775 (of 30000)
# 	Loss: 28.254133
# Iter. 17776 (of 30000)
# 	Loss: 30.698307
# Iter. 17777 (of 30000)
# 	Loss: 39.619987
# Iter. 17778 (of 30000)
# 	Loss: 32.766567
# Iter. 17779 (of 30000)
# 	Loss: 38.668144
# Iter. 17780 (of 30000)
# 	Loss: 33.532761
# Iter. 17781 (of 30000)
# 	Loss: 31.314281
# Iter. 17888 (of 30000)
# 	Loss: 33.499588
# Iter. 17889 (of 30000)
# 	Loss: 30.082748
# Iter. 17890 (of 30000)
# 	Loss: 33.000092
# Iter. 17891 (of 30000)
# 	Loss: 32.770309
# Iter. 17892 (of 30000)
# 	Loss: 32.438560
# Iter. 17893 (of 30000)
# 	Loss: 33.300274
# Iter. 17894 (of 30000)
# 	Loss: 31.138786
# Iter. 17895 (of 30000)
# 	Loss: 41.758423
# Iter. 17896 (of 30000)
# 	Loss: 35.945122
# Iter. 17897 (of 30000)
# 	Loss: 32.601601
# Iter. 17898 (of 30000)
# 	Loss: 34.356838
# Iter. 17899 (of 30000)
# 	Loss: 31.297918
# Iter. 17900 (of 30000)
# 	Loss: 35.380009
# Iter. 17901 (of 30000)
# 	Loss: 34.191978
# Iter. 17902 (of 30000)
# 	Loss: 35.202801
# Iter. 17903 (of 30000)
# 	Loss: 32.988045
# Iter. 17904 (of 30000)
# 	Loss: 39.356800
# Iter. 17905 (of 30000)
# 	Loss: 34.486809
# Iter. 17906 (of 30000)
# 	Loss: 33.723557
# Iter. 17907 (of 30000)
# 	Loss: 37.281082
# Iter. 17908 (of 30000)
# 	Loss: 30.391720
# Iter. 17909 (of 30000)
# 	Loss: 36.312153
# Iter. 17910 (of 30000)
# Traceback (most recent call last):
#   File "train-detector.py", line 111, in <module>
#     Xtrain,Ytrain = dg.get_batch(batch_size)
#   File "/content/alpr-unconstrained/src/data_generator.py", line 95, in get_batch
#     X[i] = self._X[idx]
# KeyboardInterrupt

# %%
import threading

def printit():
  threading.Timer(10000000, printit).start()
  print("Hello, World!")

printit()
# Out:
# Hello, World!

# %%
# !bash get-networks.sh
# Out:
# --2020-03-21 12:16:19--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/lp-detector/wpod-net_update1.h5
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/lp-detector/wpod-net_update1.h5’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:19--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/lp-detector/wpod-net_update1.json
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/lp-detector/wpod-net_update1.json’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:20--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/ocr/ocr-net.cfg
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/ocr/ocr-net.cfg’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:20--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/ocr/ocr-net.names
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/ocr/ocr-net.names’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:21--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/ocr/ocr-net.weights
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/ocr/ocr-net.weights’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:21--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/ocr/ocr-net.data
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/ocr/ocr-net.data’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:22--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/vehicle-detector/yolo-voc.cfg
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/vehicle-detector/yolo-voc.cfg’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:22--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/vehicle-detector/voc.data
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/vehicle-detector/voc.data’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:23--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/vehicle-detector/yolo-voc.weights
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/vehicle-detector/yolo-voc.weights’ not modified on server. Omitting download.
#
# --2020-03-21 12:16:23--  http://www.inf.ufrgs.br/~smsilva/alpr-unconstrained/data/vehicle-detector/voc.names
# Resolving www.inf.ufrgs.br (www.inf.ufrgs.br)... 143.54.11.34
# Connecting to www.inf.ufrgs.br (www.inf.ufrgs.br)|143.54.11.34|:80... connected.
# HTTP request sent, awaiting response... 304 Not Modified
# File ‘data/vehicle-detector/voc.names’ not modified on server. Omitting download.

# %%
# !bash run.sh -i /content/alpr-unconstrained/samples/training_samples -o /content/alpr-unconstrained/samples/Test -c /content/alpr-unconstrained/samples/Test/results.csv
# Out:
# Traceback (most recent call last):
#   File "vehicle-detection.py", line 28, in <module>
#     vehicle_net  = dn.load_net(vehicle_netcfg, vehicle_weights, 0)
# ctypes.ArgumentError: argument 1: <class 'TypeError'>: wrong type

# %%
for i in range(1,8):
  time.sleep(300)
  print(str(i*5)+"Mins have elapsed")
# Out:
# 5Mins have elapsed
# 10Mins have elapsed
# 15Mins have elapsed
# 20Mins have elapsed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-bebc3dded033> in <module>()
#       1 for i in range(1,8):
# ----> 2   time.sleep(300)
#       3   print(str(i*5)+"Mins have elapsed")
#
# KeyboardInterrupt:

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.12.0)

# %%
images_path = os.listdir("/content/alpr-unconstrained/samples/training_samples/")
imgs_arr = []
for i in range(0,10):
  imgs_arr.append(cv2.imread(images_path[i]))

# %%
for img in imgs_arr:
  x = loaded_model.predict(img,steps = 3)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-59-0cff2c2c1b71> in <module>()
#       1 for img in imgs_arr:
# ----> 2   x = loaded_model.predict(img,steps = 3)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1399                                             verbose=verbose,
#    1400                                             steps=steps,
# -> 1401                                             callbacks=callbacks)
#    1402
#    1403     def train_on_batch(self, x, y,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     296             batch_logs = {'batch': step, 'size': 1}
#     297             callbacks._call_batch_hook('predict', 'begin', step, batch_logs)
# --> 298             batch_outs = f(ins)
#     299             batch_outs = to_list(batch_outs)
#     300             if step == 0:
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /tensorflow-1.15.0/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'input_2' with dtype float and shape [?,?,?,3]
# 	 [[{{node input_2}}]]

# %%
from google.colab import auth
auth.authenticate_user()
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')
from googleapiclient.http import MediaFileUpload

file_metadata = {'name': 'my-trained-model_backup.h5'}

media = MediaFileUpload('/content/alpr-unconstrained/models/my-trained-model/my-trained-model_backup.h5', resumable=True)
created = drive_service.files().create(body=file_metadata,
media_body=media,
fields='id').execute()
print('File ID: {}'.format(created.get('id')))
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-14-b7b09680aad2> in <module>()
#       7 file_metadata = {'name': 'east_icdar2015_resnet_v1_50_rbox'}
#       8
# ----> 9 media = MediaFileUpload('/content/east_icdar2015_resnet_v1_50_rbox', resumable=True)
#      10 created = drive_service.files().create(body=file_metadata,
#      11 media_body=media,
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/http.py in __init__(self, filename, mimetype, chunksize, resumable)
#     564     """
#     565         self._filename = filename
# --> 566         fd = open(self._filename, "rb")
#     567         if mimetype is None:
#     568             # No mimetype provided, make a guess.
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/east_icdar2015_resnet_v1_50_rbox'

# %% [markdown]
# #East

# %%
# !git clone https://github.com/argman/EAST/
# Out:
# Cloning into 'EAST'...
# remote: Enumerating objects: 270, done.
# remote: Total 270 (delta 0), reused 0 (delta 0), pack-reused 270
# Receiving objects: 100% (270/270), 2.00 MiB | 1.42 MiB/s, done.
# Resolving deltas: 100% (127/127), done.

# %%
# %cd EAST/
# Out:
# /content/EAST

# %%
file_id = '199vZ9xEur4XSoeFR1TkYS1oxcodJAbW1'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile("weights.zip")

# %%
import os
os.getcwd()
# Out:
# '/content/EAST'

# %%
# !unzip weights.zip
# Out:
# Archive:  weights.zip
#   inflating: east_icdar2015_resnet_v1_50_rbox/checkpoint
#   inflating: east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491.data-00000-of-00001
#   inflating: east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491.index
#   inflating: east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491.meta

# %%
# !unzip weights.zip

# %%
#!rm /tmp/east_icdar2015_resnet_v1_50_rbox/*
# !cp /content/EAST/east_icdar2015_resnet_v1_50_rbox/checkpoint /content/EAST/east_icdar2015_resnet_v1_50_rbox
# Out:
# rm: cannot remove '/tmp/east_icdar2015_resnet_v1_50_rbox/*': No such file or directory
# cp: -r not specified; omitting directory '/content/EAST/east_icdar2015_resnet_v1_50_rbox/checkpoint'

# %%
# !rm /content/EAST/training_samples/*
# Out:
# rm: cannot remove '/content/EAST/training_samples/*': No such file or directory

# %%
# !mv /content/EAST/real_Image_dataset_Detection/Image/*.jpg  /content/EAST/training_samples/
# !mv /content/EAST/real_Image_dataset_Detection/Annotation/*.txt  /content/EAST/training_samples/
# Out:
# mv: cannot stat '/content/EAST/real_Image_dataset_Detection/Image/*.jpg': No such file or directory

# %%
os.chdir('/content/EAST')

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !python multigpu_train.py --gpu_list=0 --input_size=512 --batch_size_per_gpu=14 --checkpoint_path=/content/EAST/east_icdar2015_resnet_v1_50_rbox \
--text_scale=512 --training_data_path=/content/EAST/training_samples --geometry=RBOX --learning_rate=0.0001 --num_readers=1 \
--pretrained_model_path=/content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From multigpu_train.py:180: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From multigpu_train.py:72: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0322 10:08:29.076056 139751079544704 module_wrapper.py:139] From multigpu_train.py:72: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From multigpu_train.py:76: The name tf.gfile.DeleteRecursively is deprecated. Please use tf.io.gfile.rmtree instead.
#
# W0322 10:08:29.076313 139751079544704 module_wrapper.py:139] From multigpu_train.py:76: The name tf.gfile.DeleteRecursively is deprecated. Please use tf.io.gfile.rmtree instead.
#
# WARNING:tensorflow:From multigpu_train.py:77: The name tf.gfile.MkDir is deprecated. Please use tf.io.gfile.mkdir instead.
#
# W0322 10:08:29.078236 139751079544704 module_wrapper.py:139] From multigpu_train.py:77: The name tf.gfile.MkDir is deprecated. Please use tf.io.gfile.mkdir instead.
#
# WARNING:tensorflow:From multigpu_train.py:79: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0322 10:08:29.078501 139751079544704 module_wrapper.py:139] From multigpu_train.py:79: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From multigpu_train.py:87: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0322 10:08:29.081941 139751079544704 module_wrapper.py:139] From multigpu_train.py:87: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From multigpu_train.py:88: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# W0322 10:08:29.087133 139751079544704 module_wrapper.py:139] From multigpu_train.py:88: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From multigpu_train.py:90: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# W0322 10:08:29.092576 139751079544704 module_wrapper.py:139] From multigpu_train.py:90: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From multigpu_train.py:91: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0322 10:08:29.095465 139751079544704 module_wrapper.py:139] From multigpu_train.py:91: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From multigpu_train.py:29: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0322 10:08:29.101879 139751079544704 module_wrapper.py:139] From multigpu_train.py:29: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From multigpu_train.py:29: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# W0322 10:08:29.102059 139751079544704 module_wrapper.py:139] From multigpu_train.py:29: The name tf.get_variable_scope is deprecated. Please use tf.compat.v1.get_variable_scope instead.
#
# WARNING:tensorflow:From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0322 10:08:29.108022 139751079544704 module_wrapper.py:139] From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0322 10:08:29.112128 139751079544704 deprecation.py:323] From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# resnet_v1_50/block1 (?, ?, ?, 256)
# resnet_v1_50/block2 (?, ?, ?, 512)
# resnet_v1_50/block3 (?, ?, ?, 1024)
# resnet_v1_50/block4 (?, ?, ?, 2048)
# Shape of f_0 (?, ?, ?, 2048)
# Shape of f_1 (?, ?, ?, 512)
# Shape of f_2 (?, ?, ?, 256)
# Shape of f_3 (?, ?, ?, 64)
# WARNING:tensorflow:From /content/EAST/model.py:14: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
#
iB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# Step 000000, model loss 0.1549, total loss 0.1566, 2.71 seconds/step, 5.17 examples/second
# Step 000010, model loss 0.1724, total loss 0.1741, 19.24 seconds/step, 0.73 examples/second
# invalid poly
# Step 000020, model loss 0.1390, total loss 0.1407, 18.00 seconds/step, 0.78 examples/second
# Step 000030, model loss 0.1714, total loss 0.1731, 18.71 seconds/step, 0.75 examples/second
# invalid poly
# Step 000040, model loss 0.1311, total loss 0.1328, 19.22 seconds/step, 0.73 examples/second
# invalid poly
# Step 000050, model loss 0.1471, total loss 0.1488, 20.44 seconds/step, 0.69 examples/second
# Step 000060, model loss 0.1558, total loss 0.1575, 20.60 seconds/step, 0.68 examples/second
# Step 000070, model loss 0.1215, total loss 0.1232, 20.55 seconds/step, 0.68 examples/second
# Step 000080, model loss 0.0993, total loss 0.1010, 16.91 seconds/step, 0.83 examples/second
# invalid poly
# Step 000090, model loss 0.1393, total loss 0.1411, 18.86 seconds/step, 0.74 examples/second

# %%
# !cp /content/east_icdar2015_resnet_v1_50_rbox/checkpoint /tmp/east_icdar2015_resnet_v1_50_rbox/

# %%
# %%writefile multigpu_train.py

from tqdm import tqdm
import time
import numpy as np
import tensorflow as tf
from tensorflow.contrib import slim

tf.app.flags.DEFINE_integer('input_size', 512, '')
tf.app.flags.DEFINE_integer('batch_size_per_gpu', 14, '')
tf.app.flags.DEFINE_integer('num_readers', 16, '')
tf.app.flags.DEFINE_float('learning_rate', 0.0001, '')
tf.app.flags.DEFINE_integer('max_steps', 100000, '')
tf.app.flags.DEFINE_float('moving_average_decay', 0.997, '')
tf.app.flags.DEFINE_string('gpu_list', '1', '')
tf.app.flags.DEFINE_string('checkpoint_path', '/tmp/east_resnet_v1_50_rbox/', '')
tf.app.flags.DEFINE_boolean('restore', False, 'whether to resotre from checkpoint')
tf.app.flags.DEFINE_integer('save_checkpoint_steps', 50, '')
tf.app.flags.DEFINE_integer('save_summary_steps', 100, '')
tf.app.flags.DEFINE_string('pretrained_model_path', None, '')

import model
import icdar

FLAGS = tf.app.flags.FLAGS

gpus = list(range(len(FLAGS.gpu_list.split(','))))


def tower_loss(images, score_maps, geo_maps, training_masks, reuse_variables=None):
    # Build inference graph
    with tf.variable_scope(tf.get_variable_scope(), reuse=reuse_variables):
        f_score, f_geometry = model.model(images, is_training=True)

    model_loss = model.loss(score_maps, f_score,
                            geo_maps, f_geometry,
                            training_masks)
    total_loss = tf.add_n([model_loss] + tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES))

    # add summary
    if reuse_variables is None:
        tf.summary.image('input', images)
        tf.summary.image('score_map', score_maps)
        tf.summary.image('score_map_pred', f_score * 255)
        tf.summary.image('geo_map_0', geo_maps[:, :, :, 0:1])
        tf.summary.image('geo_map_0_pred', f_geometry[:, :, :, 0:1])
        tf.summary.image('training_masks', training_masks)
        tf.summary.scalar('model_loss', model_loss)
        tf.summary.scalar('total_loss', total_loss)

    return total_loss, model_loss


def average_gradients(tower_grads):
    average_grads = []
    for grad_and_vars in zip(*tower_grads):
        grads = []
        for g, _ in grad_and_vars:
            expanded_g = tf.expand_dims(g, 0)
            grads.append(expanded_g)

        grad = tf.concat(grads, 0)
        grad = tf.reduce_mean(grad, 0)

        v = grad_and_vars[0][1]
        grad_and_var = (grad, v)
        average_grads.append(grad_and_var)

    return average_grads


def main(argv=None):
    import os
    os.environ['CUDA_VISIBLE_DEVICES'] = FLAGS.gpu_list
    if not tf.gfile.Exists(FLAGS.checkpoint_path):
        tf.gfile.MkDir(FLAGS.checkpoint_path)
    else:
        if not FLAGS.restore:
            tf.gfile.DeleteRecursively(FLAGS.checkpoint_path)
            tf.gfile.MkDir(FLAGS.checkpoint_path)

    input_images = tf.placeholder(tf.float32, shape=[None, None, None, 3], name='input_images')
    input_score_maps = tf.placeholder(tf.float32, shape=[None, None, None, 1], name='input_score_maps')
    if FLAGS.geometry == 'RBOX':
        input_geo_maps = tf.placeholder(tf.float32, shape=[None, None, None, 5], name='input_geo_maps')
    else:
        input_geo_maps = tf.placeholder(tf.float32, shape=[None, None, None, 8], name='input_geo_maps')
    input_training_masks = tf.placeholder(tf.float32, shape=[None, None, None, 1], name='input_training_masks')

    global_step = tf.get_variable('global_step', [], initializer=tf.constant_initializer(0), trainable=False)
    learning_rate = tf.train.exponential_decay(FLAGS.learning_rate, global_step, decay_steps=10000, decay_rate=0.94, staircase=True)
    # add summary
    tf.summary.scalar('learning_rate', learning_rate)
    opt = tf.train.AdamOptimizer(learning_rate)
    # opt = tf.train.MomentumOptimizer(learning_rate, 0.9)


    # split
    input_images_split = tf.split(input_images, len(gpus))
    input_score_maps_split = tf.split(input_score_maps, len(gpus))
    input_geo_maps_split = tf.split(input_geo_maps, len(gpus))
    input_training_masks_split = tf.split(input_training_masks, len(gpus))

    tower_grads = []
    reuse_variables = None
    for i, gpu_id in enumerate(gpus):
        with tf.device('/gpu:%d' % gpu_id):
            with tf.name_scope('model_%d' % gpu_id) as scope:
                iis = input_images_split[i]
                isms = input_score_maps_split[i]
                igms = input_geo_maps_split[i]
                itms = input_training_masks_split[i]
                total_loss, model_loss = tower_loss(iis, isms, igms, itms, reuse_variables)
                batch_norm_updates_op = tf.group(*tf.get_collection(tf.GraphKeys.UPDATE_OPS, scope))
                reuse_variables = True

                grads = opt.compute_gradients(total_loss)
                tower_grads.append(grads)

    grads = average_gradients(tower_grads)
    apply_gradient_op = opt.apply_gradients(grads, global_step=global_step)

    summary_op = tf.summary.merge_all()
    # save moving average
    variable_averages = tf.train.ExponentialMovingAverage(
        FLAGS.moving_average_decay, global_step)
    variables_averages_op = variable_averages.apply(tf.trainable_variables())
    # batch norm updates
    with tf.control_dependencies([variables_averages_op, apply_gradient_op, batch_norm_updates_op]):
        train_op = tf.no_op(name='train_op')

    saver = tf.train.Saver(tf.global_variables())
    summary_writer = tf.summary.FileWriter(FLAGS.checkpoint_path, tf.get_default_graph())

    init = tf.global_variables_initializer()

    if FLAGS.pretrained_model_path is not None:
        variable_restore_op = slim.assign_from_checkpoint_fn(FLAGS.pretrained_model_path, slim.get_trainable_variables(),
                                                             ignore_missing_vars=True)
    with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as sess:
        if FLAGS.restore:
            print('continue training from previous checkpoint')
            print(FLAGS.checkpoint_path)
            ckpt = tf.train.latest_checkpoint(FLAGS.checkpoint_path)
            saver.restore(sess, ckpt)
        else:
            sess.run(init)
            if FLAGS.pretrained_model_path is not None:
                variable_restore_op(sess)

        data_generator = icdar.get_batch(num_workers=FLAGS.num_readers,
                                         input_size=FLAGS.input_size,
                                         batch_size=FLAGS.batch_size_per_gpu * len(gpus))

        start = time.time()
        for step in tqdm(range(FLAGS.max_steps)):
            data = next(data_generator)
            ml, tl, _ = sess.run([model_loss, total_loss, train_op], feed_dict={input_images: data[0],
                                                                                input_score_maps: data[2],
                                                                                input_geo_maps: data[3],
                                                                                input_training_masks: data[4]})
            if np.isnan(tl):
                print('Loss diverged, stop training')
                break

            if step % 10 == 0:
                avg_time_per_step = (time.time() - start)/10
                avg_examples_per_second = (10 * FLAGS.batch_size_per_gpu * len(gpus))/(time.time() - start)
                start = time.time()
                print('Step {:06d}, model loss {:.4f}, total loss {:.4f}, {:.2f} seconds/step, {:.2f} examples/second'.format(
                    step, ml, tl, avg_time_per_step, avg_examples_per_second))

            if step % FLAGS.save_checkpoint_steps == 0:
                saver.save(sess, FLAGS.checkpoint_path + 'model.ckpt', global_step=global_step)

            if step % FLAGS.save_summary_steps == 0:
                _, tl, summary_str = sess.run([train_op, total_loss, summary_op], feed_dict={input_images: data[0],
                                                                                             input_score_maps: data[2],
                                                                                             input_geo_maps: data[3],
                                                                                             input_training_masks: data[4]})
                summary_writer.add_summary(summary_str, global_step=step)

if __name__ == '__main__':
    tf.app.run()
# Out:
# Overwriting multigpu_train.py

# %%
# %%writefile icdar.py

# coding:utf-8
import glob
import csv
import cv2
import time
import os
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
import matplotlib.patches as Patches
from shapely.geometry import Polygon

import tensorflow as tf

from data_util import GeneratorEnqueuer

tf.app.flags.DEFINE_string('training_data_path', '/data/ocr/icdar2015/',
                           'training dataset to use')
tf.app.flags.DEFINE_integer('max_image_large_side', 1280,
                            'max image size of training')
tf.app.flags.DEFINE_integer('max_text_size', 800,
                            'if the text in the input image is bigger than this, then we resize'
                            'the image according to this')
tf.app.flags.DEFINE_integer('min_text_size', 10,
                            'if the text size is smaller than this, we ignore it during training')
tf.app.flags.DEFINE_float('min_crop_side_ratio', 0.1,
                          'when doing random crop from input image, the'
                          'min length of min(H, W')
tf.app.flags.DEFINE_string('geometry', 'RBOX',
                           'which geometry to generate, RBOX or QUAD')


FLAGS = tf.app.flags.FLAGS


def get_images():
    files = []
    for ext in ['jpg', 'png', 'jpeg', 'JPG']:
        files.extend(glob.glob(
            os.path.join(FLAGS.training_data_path, '*.{}'.format(ext))))
    return files


def load_annoataion(p):
    '''
    load annotation from the text file
    :param p:
    :return:
    '''
    text_polys = []
    text_tags = []
    if not os.path.exists(p):
        return np.array(text_polys, dtype=np.float32)
    with open(p, 'r') as f:
        reader = csv.reader(f)
        for line in reader:
            label = line[-1]
            # strip BOM. \ufeff for python3,  \xef\xbb\bf for python2
            line = [i.strip('\ufeff').strip('\xef\xbb\xbf') for i in line]

            x1, y1, x2, y2, x3, y3, x4, y4 = list(map(float, line[:8]))
            text_polys.append([[x1, y1], [x2, y2], [x3, y3], [x4, y4]])
            if label == '*' or label == '###':
                text_tags.append(True)
            else:
                text_tags.append(False)
        return np.array(text_polys, dtype=np.float32), np.array(text_tags, dtype=np.bool)


def polygon_area(poly):
    '''
    compute area of a polygon
    :param poly:
    :return:
    '''
    edge = [
        (poly[1][0] - poly[0][0]) * (poly[1][1] + poly[0][1]),
        (poly[2][0] - poly[1][0]) * (poly[2][1] + poly[1][1]),
        (poly[3][0] - poly[2][0]) * (poly[3][1] + poly[2][1]),
        (poly[0][0] - poly[3][0]) * (poly[0][1] + poly[3][1])
    ]
    return np.sum(edge)/2.


def check_and_validate_polys(polys, tags, xxx_todo_changeme):
    '''
    check so that the text poly is in the same direction,
    and also filter some invalid polygons
    :param polys:
    :param tags:
    :return:
    '''
    (h, w) = xxx_todo_changeme
    if polys.shape[0] == 0:
        return polys
    polys[:, :, 0] = np.clip(polys[:, :, 0], 0, w-1)
    polys[:, :, 1] = np.clip(polys[:, :, 1], 0, h-1)

    validated_polys = []
    validated_tags = []
    for poly, tag in zip(polys, tags):
        p_area = polygon_area(poly)
        if abs(p_area) < 1:
            # print poly
            print('invalid poly')
            continue
        if p_area > 0:
            #print('poly in wrong direction')
            poly = poly[(0, 3, 2, 1), :]
        validated_polys.append(poly)
        validated_tags.append(tag)
    return np.array(validated_polys), np.array(validated_tags)


def crop_area(im, polys, tags, crop_background=False, max_tries=50):
    '''
    make random crop from the input image
    :param im:
    :param polys:
    :param tags:
    :param crop_background:
    :param max_tries:
    :return:
    '''
    h, w, _ = im.shape
    pad_h = h//10
    pad_w = w//10
    h_array = np.zeros((h + pad_h*2), dtype=np.int32)
    w_array = np.zeros((w + pad_w*2), dtype=np.int32)
    for poly in polys:
        poly = np.round(poly, decimals=0).astype(np.int32)
        minx = np.min(poly[:, 0])
        maxx = np.max(poly[:, 0])
        w_array[minx+pad_w:maxx+pad_w] = 1
        miny = np.min(poly[:, 1])
        maxy = np.max(poly[:, 1])
        h_array[miny+pad_h:maxy+pad_h] = 1
    # ensure the cropped area not across a text
    h_axis = np.where(h_array == 0)[0]
    w_axis = np.where(w_array == 0)[0]
    if len(h_axis) == 0 or len(w_axis) == 0:
        return im, polys, tags
    for i in range(max_tries):
        xx = np.random.choice(w_axis, size=2)
        xmin = np.min(xx) - pad_w
        xmax = np.max(xx) - pad_w
        xmin = np.clip(xmin, 0, w-1)
        xmax = np.clip(xmax, 0, w-1)
        yy = np.random.choice(h_axis, size=2)
        ymin = np.min(yy) - pad_h
        ymax = np.max(yy) - pad_h
        ymin = np.clip(ymin, 0, h-1)
        ymax = np.clip(ymax, 0, h-1)
        if xmax - xmin < FLAGS.min_crop_side_ratio*w or ymax - ymin < FLAGS.min_crop_side_ratio*h:
            # area too small
            continue
        if polys.shape[0] != 0:
            poly_axis_in_area = (polys[:, :, 0] >= xmin) & (polys[:, :, 0] <= xmax) \
                                & (polys[:, :, 1] >= ymin) & (polys[:, :, 1] <= ymax)
            selected_polys = np.where(np.sum(poly_axis_in_area, axis=1) == 4)[0]
        else:
            selected_polys = []
        if len(selected_polys) == 0:
            # no text in this area
            if crop_background:
                return im[ymin:ymax+1, xmin:xmax+1, :], polys[selected_polys], tags[selected_polys]
            else:
                continue
        im = im[ymin:ymax+1, xmin:xmax+1, :]
        polys = polys[selected_polys]
        tags = tags[selected_polys]
        polys[:, :, 0] -= xmin
        polys[:, :, 1] -= ymin
        return im, polys, tags

    return im, polys, tags


def shrink_poly(poly, r):
    '''
    fit a poly inside the origin poly, maybe bugs here...
    used for generate the score map
    :param poly: the text poly
    :param r: r in the paper
    :return: the shrinked poly
    '''
    # shrink ratio
    R = 0.3
    # find the longer pair
    if np.linalg.norm(poly[0] - poly[1]) + np.linalg.norm(poly[2] - poly[3]) > \
                    np.linalg.norm(poly[0] - poly[3]) + np.linalg.norm(poly[1] - poly[2]):
        # first move (p0, p1), (p2, p3), then (p0, p3), (p1, p2)
        ## p0, p1
        theta = np.arctan2((poly[1][1] - poly[0][1]), (poly[1][0] - poly[0][0]))
        poly[0][0] += R * r[0] * np.cos(theta)
        poly[0][1] += R * r[0] * np.sin(theta)
        poly[1][0] -= R * r[1] * np.cos(theta)
        poly[1][1] -= R * r[1] * np.sin(theta)
        ## p2, p3
        theta = np.arctan2((poly[2][1] - poly[3][1]), (poly[2][0] - poly[3][0]))
        poly[3][0] += R * r[3] * np.cos(theta)
        poly[3][1] += R * r[3] * np.sin(theta)
        poly[2][0] -= R * r[2] * np.cos(theta)
        poly[2][1] -= R * r[2] * np.sin(theta)
        ## p0, p3
        theta = np.arctan2((poly[3][0] - poly[0][0]), (poly[3][1] - poly[0][1]))
        poly[0][0] += R * r[0] * np.sin(theta)
        poly[0][1] += R * r[0] * np.cos(theta)
        poly[3][0] -= R * r[3] * np.sin(theta)
        poly[3][1] -= R * r[3] * np.cos(theta)
        ## p1, p2
        theta = np.arctan2((poly[2][0] - poly[1][0]), (poly[2][1] - poly[1][1]))
        poly[1][0] += R * r[1] * np.sin(theta)
        poly[1][1] += R * r[1] * np.cos(theta)
        poly[2][0] -= R * r[2] * np.sin(theta)
        poly[2][1] -= R * r[2] * np.cos(theta)
    else:
        ## p0, p3
        # print poly
        theta = np.arctan2((poly[3][0] - poly[0][0]), (poly[3][1] - poly[0][1]))
        poly[0][0] += R * r[0] * np.sin(theta)
        poly[0][1] += R * r[0] * np.cos(theta)
        poly[3][0] -= R * r[3] * np.sin(theta)
        poly[3][1] -= R * r[3] * np.cos(theta)
        ## p1, p2
        theta = np.arctan2((poly[2][0] - poly[1][0]), (poly[2][1] - poly[1][1]))
        poly[1][0] += R * r[1] * np.sin(theta)
        poly[1][1] += R * r[1] * np.cos(theta)
        poly[2][0] -= R * r[2] * np.sin(theta)
        poly[2][1] -= R * r[2] * np.cos(theta)
        ## p0, p1
        theta = np.arctan2((poly[1][1] - poly[0][1]), (poly[1][0] - poly[0][0]))
        poly[0][0] += R * r[0] * np.cos(theta)
        poly[0][1] += R * r[0] * np.sin(theta)
        poly[1][0] -= R * r[1] * np.cos(theta)
        poly[1][1] -= R * r[1] * np.sin(theta)
        ## p2, p3
        theta = np.arctan2((poly[2][1] - poly[3][1]), (poly[2][0] - poly[3][0]))
        poly[3][0] += R * r[3] * np.cos(theta)
        poly[3][1] += R * r[3] * np.sin(theta)
        poly[2][0] -= R * r[2] * np.cos(theta)
        poly[2][1] -= R * r[2] * np.sin(theta)
    return poly


def point_dist_to_line(p1, p2, p3):
    # compute the distance from p3 to p1-p2
    return np.linalg.norm(np.cross(p2 - p1, p1 - p3)) / np.linalg.norm(p2 - p1)


def fit_line(p1, p2):
    # fit a line ax+by+c = 0
    if p1[0] == p1[1]:
        return [1., 0., -p1[0]]
    else:
        [k, b] = np.polyfit(p1, p2, deg=1)
        return [k, -1., b]


def line_cross_point(line1, line2):
    # line1 0= ax+by+c, compute the cross point of line1 and line2
    if line1[0] != 0 and line1[0] == line2[0]:
        print('Cross point does not exist')
        return None
    if line1[0] == 0 and line2[0] == 0:
        print('Cross point does not exist')
        return None
    if line1[1] == 0:
        x = -line1[2]
        y = line2[0] * x + line2[2]
    elif line2[1] == 0:
        x = -line2[2]
        y = line1[0] * x + line1[2]
    else:
        k1, _, b1 = line1
        k2, _, b2 = line2
        x = -(b1-b2)/(k1-k2)
        y = k1*x + b1
    return np.array([x, y], dtype=np.float32)


def line_verticle(line, point):
    # get the verticle line from line across point
    if line[1] == 0:
        verticle = [0, -1, point[1]]
    else:
        if line[0] == 0:
            verticle = [1, 0, -point[0]]
        else:
            verticle = [-1./line[0], -1, point[1] - (-1/line[0] * point[0])]
    return verticle


def rectangle_from_parallelogram(poly):
    '''
    fit a rectangle from a parallelogram
    :param poly:
    :return:
    '''
    p0, p1, p2, p3 = poly
    angle_p0 = np.arccos(np.dot(p1-p0, p3-p0)/(np.linalg.norm(p0-p1) * np.linalg.norm(p3-p0)))
    if angle_p0 < 0.5 * np.pi:
        if np.linalg.norm(p0 - p1) > np.linalg.norm(p0-p3):
            # p0 and p2
            ## p0
            p2p3 = fit_line([p2[0], p3[0]], [p2[1], p3[1]])
            p2p3_verticle = line_verticle(p2p3, p0)

            new_p3 = line_cross_point(p2p3, p2p3_verticle)
            ## p2
            p0p1 = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
            p0p1_verticle = line_verticle(p0p1, p2)

            new_p1 = line_cross_point(p0p1, p0p1_verticle)
            return np.array([p0, new_p1, p2, new_p3], dtype=np.float32)
        else:
            p1p2 = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
            p1p2_verticle = line_verticle(p1p2, p0)

            new_p1 = line_cross_point(p1p2, p1p2_verticle)
            p0p3 = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
            p0p3_verticle = line_verticle(p0p3, p2)

            new_p3 = line_cross_point(p0p3, p0p3_verticle)
            return np.array([p0, new_p1, p2, new_p3], dtype=np.float32)
    else:
        if np.linalg.norm(p0-p1) > np.linalg.norm(p0-p3):
            # p1 and p3
            ## p1
            p2p3 = fit_line([p2[0], p3[0]], [p2[1], p3[1]])
            p2p3_verticle = line_verticle(p2p3, p1)

            new_p2 = line_cross_point(p2p3, p2p3_verticle)
            ## p3
            p0p1 = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
            p0p1_verticle = line_verticle(p0p1, p3)

            new_p0 = line_cross_point(p0p1, p0p1_verticle)
            return np.array([new_p0, p1, new_p2, p3], dtype=np.float32)
        else:
            p0p3 = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
            p0p3_verticle = line_verticle(p0p3, p1)

            new_p0 = line_cross_point(p0p3, p0p3_verticle)
            p1p2 = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
            p1p2_verticle = line_verticle(p1p2, p3)

            new_p2 = line_cross_point(p1p2, p1p2_verticle)
            return np.array([new_p0, p1, new_p2, p3], dtype=np.float32)


def sort_rectangle(poly):
    # sort the four coordinates of the polygon, points in poly should be sorted clockwise
    # First find the lowest point
    p_lowest = np.argmax(poly[:, 1])
    if np.count_nonzero(poly[:, 1] == poly[p_lowest, 1]) == 2:
        # 底边平行于X轴, 那么p0为左上角 - if the bottom line is parallel to x-axis, then p0 must be the upper-left corner
        p0_index = np.argmin(np.sum(poly, axis=1))
        p1_index = (p0_index + 1) % 4
        p2_index = (p0_index + 2) % 4
        p3_index = (p0_index + 3) % 4
        return poly[[p0_index, p1_index, p2_index, p3_index]], 0.
    else:
        # 找到最低点右边的点 - find the point that sits right to the lowest point
        p_lowest_right = (p_lowest - 1) % 4
        p_lowest_left = (p_lowest + 1) % 4
        angle = np.arctan(-(poly[p_lowest][1] - poly[p_lowest_right][1])/(poly[p_lowest][0] - poly[p_lowest_right][0]))
        # assert angle > 0
        if angle <= 0:
            pass
            #print(angle, poly[p_lowest], poly[p_lowest_right])
        if angle/np.pi * 180 > 45:
            # 这个点为p2 - this point is p2
            p2_index = p_lowest
            p1_index = (p2_index - 1) % 4
            p0_index = (p2_index - 2) % 4
            p3_index = (p2_index + 1) % 4
            return poly[[p0_index, p1_index, p2_index, p3_index]], -(np.pi/2 - angle)
        else:
            # 这个点为p3 - this point is p3
            p3_index = p_lowest
            p0_index = (p3_index + 1) % 4
            p1_index = (p3_index + 2) % 4
            p2_index = (p3_index + 3) % 4
            return poly[[p0_index, p1_index, p2_index, p3_index]], angle


def restore_rectangle_rbox(origin, geometry):
    d = geometry[:, :4]
    angle = geometry[:, 4]
    # for angle > 0
    origin_0 = origin[angle >= 0]
    d_0 = d[angle >= 0]
    angle_0 = angle[angle >= 0]
    if origin_0.shape[0] > 0:
        p = np.array([np.zeros(d_0.shape[0]), -d_0[:, 0] - d_0[:, 2],
                      d_0[:, 1] + d_0[:, 3], -d_0[:, 0] - d_0[:, 2],
                      d_0[:, 1] + d_0[:, 3], np.zeros(d_0.shape[0]),
                      np.zeros(d_0.shape[0]), np.zeros(d_0.shape[0]),
                      d_0[:, 3], -d_0[:, 2]])
        p = p.transpose((1, 0)).reshape((-1, 5, 2))  # N*5*2

        rotate_matrix_x = np.array([np.cos(angle_0), np.sin(angle_0)]).transpose((1, 0))
        rotate_matrix_x = np.repeat(rotate_matrix_x, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))  # N*5*2

        rotate_matrix_y = np.array([-np.sin(angle_0), np.cos(angle_0)]).transpose((1, 0))
        rotate_matrix_y = np.repeat(rotate_matrix_y, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))

        p_rotate_x = np.sum(rotate_matrix_x * p, axis=2)[:, :, np.newaxis]  # N*5*1
        p_rotate_y = np.sum(rotate_matrix_y * p, axis=2)[:, :, np.newaxis]  # N*5*1

        p_rotate = np.concatenate([p_rotate_x, p_rotate_y], axis=2)  # N*5*2

        p3_in_origin = origin_0 - p_rotate[:, 4, :]
        new_p0 = p_rotate[:, 0, :] + p3_in_origin  # N*2
        new_p1 = p_rotate[:, 1, :] + p3_in_origin
        new_p2 = p_rotate[:, 2, :] + p3_in_origin
        new_p3 = p_rotate[:, 3, :] + p3_in_origin

        new_p_0 = np.concatenate([new_p0[:, np.newaxis, :], new_p1[:, np.newaxis, :],
                                  new_p2[:, np.newaxis, :], new_p3[:, np.newaxis, :]], axis=1)  # N*4*2
    else:
        new_p_0 = np.zeros((0, 4, 2))
    # for angle < 0
    origin_1 = origin[angle < 0]
    d_1 = d[angle < 0]
    angle_1 = angle[angle < 0]
    if origin_1.shape[0] > 0:
        p = np.array([-d_1[:, 1] - d_1[:, 3], -d_1[:, 0] - d_1[:, 2],
                      np.zeros(d_1.shape[0]), -d_1[:, 0] - d_1[:, 2],
                      np.zeros(d_1.shape[0]), np.zeros(d_1.shape[0]),
                      -d_1[:, 1] - d_1[:, 3], np.zeros(d_1.shape[0]),
                      -d_1[:, 1], -d_1[:, 2]])
        p = p.transpose((1, 0)).reshape((-1, 5, 2))  # N*5*2

        rotate_matrix_x = np.array([np.cos(-angle_1), -np.sin(-angle_1)]).transpose((1, 0))
        rotate_matrix_x = np.repeat(rotate_matrix_x, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))  # N*5*2

        rotate_matrix_y = np.array([np.sin(-angle_1), np.cos(-angle_1)]).transpose((1, 0))
        rotate_matrix_y = np.repeat(rotate_matrix_y, 5, axis=1).reshape(-1, 2, 5).transpose((0, 2, 1))

        p_rotate_x = np.sum(rotate_matrix_x * p, axis=2)[:, :, np.newaxis]  # N*5*1
        p_rotate_y = np.sum(rotate_matrix_y * p, axis=2)[:, :, np.newaxis]  # N*5*1

        p_rotate = np.concatenate([p_rotate_x, p_rotate_y], axis=2)  # N*5*2

        p3_in_origin = origin_1 - p_rotate[:, 4, :]
        new_p0 = p_rotate[:, 0, :] + p3_in_origin  # N*2
        new_p1 = p_rotate[:, 1, :] + p3_in_origin
        new_p2 = p_rotate[:, 2, :] + p3_in_origin
        new_p3 = p_rotate[:, 3, :] + p3_in_origin

        new_p_1 = np.concatenate([new_p0[:, np.newaxis, :], new_p1[:, np.newaxis, :],
                                  new_p2[:, np.newaxis, :], new_p3[:, np.newaxis, :]], axis=1)  # N*4*2
    else:
        new_p_1 = np.zeros((0, 4, 2))
    return np.concatenate([new_p_0, new_p_1])


def restore_rectangle(origin, geometry):
    return restore_rectangle_rbox(origin, geometry)


def generate_rbox(im_size, polys, tags):
    h, w = im_size
    poly_mask = np.zeros((h, w), dtype=np.uint8)
    score_map = np.zeros((h, w), dtype=np.uint8)
    geo_map = np.zeros((h, w, 5), dtype=np.float32)
    # mask used during traning, to ignore some hard areas
    training_mask = np.ones((h, w), dtype=np.uint8)
    for poly_idx, poly_tag in enumerate(zip(polys, tags)):
        poly = poly_tag[0]
        tag = poly_tag[1]

        r = [None, None, None, None]
        for i in range(4):
            r[i] = min(np.linalg.norm(poly[i] - poly[(i + 1) % 4]),
                       np.linalg.norm(poly[i] - poly[(i - 1) % 4]))
        # score map
        shrinked_poly = shrink_poly(poly.copy(), r).astype(np.int32)[np.newaxis, :, :]
        cv2.fillPoly(score_map, shrinked_poly, 1)
        cv2.fillPoly(poly_mask, shrinked_poly, poly_idx + 1)
        # if the poly is too small, then ignore it during training
        poly_h = min(np.linalg.norm(poly[0] - poly[3]), np.linalg.norm(poly[1] - poly[2]))
        poly_w = min(np.linalg.norm(poly[0] - poly[1]), np.linalg.norm(poly[2] - poly[3]))
        if min(poly_h, poly_w) < FLAGS.min_text_size:
            cv2.fillPoly(training_mask, poly.astype(np.int32)[np.newaxis, :, :], 0)
        if tag:
            cv2.fillPoly(training_mask, poly.astype(np.int32)[np.newaxis, :, :], 0)

        xy_in_poly = np.argwhere(poly_mask == (poly_idx + 1))
        # if geometry == 'RBOX':
        # 对任意两个顶点的组合生成一个平行四边形 - generate a parallelogram for any combination of two vertices
        fitted_parallelograms = []
        for i in range(4):
            p0 = poly[i]
            p1 = poly[(i + 1) % 4]
            p2 = poly[(i + 2) % 4]
            p3 = poly[(i + 3) % 4]
            edge = fit_line([p0[0], p1[0]], [p0[1], p1[1]])
            backward_edge = fit_line([p0[0], p3[0]], [p0[1], p3[1]])
            forward_edge = fit_line([p1[0], p2[0]], [p1[1], p2[1]])
            if point_dist_to_line(p0, p1, p2) > point_dist_to_line(p0, p1, p3):
                # 平行线经过p2 - parallel lines through p2
                if edge[1] == 0:
                    edge_opposite = [1, 0, -p2[0]]
                else:
                    edge_opposite = [edge[0], -1, p2[1] - edge[0] * p2[0]]
            else:
                # 经过p3 - after p3
                if edge[1] == 0:
                    edge_opposite = [1, 0, -p3[0]]
                else:
                    edge_opposite = [edge[0], -1, p3[1] - edge[0] * p3[0]]
            # move forward edge
            new_p0 = p0
            new_p1 = p1
            new_p2 = p2
            new_p3 = p3
            new_p2 = line_cross_point(forward_edge, edge_opposite)
            if point_dist_to_line(p1, new_p2, p0) > point_dist_to_line(p1, new_p2, p3):
                # across p0
                if forward_edge[1] == 0:
                    forward_opposite = [1, 0, -p0[0]]
                else:
                    forward_opposite = [forward_edge[0], -1, p0[1] - forward_edge[0] * p0[0]]
            else:
                # across p3
                if forward_edge[1] == 0:
                    forward_opposite = [1, 0, -p3[0]]
                else:
                    forward_opposite = [forward_edge[0], -1, p3[1] - forward_edge[0] * p3[0]]
            new_p0 = line_cross_point(forward_opposite, edge)
            new_p3 = line_cross_point(forward_opposite, edge_opposite)
            fitted_parallelograms.append([new_p0, new_p1, new_p2, new_p3, new_p0])
            # or move backward edge
            new_p0 = p0
            new_p1 = p1
            new_p2 = p2
            new_p3 = p3
            new_p3 = line_cross_point(backward_edge, edge_opposite)
            if point_dist_to_line(p0, p3, p1) > point_dist_to_line(p0, p3, p2):
                # across p1
                if backward_edge[1] == 0:
                    backward_opposite = [1, 0, -p1[0]]
                else:
                    backward_opposite = [backward_edge[0], -1, p1[1] - backward_edge[0] * p1[0]]
            else:
                # across p2
                if backward_edge[1] == 0:
                    backward_opposite = [1, 0, -p2[0]]
                else:
                    backward_opposite = [backward_edge[0], -1, p2[1] - backward_edge[0] * p2[0]]
            new_p1 = line_cross_point(backward_opposite, edge)
            new_p2 = line_cross_point(backward_opposite, edge_opposite)
            fitted_parallelograms.append([new_p0, new_p1, new_p2, new_p3, new_p0])
        areas = [Polygon(t).area for t in fitted_parallelograms]
        parallelogram = np.array(fitted_parallelograms[np.argmin(areas)][:-1], dtype=np.float32)
        # sort thie polygon
        parallelogram_coord_sum = np.sum(parallelogram, axis=1)
        min_coord_idx = np.argmin(parallelogram_coord_sum)
        parallelogram = parallelogram[
            [min_coord_idx, (min_coord_idx + 1) % 4, (min_coord_idx + 2) % 4, (min_coord_idx + 3) % 4]]

        rectange = rectangle_from_parallelogram(parallelogram)
        rectange, rotate_angle = sort_rectangle(rectange)

        p0_rect, p1_rect, p2_rect, p3_rect = rectange
        for y, x in xy_in_poly:
            point = np.array([x, y], dtype=np.float32)
            # top
            geo_map[y, x, 0] = point_dist_to_line(p0_rect, p1_rect, point)
            # right
            geo_map[y, x, 1] = point_dist_to_line(p1_rect, p2_rect, point)
            # down
            geo_map[y, x, 2] = point_dist_to_line(p2_rect, p3_rect, point)
            # left
            geo_map[y, x, 3] = point_dist_to_line(p3_rect, p0_rect, point)
            # angle
            geo_map[y, x, 4] = rotate_angle
    return score_map, geo_map, training_mask


def generator(input_size=512, batch_size=32,
              background_ratio=3./8,
              random_scale=np.array([0.5, 1, 2.0, 3.0]),
              vis=False):
    image_list = np.array(get_images())
    #print('{} training images in {}'.format(
    #    image_list.shape[0], FLAGS.training_data_path))
    index = np.arange(0, image_list.shape[0])
    while True:
        np.random.shuffle(index)
        images = []
        image_fns = []
        score_maps = []
        geo_maps = []
        training_masks = []
        for i in index:
            try:
                im_fn = image_list[i]
                im = cv2.imread(im_fn)
                # print im_fn
                h, w, _ = im.shape
                txt_fn = im_fn.replace(os.path.basename(im_fn).split('.')[-1], 'txt')
                if not os.path.exists(txt_fn):
                    print(im_fn)
                    print('text file {} does not exists'.format(txt_fn))
                    continue

                text_polys, text_tags = load_annoataion(txt_fn)

                text_polys, text_tags = check_and_validate_polys(text_polys, text_tags, (h, w))
                # if text_polys.shape[0] == 0:
                #     continue
                # random scale this image
                rd_scale = np.random.choice(random_scale)
                im = cv2.resize(im, dsize=None, fx=rd_scale, fy=rd_scale)
                text_polys *= rd_scale
                # print rd_scale
                # random crop a area from image
                if np.random.rand() < background_ratio:
                    # crop background
                    im, text_polys, text_tags = crop_area(im, text_polys, text_tags, crop_background=True)
                    if text_polys.shape[0] > 0:
                        # cannot find background
                        continue
                    # pad and resize image
                    new_h, new_w, _ = im.shape
                    max_h_w_i = np.max([new_h, new_w, input_size])
                    im_padded = np.zeros((max_h_w_i, max_h_w_i, 3), dtype=np.uint8)
                    im_padded[:new_h, :new_w, :] = im.copy()
                    im = cv2.resize(im_padded, dsize=(input_size, input_size))
                    score_map = np.zeros((input_size, input_size), dtype=np.uint8)
                    geo_map_channels = 5 if FLAGS.geometry == 'RBOX' else 8
                    geo_map = np.zeros((input_size, input_size, geo_map_channels), dtype=np.float32)
                    training_mask = np.ones((input_size, input_size), dtype=np.uint8)
                else:
                    im, text_polys, text_tags = crop_area(im, text_polys, text_tags, crop_background=False)
                    if text_polys.shape[0] == 0:
                        continue
                    h, w, _ = im.shape

                    # pad the image to the training input size or the longer side of image
                    new_h, new_w, _ = im.shape
                    max_h_w_i = np.max([new_h, new_w, input_size])
                    im_padded = np.zeros((max_h_w_i, max_h_w_i, 3), dtype=np.uint8)
                    im_padded[:new_h, :new_w, :] = im.copy()
                    im = im_padded
                    # resize the image to input size
                    new_h, new_w, _ = im.shape
                    resize_h = input_size
                    resize_w = input_size
                    im = cv2.resize(im, dsize=(resize_w, resize_h))
                    resize_ratio_3_x = resize_w/float(new_w)
                    resize_ratio_3_y = resize_h/float(new_h)
                    text_polys[:, :, 0] *= resize_ratio_3_x
                    text_polys[:, :, 1] *= resize_ratio_3_y
                    new_h, new_w, _ = im.shape
                    score_map, geo_map, training_mask = generate_rbox((new_h, new_w), text_polys, text_tags)

                if vis:
                    fig, axs = plt.subplots(3, 2, figsize=(20, 30))
                    # axs[0].imshow(im[:, :, ::-1])
                    # axs[0].set_xticks([])
                    # axs[0].set_yticks([])
                    # for poly in text_polys:
                    #     poly_h = min(abs(poly[3, 1] - poly[0, 1]), abs(poly[2, 1] - poly[1, 1]))
                    #     poly_w = min(abs(poly[1, 0] - poly[0, 0]), abs(poly[2, 0] - poly[3, 0]))
                    #     axs[0].add_artist(Patches.Polygon(
                    #         poly * 4, facecolor='none', edgecolor='green', linewidth=2, linestyle='-', fill=True))
                    #     axs[0].text(poly[0, 0] * 4, poly[0, 1] * 4, '{:.0f}-{:.0f}'.format(poly_h * 4, poly_w * 4),
                    #                    color='purple')
                    # axs[1].imshow(score_map)
                    # axs[1].set_xticks([])
                    # axs[1].set_yticks([])
                    axs[0, 0].imshow(im[:, :, ::-1])
                    axs[0, 0].set_xticks([])
                    axs[0, 0].set_yticks([])
                    for poly in text_polys:
                        poly_h = min(abs(poly[3, 1] - poly[0, 1]), abs(poly[2, 1] - poly[1, 1]))
                        poly_w = min(abs(poly[1, 0] - poly[0, 0]), abs(poly[2, 0] - poly[3, 0]))
                        axs[0, 0].add_artist(Patches.Polygon(
                            poly, facecolor='none', edgecolor='green', linewidth=2, linestyle='-', fill=True))
                        axs[0, 0].text(poly[0, 0], poly[0, 1], '{:.0f}-{:.0f}'.format(poly_h, poly_w), color='purple')
                    axs[0, 1].imshow(score_map[::, ::])
                    axs[0, 1].set_xticks([])
                    axs[0, 1].set_yticks([])
                    axs[1, 0].imshow(geo_map[::, ::, 0])
                    axs[1, 0].set_xticks([])
                    axs[1, 0].set_yticks([])
                    axs[1, 1].imshow(geo_map[::, ::, 1])
                    axs[1, 1].set_xticks([])
                    axs[1, 1].set_yticks([])
                    axs[2, 0].imshow(geo_map[::, ::, 2])
                    axs[2, 0].set_xticks([])
                    axs[2, 0].set_yticks([])
                    axs[2, 1].imshow(training_mask[::, ::])
                    axs[2, 1].set_xticks([])
                    axs[2, 1].set_yticks([])
                    plt.tight_layout()
                    plt.show()
                    plt.close()

                images.append(im[:, :, ::-1].astype(np.float32))
                image_fns.append(im_fn)
                score_maps.append(score_map[::4, ::4, np.newaxis].astype(np.float32))
                geo_maps.append(geo_map[::4, ::4, :].astype(np.float32))
                training_masks.append(training_mask[::4, ::4, np.newaxis].astype(np.float32))

                if len(images) == batch_size:
                    yield images, image_fns, score_maps, geo_maps, training_masks
                    images = []
                    image_fns = []
                    score_maps = []
                    geo_maps = []
                    training_masks = []
            except Exception as e:
                import traceback
                traceback.print_exc()
                continue


def get_batch(num_workers, **kwargs):
    #yield generator(**kwargs)
    try:
        enqueuer = GeneratorEnqueuer(generator(**kwargs), use_multiprocessing=True)
        #print('Generator use 10 batches for buffering, this may take a while, you can tune this yourself.')
        enqueuer.start(max_queue_size=10, workers=num_workers)
        generator_output = None
        while True:
            while enqueuer.is_running():
                if not enqueuer.queue.empty():
                    generator_output = enqueuer.queue.get()
                    break
                else:
                    time.sleep(0.01)
            yield generator_output
            generator_output = None
    finally:
        if enqueuer is not None:
            enqueuer.stop()



if __name__ == '__main__':
    pass
# Out:
# Overwriting icdar.py

# %%
# %%writefile /content/EAST/lanms/Makefile
#
# CXXFLAGS = -I include  -std=c++11 -O3 $(shell python3-config --cflags)
# LDFLAGS = $(shell python-config --ldflags)
#
# DEPS = lanms.h $(shell find include -xtype f)
# CXX_SOURCES = adaptor.cpp include/clipper/clipper.cpp
#
# LIB_SO = adaptor.so
#
# $(LIB_SO): $(CXX_SOURCES) $(DEPS)
# 	$(CXX) -o $@ $(CXXFLAGS) $(LDFLAGS) $(CXX_SOURCES) --shared -fPIC
#
# clean:
# 	rm -rf $(LIB_SO)
# Out:
# Overwriting /content/EAST/lanms/Makefile

# %%
# %%writefile eval.py

import cv2
import time
import math
import os
import numpy as np
import tensorflow as tf

import locality_aware_nms as nms_locality
import lanms

tf.app.flags.DEFINE_string('test_data_path', '/tmp/ch4_test_images/images/', '')
tf.app.flags.DEFINE_string('gpu_list', '0', '')
tf.app.flags.DEFINE_string('checkpoint_path', '/tmp/east_icdar2015_resnet_v1_50_rbox/', '')
tf.app.flags.DEFINE_string('output_dir', '/tmp/ch4_test_images/images/', '')
tf.app.flags.DEFINE_bool('no_write_images', False, 'do not write images')

import model
from icdar import restore_rectangle

FLAGS = tf.app.flags.FLAGS

def get_images():
    '''
    find image files in test data path
    :return: list of files found
    '''
    files = []
    exts = ['jpg', 'png', 'jpeg', 'JPG']
    for parent, dirnames, filenames in os.walk(FLAGS.test_data_path):
        for filename in filenames:
            for ext in exts:
                if filename.endswith(ext):
                    files.append(os.path.join(parent, filename))
                    break
    print('Find {} images'.format(len(files)))
    return files


def resize_image(im, max_side_len=2400):
    '''
    resize image to a size multiple of 32 which is required by the network
    :param im: the resized image
    :param max_side_len: limit of max image size to avoid out of memory in gpu
    :return: the resized image and the resize ratio
    '''
    h, w, _ = im.shape

    resize_w = w
    resize_h = h

    # limit the max side
    if max(resize_h, resize_w) > max_side_len:
        ratio = float(max_side_len) / resize_h if resize_h > resize_w else float(max_side_len) / resize_w
    else:
        ratio = 1.
    resize_h = int(resize_h * ratio)
    resize_w = int(resize_w * ratio)

    resize_h = resize_h if resize_h % 32 == 0 else (resize_h // 32 - 1) * 32
    resize_w = resize_w if resize_w % 32 == 0 else (resize_w // 32 - 1) * 32
    resize_h = max(32, resize_h)
    resize_w = max(32, resize_w)
    im = cv2.resize(im, (int(resize_w), int(resize_h)))

    ratio_h = resize_h / float(h)
    ratio_w = resize_w / float(w)

    return im, (ratio_h, ratio_w)


def detect(score_map, geo_map, timer, score_map_thresh=0.8, box_thresh=0.1, nms_thres=0.2):
    '''
    restore text boxes from score map and geo map
    :param score_map:
    :param geo_map:
    :param timer:
    :param score_map_thresh: threshhold for score map
    :param box_thresh: threshhold for boxes
    :param nms_thres: threshold for nms
    :return:
    '''
    if len(score_map.shape) == 4:
        score_map = score_map[0, :, :, 0]
        geo_map = geo_map[0, :, :, ]
    # filter the score map
    xy_text = np.argwhere(score_map > score_map_thresh)
    # sort the text boxes via the y axis
    xy_text = xy_text[np.argsort(xy_text[:, 0])]
    # restore
    start = time.time()
    text_box_restored = restore_rectangle(xy_text[:, ::-1]*4, geo_map[xy_text[:, 0], xy_text[:, 1], :]) # N*4*2
    print('{} text boxes before nms'.format(text_box_restored.shape[0]))
    boxes = np.zeros((text_box_restored.shape[0], 9), dtype=np.float32)
    boxes[:, :8] = text_box_restored.reshape((-1, 8))
    boxes[:, 8] = score_map[xy_text[:, 0], xy_text[:, 1]]
    timer['restore'] = time.time() - start
    # nms part
    start = time.time()
    # boxes = nms_locality.nms_locality(boxes.astype(np.float64), nms_thres)
    #boxes = lanms.merge_quadrangle_n9(boxes.astype('float32'), nms_thres)
    timer['nms'] = time.time() - start

    if boxes.shape[0] == 0:
        return None, timer

    # here we filter some low score boxes by the average score map, this is different from the orginal paper
    for i, box in enumerate(boxes):
        mask = np.zeros_like(score_map, dtype=np.uint8)
        cv2.fillPoly(mask, box[:8].reshape((-1, 4, 2)).astype(np.int32) // 4, 1)
        boxes[i, 8] = cv2.mean(score_map, mask)[0]
    boxes = boxes[boxes[:, 8] > box_thresh]

    return boxes, timer


def sort_poly(p):
    min_axis = np.argmin(np.sum(p, axis=1))
    p = p[[min_axis, (min_axis+1)%4, (min_axis+2)%4, (min_axis+3)%4]]
    if abs(p[0, 0] - p[1, 0]) > abs(p[0, 1] - p[1, 1]):
        return p
    else:
        return p[[0, 3, 2, 1]]


def main(argv=None):
    import os
    os.environ['CUDA_VISIBLE_DEVICES'] = FLAGS.gpu_list


    try:
        os.makedirs(FLAGS.output_dir)
    except OSError as e:
        if e.errno != 17:
            raise

    with tf.get_default_graph().as_default():
        input_images = tf.placeholder(tf.float32, shape=[None, None, None, 3], name='input_images')
        global_step = tf.get_variable('global_step', [], initializer=tf.constant_initializer(0), trainable=False)

        f_score, f_geometry = model.model(input_images, is_training=False)

        variable_averages = tf.train.ExponentialMovingAverage(0.997, global_step)
        saver = tf.train.Saver(variable_averages.variables_to_restore())

        with tf.Session(config=tf.ConfigProto(allow_soft_placement=True)) as sess:
            ckpt_state = tf.train.get_checkpoint_state(FLAGS.checkpoint_path)
            model_path = os.path.join(FLAGS.checkpoint_path, os.path.basename(ckpt_state.model_checkpoint_path))
            print('Restore from {}'.format(model_path))
            saver.restore(sess, model_path)

            im_fn_list = get_images()
            for im_fn in im_fn_list:
                im = cv2.imread(im_fn)[:, :, ::-1]
                start_time = time.time()
                im_resized, (ratio_h, ratio_w) = resize_image(im)

                timer = {'net': 0, 'restore': 0, 'nms': 0}
                start = time.time()
                score, geometry = sess.run([f_score, f_geometry], feed_dict={input_images: [im_resized]})
                timer['net'] = time.time() - start

                boxes, timer = detect(score_map=score, geo_map=geometry, timer=timer)
                print('{} : net {:.0f}ms, restore {:.0f}ms, nms {:.0f}ms'.format(
                    im_fn, timer['net']*1000, timer['restore']*1000, timer['nms']*1000))

                if boxes is not None:
                    boxes = boxes[:, :8].reshape((-1, 4, 2))
                    boxes[:, :, 0] /= ratio_w
                    boxes[:, :, 1] /= ratio_h

                duration = time.time() - start_time
                print('[timing] {}'.format(duration))

                # save to file
                if boxes is not None:
                    res_file = os.path.join(
                        FLAGS.output_dir,
                        '{}.txt'.format(
                            os.path.basename(im_fn).split('.')[0]))

                    with open(res_file, 'w') as f:
                        for box in boxes:
                            # to avoid submitting errors
                            box = sort_poly(box.astype(np.int32))
                            if np.linalg.norm(box[0] - box[1]) < 5 or np.linalg.norm(box[3]-box[0]) < 5:
                                continue
                            f.write('{},{},{},{},{},{},{},{}\r\n'.format(
                                box[0, 0], box[0, 1], box[1, 0], box[1, 1], box[2, 0], box[2, 1], box[3, 0], box[3, 1],
                            ))
                            cv2.polylines(im[:, :, ::-1], [box.astype(np.int32).reshape((-1, 1, 2))], True, color=(255, 255, 0), thickness=1)
                if not FLAGS.no_write_images:
                    img_path = os.path.join(FLAGS.output_dir, os.path.basename(im_fn))
                    cv2.imwrite(img_path, im[:, :, ::-1])

if __name__ == '__main__':
    tf.app.run()
# Out:
# Overwriting eval.py

# %%
# !cp /content/EAST/training_samples/9*.jpg test/

# %%
# !python eval.py --test_data_path=test/ --checkpoint_path=/content/east_icdar2015_resnet_v1_50_rbox/ --output_dir=/tmp/
# Out:
# make: Entering directory '/content/EAST/lanms'
# make: 'adaptor.so' is up to date.
# make: Leaving directory '/content/EAST/lanms'
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From eval.py:197: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From eval.py:137: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0322 10:51:00.046094 139827969202048 module_wrapper.py:139] From eval.py:137: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From eval.py:138: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0322 10:51:00.046809 139827969202048 module_wrapper.py:139] From eval.py:138: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From eval.py:139: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0322 10:51:00.047854 139827969202048 module_wrapper.py:139] From eval.py:139: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0322 10:51:00.057672 139827969202048 module_wrapper.py:139] From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/EAST/nets/resnet_v1.py:181: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0322 10:51:00.057972 139827969202048 module_wrapper.py:139] From /content/EAST/nets/resnet_v1.py:181: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0322 10:51:00.061433 139827969202048 deprecation.py:323] From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# resnet_v1_50/block1 (?, ?, ?, 256)
# resnet_v1_50/block2 (?, ?, ?, 512)
# resnet_v1_50/block3 (?, ?, ?, 1024)
# resnet_v1_50/block4 (?, ?, ?, 2048)
# Shape of f_0 (?, ?, ?, 2048)
# Shape of f_1 (?, ?, ?, 512)
# Shape of f_2 (?, ?, ?, 256)
# Shape of f_3 (?, ?, ?, 64)
# WARNING:tensorflow:From /content/EAST/model.py:14: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W0322 10:51:01.503641 139827969202048 module_wrapper.py:139] From /content/EAST/model.py:14: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# Shape of h_0 (?, ?, ?, 2048), g_0 (?, ?, ?, 2048)
# Shape of h_1 (?, ?, ?, 128), g_1 (?, ?, ?, 128)
# Shape of h_2 (?, ?, ?, 64), g_2 (?, ?, ?, 64)
# Shape of h_3 (?, ?, ?, 32), g_3 (?, ?, ?, 32)
# WARNING:tensorflow:From eval.py:144: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0322 10:51:01.768244 139827969202048 module_wrapper.py:139] From eval.py:144: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From eval.py:146: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0322 10:51:02.093586 139827969202048 module_wrapper.py:139] From eval.py:146: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From eval.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0322 10:51:02.093857 139827969202048 module_wrapper.py:139] From eval.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2020-03-22 10:51:02.099219: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-03-22 10:51:02.099446: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x24492c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-22 10:51:02.099474: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-22 10:51:02.101334: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-22 10:51:02.228628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 10:51:02.229231: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2449480 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-22 10:51:02.229272: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-03-22 10:51:02.229444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 10:51:02.229845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-22 10:51:02.230148: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-22 10:51:02.231509: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-22 10:51:02.233013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-22 10:51:02.233329: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-22 10:51:02.234818: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-22 10:51:02.235500: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-22 10:51:02.239059: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-22 10:51:02.239183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 10:51:02.239613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 10:51:02.239999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-22 10:51:02.240069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-22 10:51:02.241135: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-22 10:51:02.241161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-22 10:51:02.241171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-22 10:51:02.241283: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 10:51:02.241678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 10:51:02.242015: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-03-22 10:51:02.242055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# Restore from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# INFO:tensorflow:Restoring parameters from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# I0322 10:51:02.244277 139827969202048 saver.py:1284] Restoring parameters from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# Find 12 images
# 2020-03-22 10:51:03.608529: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-22 10:51:04.793687: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 135 text boxes before nms
# test/93. 1200px-rithaladelhi.jpg : net 2996ms, restore 1ms, nms 0ms
# [timing] 3.013096570968628
# 736 text boxes before nms
# test/93.jpg : net 785ms, restore 1ms, nms 0ms
# [timing] 0.815798282623291
# 1371 text boxes before nms
# test/92.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.07905459403991699
# 499 text boxes before nms
# test/91.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05017423629760742
# 853 text boxes before nms
# test/9. videoblocks-janpath-market-street-sign-hindi-and-english-new-delhi-india_sxqpwcxtx_thumbnail-full01.jpg : net 1085ms, restore 1ms, nms 0ms
# [timing] 1.24479079246521
# 1611 text boxes before nms
# test/95.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08918952941894531
# 1902 text boxes before nms
# test/9.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.09192657470703125
# 520 text boxes before nms
# test/98.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04834747314453125
# 319 text boxes before nms
# test/90.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04204750061035156
# 1167 text boxes before nms
# test/96.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07431817054748535
# 462 text boxes before nms
# test/97.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04828929901123047
# 819 text boxes before nms
# test/94.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05773496627807617

# %% [markdown]
# ##Upload the models into drive

# %%
from google.colab import auth
auth.authenticate_user()
from googleapiclient.discovery import build
drive_service = build('drive', 'v3')
from googleapiclient.http import MediaFileUpload
os.chdir('/content/east_icdar2015_resnet_v1_50_rbox')
for files in os.listdir('/content/east_icdar2015_resnet_v1_50_rbox'):
  file_metadata = {'name': files}
  media = MediaFileUpload(files, resumable=True)
  created = drive_service.files().create(body=file_metadata,
  media_body=media,
  fields='id').execute()
  print('File ID: {}'.format(created.get('id')))
# Out:
# File ID: 1sIlrQU1bqkG7el9hoT-gLxImnKk82hrd
# File ID: 1_sb4Mtb8nge3q8Xeq4_UVA2rk665qCkY
# File ID: 19b3FHPmhTGmx5cOPQjJ_ZORpZTzFD_fY
# File ID: 1B4ECV81-wiAK4vIZMbJhBAAV6YnDvI_2

# %%
os.listdir('/content/east_icdar2015_resnet_v1_50_rbox')
# Out:
# ['model.ckpt-49491.data-00000-of-00001',
#  'checkpoint',
#  'model.ckpt-49491.meta',
#  'model.ckpt-49491.index']

# %%
os.chdir('/content/EAST')
# !cp /content/EAST/training_samples/*.jpg test/
# !python eval.py --test_data_path=test/ --checkpoint_path=/content/east_icdar2015_resnet_v1_50_rbox/ --output_dir=/tmp/
# Out:
# make: Entering directory '/content/EAST/lanms'
# make: 'adaptor.so' is up to date.
# make: Leaving directory '/content/EAST/lanms'
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From eval.py:197: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From eval.py:137: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0322 11:11:32.942248 140617758287744 module_wrapper.py:139] From eval.py:137: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From eval.py:138: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0322 11:11:32.943156 140617758287744 module_wrapper.py:139] From eval.py:138: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From eval.py:139: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0322 11:11:32.945193 140617758287744 module_wrapper.py:139] From eval.py:139: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0322 11:11:32.957855 140617758287744 module_wrapper.py:139] From /content/EAST/nets/resnet_utils.py:236: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/EAST/nets/resnet_v1.py:181: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0322 11:11:32.958188 140617758287744 module_wrapper.py:139] From /content/EAST/nets/resnet_v1.py:181: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W0322 11:11:32.962126 140617758287744 deprecation.py:323] From /tensorflow-1.15.0/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# resnet_v1_50/block1 (?, ?, ?, 256)
# resnet_v1_50/block2 (?, ?, ?, 512)
# resnet_v1_50/block3 (?, ?, ?, 1024)
# resnet_v1_50/block4 (?, ?, ?, 2048)
# Shape of f_0 (?, ?, ?, 2048)
# Shape of f_1 (?, ?, ?, 512)
# Shape of f_2 (?, ?, ?, 256)
# Shape of f_3 (?, ?, ?, 64)
# WARNING:tensorflow:From /content/EAST/model.py:14: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# W0322 11:11:34.425031 140617758287744 module_wrapper.py:139] From /content/EAST/model.py:14: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# Shape of h_0 (?, ?, ?, 2048), g_0 (?, ?, ?, 2048)
# Shape of h_1 (?, ?, ?, 128), g_1 (?, ?, ?, 128)
# Shape of h_2 (?, ?, ?, 64), g_2 (?, ?, ?, 64)
# Shape of h_3 (?, ?, ?, 32), g_3 (?, ?, ?, 32)
# WARNING:tensorflow:From eval.py:144: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0322 11:11:34.687847 140617758287744 module_wrapper.py:139] From eval.py:144: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From eval.py:146: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0322 11:11:35.009696 140617758287744 module_wrapper.py:139] From eval.py:146: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From eval.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0322 11:11:35.009966 140617758287744 module_wrapper.py:139] From eval.py:146: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2020-03-22 11:11:35.015522: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-03-22 11:11:35.015769: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2885480 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-22 11:11:35.015803: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-22 11:11:35.017840: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-22 11:11:35.145562: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 11:11:35.146148: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2885d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-22 11:11:35.146177: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P4, Compute Capability 6.1
# 2020-03-22 11:11:35.146384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 11:11:35.146869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# 2020-03-22 11:11:35.147250: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-22 11:11:35.148966: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-22 11:11:35.150657: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-22 11:11:35.150988: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-22 11:11:35.152665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-22 11:11:35.153366: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-22 11:11:35.156558: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-22 11:11:35.156713: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 11:11:35.157124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 11:11:35.157434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-22 11:11:35.157538: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-22 11:11:35.158666: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-22 11:11:35.158691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-22 11:11:35.158701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-22 11:11:35.158814: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 11:11:35.159210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-22 11:11:35.159557: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-03-22 11:11:35.159610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7123 MB memory) -> physical GPU (device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1)
# Restore from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# INFO:tensorflow:Restoring parameters from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# I0322 11:11:35.161780 140617758287744 saver.py:1284] Restoring parameters from /content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491
# Find 428 images
# 2020-03-22 11:11:36.560847: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-22 11:11:37.754789: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 1336 text boxes before nms
# test/24.jpg : net 3224ms, restore 2ms, nms 0ms
# [timing] 3.276482343673706
# 167 text boxes before nms
# test/310.jpg : net 28ms, restore 0ms, nms 0ms
# [timing] 0.03892803192138672
# 1046 text boxes before nms
# test/51.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07756257057189941
# 706 text boxes before nms
# test/260.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05827021598815918
# 436 text boxes before nms
# test/32.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.05187416076660156
# 1094 text boxes before nms
# test/113.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07186388969421387
# 418 text boxes before nms
# test/16. _13527880332.jpg : net 831ms, restore 1ms, nms 0ms
# [timing] 0.8591740131378174
# 750 text boxes before nms
# test/250.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.06195783615112305
# 1023 text boxes before nms
# test/64.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07374787330627441
# 427 text boxes before nms
# test/42.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04422259330749512
# 957 text boxes before nms
# test/268.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07943248748779297
# 845 text boxes before nms
# test/218.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06408858299255371
# 72 text boxes before nms
# test/0.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.03484988212585449
# 763 text boxes before nms
# test/79.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05627107620239258
# 589 text boxes before nms
# test/427. 2018_3$largeimg18_mar_2018_231139550.jpg : net 740ms, restore 1ms, nms 0ms
# [timing] 0.7573513984680176
# 1162 text boxes before nms
# test/7.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0765688419342041
# 2301 text boxes before nms
# test/297.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.12065696716308594
# 447 text boxes before nms
# test/277.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04551124572753906
# 641 text boxes before nms
# test/4.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.059720516204833984
# 564 text boxes before nms
# test/213.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05320906639099121
# 643 text boxes before nms
# test/146.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.057093143463134766
# 1006 text boxes before nms
# test/140.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07125449180603027
# 1260 text boxes before nms
# test/84.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.08487486839294434
# 598 text boxes before nms
# test/167.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05236625671386719
# 768 text boxes before nms
# test/317.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05835843086242676
# 390 text boxes before nms
# test/72.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.0444185733795166
# 96 text boxes before nms
# test/126. heritage-line-1_14_1495-1.jpg : net 634ms, restore 0ms, nms 0ms
# [timing] 0.6371300220489502
# 1162 text boxes before nms
# test/122. img_3824.jpg : net 852ms, restore 1ms, nms 0ms
# [timing] 0.9141614437103271
# 880 text boxes before nms
# test/251.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06495046615600586
# 315 text boxes before nms
# test/65.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.04532766342163086
# 808 text boxes before nms
# test/217.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05788087844848633
# 688 text boxes before nms
# test/105. parshvanath-and-adinath-khajuraho-temple-images.jpg : net 731ms, restore 1ms, nms 0ms
# [timing] 0.7499172687530518
# 775 text boxes before nms
# test/283.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0603787899017334
# 628 text boxes before nms
# test/47.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.051007747650146484
# 791 text boxes before nms
# test/121.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.058316707611083984
# 860 text boxes before nms
# test/48.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.0649406909942627
# 51 text boxes before nms
# test/172.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.0325772762298584
# 1534 text boxes before nms
# test/324.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09495759010314941
# 1715 text boxes before nms
# test/86.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.10016894340515137
# 670 text boxes before nms
# test/189.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06112527847290039
# 595 text boxes before nms
# test/61.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05526375770568848
# 302 text boxes before nms
# test/154.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.042676448822021484
# 135 text boxes before nms
# test/93. 1200px-rithaladelhi.jpg : net 578ms, restore 0ms, nms 0ms
# [timing] 0.5942249298095703
# 1146 text boxes before nms
# test/180.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07205510139465332
# 3281 text boxes before nms
# test/112. 657892-634346-616442-ngt-national-green-tribunal-101217.jpg : net 660ms, restore 3ms, nms 0ms
# [timing] 0.946307897567749
# 572 text boxes before nms
# test/19.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05739283561706543
# 173 text boxes before nms
# test/212.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03909444808959961
# 536 text boxes before nms
# test/293.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04962635040283203
# 980 text boxes before nms
# test/20.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07135629653930664
# 495 text boxes before nms
# test/105.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05017352104187012
# 178 text boxes before nms
# test/119. 21991845.jpg : net 649ms, restore 1ms, nms 0ms
# [timing] 0.6556518077850342
# 74 text boxes before nms
# test/162. firing-near-resteraunt-near-karol-bagh-metro-station.jpg : net 634ms, restore 0ms, nms 0ms
# [timing] 0.6369020938873291
# 728 text boxes before nms
# test/166. 698797-delhi-hc.jpg : net 59ms, restore 1ms, nms 0ms
# [timing] 0.1373589038848877
# 1939 text boxes before nms
# test/236.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.10451912879943848
# 985 text boxes before nms
# test/300.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06935548782348633
# 503 text boxes before nms
# test/33.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04919910430908203
# 1121 text boxes before nms
# test/264.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07769179344177246
# 1666 text boxes before nms
# test/295.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.09985923767089844
# 800 text boxes before nms
# test/304.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05725598335266113
# 862 text boxes before nms
# test/11. nyoooz_hindi1902_1507879752.jpg : net 758ms, restore 1ms, nms 0ms
# [timing] 0.7955737113952637
# 982 text boxes before nms
# test/123.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06469464302062988
# 612 text boxes before nms
# test/286.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.051366329193115234
# 0 text boxes before nms
# test/160. 1-57-1507091095-261079-khaskhabar.jpg : net 750ms, restore 0ms, nms 0ms
# [timing] 0.7535533905029297
# 1723 text boxes before nms
# test/70.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.10047626495361328
# 250 text boxes before nms
# test/152. 28177310_3e1bf624-1bdc-43fe-a8d5-52b75cd96970.jpg : net 811ms, restore 1ms, nms 0ms
# [timing] 0.8257410526275635
# 591 text boxes before nms
# test/144.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05399012565612793
# 75 text boxes before nms
# test/152. hardlook-759.jpg : net 773ms, restore 0ms, nms 0ms
# [timing] 0.7798299789428711
# 1840 text boxes before nms
# test/308.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.10646629333496094
# 2050 text boxes before nms
# test/142. maxresdefault.jpg : net 58ms, restore 2ms, nms 0ms
# [timing] 0.2291407585144043
# 2129 text boxes before nms
# test/12. img201709231226442656225.jpg : net 718ms, restore 2ms, nms 0ms
# [timing] 0.9228136539459229
# 744 text boxes before nms
# test/129. iri23042013.jpg : net 796ms, restore 1ms, nms 0ms
# [timing] 0.8332960605621338
# 848 text boxes before nms
# test/6.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06398773193359375
# 1156 text boxes before nms
# test/114. lodhi-or-lodi-garden-new-delhi-popular-tourist-place-for-greenery-lovers-2-728.jpg : net 814ms, restore 1ms, nms 0ms
# [timing] 0.8643960952758789
# 1229 text boxes before nms
# test/56.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07288813591003418
# 372 text boxes before nms
# test/140. tibetan-1024x768.jpg : net 776ms, restore 1ms, nms 0ms
# [timing] 0.7923035621643066
# 736 text boxes before nms
# test/93.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06037402153015137
# 750 text boxes before nms
# test/325.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0582890510559082
# 552 text boxes before nms
# test/160.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05899381637573242
# 782 text boxes before nms
# test/183.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.060416221618652344
# 175 text boxes before nms
# test/290.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.03892922401428223
# 677 text boxes before nms
# test/28.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05611681938171387
# 1481 text boxes before nms
# test/279.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.08169746398925781
# 934 text boxes before nms
# test/111.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06707429885864258
# 680 text boxes before nms
# test/115.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05810356140136719
# 448 text boxes before nms
# test/274.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04802370071411133
# 1096 text boxes before nms
# test/114. delhi-high-court-new.jpg : net 844ms, restore 1ms, nms 0ms
# [timing] 0.9212725162506104
# 96 text boxes before nms
# test/129. narsinghpur.jpg : net 28ms, restore 0ms, nms 0ms
# [timing] 0.036434173583984375
# 1270 text boxes before nms
# test/126. img_3086.jpg : net 1840ms, restore 1ms, nms 0ms
# [timing] 2.3591089248657227
# 680 text boxes before nms
# test/77.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05639338493347168
# 533 text boxes before nms
# test/499. veg-gulati_1427545555m.jpg : net 25ms, restore 1ms, nms 0ms
# [timing] 0.05287981033325195
# 264 text boxes before nms
# test/11. national-museum.jpg : net 822ms, restore 1ms, nms 0ms
# [timing] 0.8319418430328369
# 88 text boxes before nms
# test/135.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03440737724304199
# 2094 text boxes before nms
# test/309.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.11729574203491211
# 463 text boxes before nms
# test/81.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.049131155014038086
# 1291 text boxes before nms
# test/101.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07589125633239746
# 1099 text boxes before nms
# test/285.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.06695246696472168
# 1374 text boxes before nms
# test/487. videoblocks-entry-for-differently-abled-sign-disabled-handicapped-entrance-delhi-india_bpbk2zyy6g_thumbnail-full01.jpg : net 1083ms, restore 2ms, nms 0ms
# [timing] 1.3393735885620117
# 417 text boxes before nms
# test/87.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04754185676574707
# 378 text boxes before nms
# test/151. up-bjp-leaders-15237.jpg : net 771ms, restore 1ms, nms 0ms
# [timing] 0.7881302833557129
# 1371 text boxes before nms
# test/92.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07874417304992676
# 49 text boxes before nms
# test/161.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.034416913986206055
# 3908 text boxes before nms
# test/182.jpg : net 27ms, restore 3ms, nms 0ms
# [timing] 0.18350720405578613
# 286 text boxes before nms
# test/484. 29.national%20museum.jpg : net 633ms, restore 1ms, nms 0ms
# [timing] 0.639228343963623
# 392 text boxes before nms
# test/45. gurgaon_1460298928.jpg : net 817ms, restore 1ms, nms 0ms
# [timing] 0.8385343551635742
# 2345 text boxes before nms
# test/441. picsart010908623962.jpg : net 842ms, restore 2ms, nms 0ms
# [timing] 0.9520249366760254
# 338 text boxes before nms
# test/44.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.052091360092163086
# 477 text boxes before nms
# test/314.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0518641471862793
# 864 text boxes before nms
# test/171.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06210470199584961
# 743 text boxes before nms
# test/281.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.06270289421081543
# 610 text boxes before nms
# test/226.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05401253700256348
# 0 text boxes before nms
# test/136.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03203701972961426
# 106 text boxes before nms
# test/264. himachal-bhawan1.jpg : net 16ms, restore 0ms, nms 0ms
# [timing] 0.02071404457092285
# 446 text boxes before nms
# test/Pandit-Kulfi-1.jpg : net 16ms, restore 1ms, nms 0ms
# [timing] 0.027776241302490234
# 244 text boxes before nms
# test/15. niti-aayog-1493557223.jpg : net 22ms, restore 1ms, nms 0ms
# [timing] 0.033916473388671875
# 990 text boxes before nms
# test/52.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07414865493774414
# 755 text boxes before nms
# test/170.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0651547908782959
# 155 text boxes before nms
# test/292.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03760385513305664
# 1774 text boxes before nms
# test/139.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.10103082656860352
# 1673 text boxes before nms
# test/267.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09890627861022949
# 0 text boxes before nms
# test/179.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.031061887741088867
# 921 text boxes before nms
# test/109. khajuraho_station.jpg : net 832ms, restore 1ms, nms 0ms
# [timing] 0.8810148239135742
# 1662 text boxes before nms
# test/313.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.10414767265319824
# 106 text boxes before nms
# test/139. 20141009_133738-e1512027263118.jpg : net 638ms, restore 1ms, nms 0ms
# [timing] 0.6417033672332764
# 248 text boxes before nms
# test/294. temple-direction-sign-arrow-pointing-english-and-hindi-languages_sf3rupq4x_thumbnail-full01.jpg : net 119ms, restore 1ms, nms 0ms
# [timing] 0.1877598762512207
# 742 text boxes before nms
# test/125.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.059114933013916016
# 884 text boxes before nms
# test/299.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06839346885681152
# 107 text boxes before nms
# test/312. akbar-road.jpg : net 25ms, restore 0ms, nms 0ms
# [timing] 0.03227066993713379
# 1245 text boxes before nms
# test/296.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07131195068359375
# 1169 text boxes before nms
# test/222.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07965922355651855
# 979 text boxes before nms
# test/263.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06500887870788574
# 770 text boxes before nms
# test/16.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0613102912902832
# 403 text boxes before nms
# test/139. ugc759.jpg : net 25ms, restore 1ms, nms 0ms
# [timing] 0.04225921630859375
# 398 text boxes before nms
# test/102. indiatve36df4_patelnagar.jpg : net 24ms, restore 1ms, nms 0ms
# [timing] 0.03979945182800293
# 0 text boxes before nms
# test/307.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.031050682067871094
# 988 text boxes before nms
# test/102.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06685638427734375
# 1447 text boxes before nms
# test/170. img_4941.jpg : net 1142ms, restore 1ms, nms 0ms
# [timing] 1.3916771411895752
# 188 text boxes before nms
# test/194.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.039087533950805664
# 1886 text boxes before nms
# test/120. 1478080632_rotates_shareiq_1213_1478078172.9512.jpg : net 771ms, restore 2ms, nms 0ms
# [timing] 0.9666798114776611
# 246 text boxes before nms
# test/287.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04101872444152832
# 462 text boxes before nms
# test/205.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05246567726135254
# 1182 text boxes before nms
# test/155.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07761979103088379
# 211 text boxes before nms
# test/311.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04013943672180176
# 636 text boxes before nms
# test/107.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0560455322265625
# 227 text boxes before nms
# test/136. untitled-272.jpg : net 676ms, restore 1ms, nms 0ms
# [timing] 0.6847586631774902
# 208 text boxes before nms
# test/145.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0397489070892334
# 914 text boxes before nms
# test/59.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06372666358947754
# 1491 text boxes before nms
# test/178.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09250879287719727
# 957 text boxes before nms
# test/256.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06345343589782715
# 1020 text boxes before nms
# test/30.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06781983375549316
# 918 text boxes before nms
# test/209.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.06627893447875977
# 457 text boxes before nms
# test/18. janpath-market.jpg : net 659ms, restore 1ms, nms 0ms
# [timing] 0.6723451614379883
# 1765 text boxes before nms
# test/211.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09675860404968262
# 916 text boxes before nms
# test/122. img1909930368.jpg : net 724ms, restore 1ms, nms 0ms
# [timing] 0.8264086246490479
# 2205 text boxes before nms
# test/89.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.11820650100708008
# 476 text boxes before nms
# test/228.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0511317253112793
# 682 text boxes before nms
# test/58.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.05538773536682129
# 554 text boxes before nms
# test/278.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.050159454345703125
# 366 text boxes before nms
# test/254.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.047991037368774414
# 600 text boxes before nms
# test/128. 1499669776_national_gallery_of_modern_art_delhi__282_29.jpg : net 25ms, restore 1ms, nms 0ms
# [timing] 0.05115818977355957
# 499 text boxes before nms
# test/91.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05026555061340332
# 1146 text boxes before nms
# test/275.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07414031028747559
# 1076 text boxes before nms
# test/34.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07140469551086426
# 407 text boxes before nms
# test/103. gurgaon_1460298928.jpg : net 654ms, restore 1ms, nms 0ms
# [timing] 0.6655926704406738
# 340 text boxes before nms
# test/131. citi-maas6-1024x768.jpg : net 764ms, restore 1ms, nms 0ms
# [timing] 0.7776663303375244
# 1446 text boxes before nms
# test/76.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0862283706665039
# 2010 text boxes before nms
# test/74.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.11208271980285645
# 109 text boxes before nms
# test/11. caption.jpg : net 20ms, restore 0ms, nms 0ms
# [timing] 0.026705026626586914
# 0 text boxes before nms
# test/323.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.031005144119262695
# 816 text boxes before nms
# test/24. sharda-ukil-school-of-art-janpath-delhi-fashion-designing-institutes-0k9l9.jpg : net 817ms, restore 1ms, nms 0ms
# [timing] 0.8506317138671875
# 127 text boxes before nms
# test/132. 300px-pitampuradelhi.jpg : net 416ms, restore 1ms, nms 0ms
# [timing] 0.4196631908416748
# 560 text boxes before nms
# test/238.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.04886579513549805
# 187 text boxes before nms
# test/163. gali-paranthe-wali.jpg : net 583ms, restore 1ms, nms 0ms
# [timing] 0.5912628173828125
# 1282 text boxes before nms
# test/148.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0782468318939209
# 4002 text boxes before nms
# test/240. temple-entrance-door-sign-english-and-hindi-languages-india_btx6gupxel_thumbnail-full01.jpg : net 119ms, restore 3ms, nms 0ms
# [timing] 0.8259081840515137
# 1389 text boxes before nms
# test/187.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08599328994750977
# 736 text boxes before nms
# test/43.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.0607907772064209
# 146 text boxes before nms
# test/495. delhi-paranthe-wali-gali.jpg : net 660ms, restore 0ms, nms 0ms
# [timing] 0.6673216819763184
# 853 text boxes before nms
# test/9. videoblocks-janpath-market-street-sign-hindi-and-english-new-delhi-india_sxqpwcxtx_thumbnail-full01.jpg : net 119ms, restore 1ms, nms 0ms
# [timing] 0.28066539764404297
# 1425 text boxes before nms
# test/27.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08701372146606445
# 274 text boxes before nms
# test/165.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.041258811950683594
# 169 text boxes before nms
# test/136. rbi-announces-f4755.jpg : net 25ms, restore 0ms, nms 0ms
# [timing] 0.03448486328125
# 262 text boxes before nms
# test/341. 15092450197_3dc5a760d3_b.jpg : net 902ms, restore 1ms, nms 0ms
# [timing] 0.9266457557678223
# 814 text boxes before nms
# test/60.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.05888485908508301
# 1044 text boxes before nms
# test/8.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06710171699523926
# 1611 text boxes before nms
# test/95.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.08956766128540039
# 1902 text boxes before nms
# test/9.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.10218524932861328
# 1116 text boxes before nms
# test/150.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07051587104797363
# 1517 text boxes before nms
# test/104. aa-cover-5dfhaeu9i4at0o046ruj9vl6v7-20161221105554.medi.jpg : net 810ms, restore 1ms, nms 0ms
# [timing] 0.8718407154083252
# 924 text boxes before nms
# test/14.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06203722953796387
# 358 text boxes before nms
# test/88.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0477144718170166
# 456 text boxes before nms
# test/164. 12243201_10153720744566585_194230972898132752_n.jpg : net 643ms, restore 1ms, nms 0ms
# [timing] 0.6531000137329102
# 409 text boxes before nms
# test/177.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.048992156982421875
# 377 text boxes before nms
# test/11. dsc_0018.jpg : net 13ms, restore 1ms, nms 0ms
# [timing] 0.020704030990600586
# 620 text boxes before nms
# test/294.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.057901620864868164
# 1244 text boxes before nms
# test/23.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.08316516876220703
# 1202 text boxes before nms
# test/224.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0776832103729248
# 386 text boxes before nms
# test/175.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04567527770996094
# 163 text boxes before nms
# test/184.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.03851485252380371
# 1425 text boxes before nms
# test/132.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08401274681091309
# 0 text boxes before nms
# test/266.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03167295455932617
# 1053 text boxes before nms
# test/207.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07282781600952148
# 1403 text boxes before nms
# test/176.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08251452445983887
# 399 text boxes before nms
# test/235.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.044982194900512695
# 740 text boxes before nms
# test/214.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06413650512695312
# 463 text boxes before nms
# test/244.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.049284934997558594
# 30 text boxes before nms
# test/282.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.03288412094116211
# 2407 text boxes before nms
# test/265.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.12236595153808594
# 351 text boxes before nms
# test/138.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04546332359313965
# 1992 text boxes before nms
# test/230.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.1010444164276123
# 1082 text boxes before nms
# test/25.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0683140754699707
# 137 text boxes before nms
# test/164.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.036360740661621094
# 1942 text boxes before nms
# test/62.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.10515952110290527
# 975 text boxes before nms
# test/257.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06806325912475586
# 397 text boxes before nms
# test/158. ugc-1-759.jpg : net 25ms, restore 0ms, nms 0ms
# [timing] 0.04657793045043945
# 565 text boxes before nms
# test/117. name-stone.jpg : net 18ms, restore 1ms, nms 0ms
# [timing] 0.03502798080444336
# 852 text boxes before nms
# test/110.jpg : net 29ms, restore 1ms, nms 0ms
# [timing] 0.07101821899414062
# 1005 text boxes before nms
# test/269.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07667016983032227
# 631 text boxes before nms
# test/273.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.055330514907836914
# 1072 text boxes before nms
# test/75.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0668494701385498
# 213 text boxes before nms
# test/133. 06102011266.jpg : net 785ms, restore 1ms, nms 0ms
# [timing] 0.7968871593475342
# 1941 text boxes before nms
# test/210. 595291a7b4ce8a3750530dec_59267d9f9a22727e7f52d080_1498583463954.jpg : net 710ms, restore 2ms, nms 0ms
# [timing] 0.8150472640991211
# 544 text boxes before nms
# test/159.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05041098594665527
# 452 text boxes before nms
# test/204.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04882955551147461
# 1315 text boxes before nms
# test/249.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08028960227966309
# 449 text boxes before nms
# test/55.jpg : net 30ms, restore 1ms, nms 0ms
# [timing] 0.05559563636779785
# 25 text boxes before nms
# test/173.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03405451774597168
# 522 text boxes before nms
# test/61. delhi-highcourt_1504878068.jpg : net 25ms, restore 1ms, nms 0ms
# [timing] 0.05962252616882324
# 2737 text boxes before nms
# test/102. img_20150110_183248.jpg : net 600ms, restore 2ms, nms 0ms
# [timing] 0.7758715152740479
# 0 text boxes before nms
# test/272.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03140449523925781
# 1077 text boxes before nms
# test/276.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.07195925712585449
# 423 text boxes before nms
# test/122.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.04584550857543945
# 454 text boxes before nms
# test/3.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04757380485534668
# 861 text boxes before nms
# test/156.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06869983673095703
# 671 text boxes before nms
# test/149. 1200px-chinchwad_railway_station.jpg : net 68ms, restore 1ms, nms 0ms
# [timing] 0.14583539962768555
# 1889 text boxes before nms
# test/65. laxmi_nagar_metro_st._sign_board.jpg : net 1153ms, restore 3ms, nms 0ms
# [timing] 1.511465072631836
# 682 text boxes before nms
# test/1.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05945920944213867
# 927 text boxes before nms
# test/panchavati-gaurav-to-add-50-outl-807e888a81.jpg : net 782ms, restore 1ms, nms 0ms
# [timing] 0.8195040225982666
# 967 text boxes before nms
# test/192. delhi-high-court-7591.jpg : net 25ms, restore 1ms, nms 0ms
# [timing] 0.06070756912231445
# 407 text boxes before nms
# test/270. palika-bazaar.jpg : net 805ms, restore 1ms, nms 0ms
# [timing] 0.8258426189422607
# 116 text boxes before nms
# test/252.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03459477424621582
# 131 text boxes before nms
# test/162. 113-640x360.jpg : net 753ms, restore 0ms, nms 0ms
# [timing] 0.7615513801574707
# 349 text boxes before nms
# test/46.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.053377628326416016
# 1599 text boxes before nms
# test/117.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09183406829833984
# 903 text boxes before nms
# test/10.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06416678428649902
# 1929 text boxes before nms
# test/106.jpg : net 27ms, restore 5ms, nms 0ms
# [timing] 0.10498690605163574
# 526 text boxes before nms
# test/126.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04893350601196289
# 108 text boxes before nms
# test/253.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.03453373908996582
# 1296 text boxes before nms
# test/112.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.0778803825378418
# 1114 text boxes before nms
# test/18.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07136178016662598
# 1009 text boxes before nms
# test/202.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08275008201599121
# 0 text boxes before nms
# test/203.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.030941009521484375
# 958 text boxes before nms
# test/11.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06375527381896973
# 2475 text boxes before nms
# test/185.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.12453889846801758
# 399 text boxes before nms
# test/117. main-qimg-09d0ff2a125cd775813beb37429ecc14-c.jpg : net 21ms, restore 1ms, nms 0ms
# [timing] 0.038672447204589844
# 1174 text boxes before nms
# test/36.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07931852340698242
# 1454 text boxes before nms
# test/237.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08688592910766602
# 288 text boxes before nms
# test/246.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.04270458221435547
# 1716 text boxes before nms
# test/196.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.10036492347717285
# 2040 text boxes before nms
# test/129.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.10843396186828613
# 26 text boxes before nms
# test/164. 52b9304db02d31499e48e18b58608e20--henry-miller-madhya-pradesh.jpg : net 412ms, restore 0ms, nms 0ms
# [timing] 0.41435718536376953
# 189 text boxes before nms
# test/170. guest-from-kerala-protested-outside-house-state_4146a3f6-7d6a-11e5-ba56-8cfa9414553d.jpg : net 650ms, restore 1ms, nms 0ms
# [timing] 0.6564490795135498
# 690 text boxes before nms
# test/78.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05615091323852539
# 0 text boxes before nms
# test/319.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03179621696472168
# 520 text boxes before nms
# test/98.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04658770561218262
# 1167 text boxes before nms
# test/120.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07134771347045898
# 277 text boxes before nms
# test/114. palika-bazaar-delhi.jpg : net 657ms, restore 1ms, nms 0ms
# [timing] 0.6660504341125488
# 324 text boxes before nms
# test/298.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04311537742614746
# 408 text boxes before nms
# test/147. eef31413b9324b59a1645f6a683132091983543.jpg : net 67ms, restore 1ms, nms 0ms
# [timing] 0.11882472038269043
# 145 text boxes before nms
# test/234.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.03798818588256836
# 1600 text boxes before nms
# test/149.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.09184408187866211
# 468 text boxes before nms
# test/195.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04885077476501465
# 577 text boxes before nms
# test/151.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.06696343421936035
# 428 text boxes before nms
# test/133. 4ff978e80f4b71d69a80ae4420f24d9f--new-delhi-ticket.jpg : net 683ms, restore 1ms, nms 0ms
# [timing] 0.6979076862335205
# 15 text boxes before nms
# test/163.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.03129768371582031
# 168 text boxes before nms
# test/13116615_1804919146396837_824128706_n.jpg : net 629ms, restore 0ms, nms 0ms
# [timing] 0.6329503059387207
# 5587 text boxes before nms
# test/142. 1*zvna5tlu7by4lpmb3cd90w.jpg : net 871ms, restore 4ms, nms 0ms
# [timing] 1.59824800491333
# 103 text boxes before nms
# test/157.jpg : net 28ms, restore 0ms, nms 0ms
# [timing] 0.036390066146850586
# 483 text boxes before nms
# test/128. metro_3.jpg : net 16ms, restore 1ms, nms 0ms
# [timing] 0.02886056900024414
# 2281 text boxes before nms
# test/318.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.11692070960998535
# 1314 text boxes before nms
# test/82.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07846689224243164
# 242 text boxes before nms
# test/100.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.040450096130371094
# 27 text boxes before nms
# test/57.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03343963623046875
# 432 text boxes before nms
# test/124. outside-patel-chowk-metro.jpg : net 20ms, restore 1ms, nms 0ms
# [timing] 0.03543853759765625
# 257 text boxes before nms
# test/5.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04680347442626953
# 1563 text boxes before nms
# test/73.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.09128022193908691
# 746 text boxes before nms
# test/7. 016.jpg : net 679ms, restore 1ms, nms 0ms
# [timing] 0.7520928382873535
# 241 text boxes before nms
# test/241.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.04053688049316406
# 1134 text boxes before nms
# test/221.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07405543327331543
# 542 text boxes before nms
# test/168.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05314230918884277
# 1024 text boxes before nms
# test/103.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07393980026245117
# 467 text boxes before nms
# test/240.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.050165414810180664
# 188 text boxes before nms
# test/161. nlu-450x338.jpg : net 655ms, restore 1ms, nms 0ms
# [timing] 0.6615490913391113
# 336 text boxes before nms
# test/239.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04265713691711426
# 406 text boxes before nms
# test/151. national-archiv.jpg : net 21ms, restore 1ms, nms 0ms
# [timing] 0.03485512733459473
# 803 text boxes before nms
# test/118. delhi-high-court-7591-2.jpg : net 764ms, restore 1ms, nms 0ms
# [timing] 0.7896020412445068
# 800 text boxes before nms
# test/216. delhi-jahanpanah-city-forest.jpg : net 901ms, restore 1ms, nms 0ms
# [timing] 0.9548263549804688
# 380 text boxes before nms
# test/181.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.04488658905029297
# 706 text boxes before nms
# test/271.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06346583366394043
# 2162 text boxes before nms
# test/130.jpg : net 27ms, restore 3ms, nms 0ms
# [timing] 0.11345481872558594
# 659 text boxes before nms
# test/231.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.055047035217285156
# 2399 text boxes before nms
# test/206.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.12102818489074707
# 1199 text boxes before nms
# test/289.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07340526580810547
# 464 text boxes before nms
# test/29.jpg : net 30ms, restore 1ms, nms 0ms
# [timing] 0.05460023880004883
# 619 text boxes before nms
# test/210.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06004023551940918
# 2559 text boxes before nms
# test/142.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.1212775707244873
# 1106 text boxes before nms
# test/13.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06697988510131836
# 0 text boxes before nms
# test/141.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.030460357666015625
# 832 text boxes before nms
# test/38.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05693554878234863
# 269 text boxes before nms
# test/276. 1-16337-26276.jpg : net 17ms, restore 1ms, nms 0ms
# [timing] 0.025098085403442383
# 3430 text boxes before nms
# test/132. india_welcome.jpg : net 1038ms, restore 3ms, nms 0ms
# [timing] 1.5331122875213623
# 31 text boxes before nms
# test/315.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03367972373962402
# 1012 text boxes before nms
# test/191.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06629467010498047
# 5904 text boxes before nms
# test/150. 20151112_132030.jpg : net 1889ms, restore 5ms, nms 0ms
# [timing] 4.269975423812866
# 1901 text boxes before nms
# test/200.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.1059868335723877
# 911 text boxes before nms
# test/270.jpg : net 30ms, restore 1ms, nms 0ms
# [timing] 0.06879401206970215
# 1014 text boxes before nms
# test/45.jpg : net 30ms, restore 1ms, nms 0ms
# [timing] 0.06844902038574219
# 946 text boxes before nms
# test/21.jpg : net 30ms, restore 1ms, nms 0ms
# [timing] 0.0661311149597168
# 964 text boxes before nms
# test/261.jpg : net 29ms, restore 1ms, nms 0ms
# [timing] 0.07562971115112305
# 6704 text boxes before nms
# test/20. videoblocks-road-sign-leading-to-main-bazar-hindi-and-english-new-delhi-india_shkd7v7ax_thumbnail-full01.jpg : net 132ms, restore 5ms, nms 0ms
# [timing] 1.195129632949829
# 971 text boxes before nms
# test/262.jpg : net 29ms, restore 1ms, nms 0ms
# [timing] 0.07115769386291504
# 559 text boxes before nms
# test/15. img00407-20110717-1423.jpg : net 1081ms, restore 1ms, nms 0ms
# [timing] 1.1867878437042236
# 196 text boxes before nms
# test/117. main-qimg-4f7c25fd3f68c21a80f74e7344215eee.jpg : net 19ms, restore 0ms, nms 0ms
# [timing] 0.025987863540649414
# 237 text boxes before nms
# test/291.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.039133548736572266
# 9983 text boxes before nms
# test/123. p1020013.jpg : net 2290ms, restore 6ms, nms 0ms
# [timing] 6.832197189331055
# 264 text boxes before nms
# test/305.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04079318046569824
# 267 text boxes before nms
# test/153.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04048466682434082
# 513 text boxes before nms
# test/53.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.048250436782836914
# 1493 text boxes before nms
# test/201.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.08361124992370605
# 166 text boxes before nms
# test/165. 300px-barrackpore_railway_station_%281%29.jpg : net 420ms, restore 1ms, nms 0ms
# [timing] 0.4243049621582031
# 251 text boxes before nms
# test/301.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.046727895736694336
# 219 text boxes before nms
# test/62. jantar-mantar-delhi-206694.jpg : net 781ms, restore 1ms, nms 0ms
# [timing] 0.7939684391021729
# 1294 text boxes before nms
# test/316.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0853114128112793
# 2 text boxes before nms
# test/220.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.03481578826904297
# 1061 text boxes before nms
# test/199.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06825470924377441
# 1025 text boxes before nms
# test/242.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.066192626953125
# 1889 text boxes before nms
# test/120. laxmi_nagar_metro_st._sign_board.jpg : net 128ms, restore 2ms, nms 0ms
# [timing] 0.46492481231689453
# 897 text boxes before nms
# test/128.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06515336036682129
# 460 text boxes before nms
# test/Thana-Ram-Janm-Bhoomi-1472884793-1499243551_835x547.jpg : net 652ms, restore 1ms, nms 0ms
# [timing] 0.663726806640625
# 1140 text boxes before nms
# test/37.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07677698135375977
# 386 text boxes before nms
# test/16. news_id_3162.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.043975114822387695
# 836 text boxes before nms
# test/118.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06254124641418457
# 716 text boxes before nms
# test/12. delhi-metro-billboards.jpg : net 820ms, restore 1ms, nms 0ms
# [timing] 0.851189136505127
# 3012 text boxes before nms
# test/134. img_2361.jpg : net 115ms, restore 4ms, nms 0ms
# [timing] 0.6056859493255615
# 2070 text boxes before nms
# test/pathik-hotel-by-pass-choraha-indore-lodging-services-25wt7lv.jpg : net 911ms, restore 2ms, nms 0ms
# [timing] 1.0460939407348633
# 215 text boxes before nms
# test/225.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.037212371826171875
# 399 text boxes before nms
# test/273. main-qimg-09d0ff2a125cd775813beb37429ecc14-c.jpg : net 21ms, restore 1ms, nms 0ms
# [timing] 0.034828901290893555
# 376 text boxes before nms
# test/15.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.04359698295593262
# 1255 text boxes before nms
# test/245.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.09589529037475586
# 319 text boxes before nms
# test/90.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.043526411056518555
# 1668 text boxes before nms
# test/302.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.0942986011505127
# 605 text boxes before nms
# test/322.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05759572982788086
# 1675 text boxes before nms
# test/219.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09463310241699219
# 26 text boxes before nms
# test/31.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.0340573787689209
# 561 text boxes before nms
# test/76. pitampuradelhi.jpg : net 766ms, restore 1ms, nms 0ms
# [timing] 0.7870292663574219
# 858 text boxes before nms
# test/63.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05900692939758301
# 329 text boxes before nms
# test/216.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04203391075134277
# 1787 text boxes before nms
# test/71.jpg : net 26ms, restore 2ms, nms 0ms
# [timing] 0.11436772346496582
# 119 text boxes before nms
# test/145. kanha-tiger-reserve.jpg : net 760ms, restore 0ms, nms 0ms
# [timing] 0.7673170566558838
# 1102 text boxes before nms
# test/174.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07242870330810547
# 765 text boxes before nms
# test/169.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.05734443664550781
# 796 text boxes before nms
# test/312.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05840468406677246
# 321 text boxes before nms
# test/39.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.042942047119140625
# 631 text boxes before nms
# test/162.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05340313911437988
# 117 text boxes before nms
# test/494. national-zoo-sign1_1413278727_540x540.jpg : net 20ms, restore 0ms, nms 0ms
# [timing] 0.02544546127319336
# 742 text boxes before nms
# test/303.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.058321475982666016
# 370 text boxes before nms
# test/197.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.04459500312805176
# 1698 text boxes before nms
# test/255.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.10541892051696777
# 1190 text boxes before nms
# test/131.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.08032941818237305
# 0 text boxes before nms
# test/104.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.030625581741333008
# 1141 text boxes before nms
# test/5. img_6600.jpg : net 930ms, restore 2ms, nms 0ms
# [timing] 1.0684738159179688
# 2255 text boxes before nms
# test/108.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.12714862823486328
# 424 text boxes before nms
# test/233. delhi-zoo_1476867625.jpg : net 681ms, restore 1ms, nms 0ms
# [timing] 0.696474552154541
# 285 text boxes before nms
# test/17. ghaziabad-hindustan-febuary-ghaziabad-tuesday-welcome-febuary_050296d0-29b7-11e6-a271-92fd27615944.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.04098224639892578
# 219 text boxes before nms
# test/54.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.03898191452026367
# 477 text boxes before nms
# test/119. img_9800-1.jpg : net 840ms, restore 1ms, nms 0ms
# [timing] 0.9031953811645508
# 969 text boxes before nms
# test/127.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06294631958007812
# 424 text boxes before nms
# test/198.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.04645657539367676
# 932 text boxes before nms
# test/12.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06491637229919434
# 1368 text boxes before nms
# test/158.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07719945907592773
# 2351 text boxes before nms
# test/104. election-commission.jpg : net 787ms, restore 2ms, nms 0ms
# [timing] 0.8801624774932861
# 1167 text boxes before nms
# test/96.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.08069562911987305
# 1320 text boxes before nms
# test/152.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.07430267333984375
# 1260 text boxes before nms
# test/223.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.08099699020385742
# 231 text boxes before nms
# test/147.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.0397944450378418
# 462 text boxes before nms
# test/97.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.04587531089782715
# 604 text boxes before nms
# test/259.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05176877975463867
# 1129 text boxes before nms
# test/43. palika-bazar.jpg : net 20ms, restore 1ms, nms 0ms
# [timing] 0.053487300872802734
# 3152 text boxes before nms
# test/46. videoblocks-india-tourism-delhi-sign-hindi-and-english-nighttime-new-delhi-india_rx3i43x6g_thumbnail-full01.jpg : net 119ms, restore 2ms, nms 0ms
# [timing] 0.6520042419433594
# 773 text boxes before nms
# test/22.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06716108322143555
# 770 text boxes before nms
# test/40.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.058487653732299805
# 119 text boxes before nms
# test/83.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.035213470458984375
# 325 text boxes before nms
# test/11. india_delhi_metro_rail_flickr_linuskendal_750_572_80_s.jpg : net 30ms, restore 1ms, nms 0ms
# [timing] 0.04790639877319336
# 1236 text boxes before nms
# test/233.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07494306564331055
# 225 text boxes before nms
# test/67.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.037360191345214844
# 843 text boxes before nms
# test/26.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.058129072189331055
# 783 text boxes before nms
# test/280.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.060811758041381836
# 1440 text boxes before nms
# test/17.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.08455157279968262
# 266 text boxes before nms
# test/215.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04096269607543945
# 714 text boxes before nms
# test/193.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06630396842956543
# 121 text boxes before nms
# test/114.jpg : net 27ms, restore 0ms, nms 0ms
# [timing] 0.038738250732421875
# 2490 text boxes before nms
# test/123. tropic-of-cancer-sponsored-by-the-government-of-madhya-pradesh.jpg : net 751ms, restore 2ms, nms 0ms
# [timing] 0.9937038421630859
# 93 text boxes before nms
# test/149. hi369559685.jpg : net 788ms, restore 0ms, nms 0ms
# [timing] 0.796790599822998
# 391 text boxes before nms
# test/475. picsart03170990089.jpg : net 829ms, restore 1ms, nms 0ms
# [timing] 0.849189281463623
# 1236 text boxes before nms
# test/258.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07385134696960449
# 1765 text boxes before nms
# test/68.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.09149479866027832
# 1078 text boxes before nms
# test/85.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.06623697280883789
# 695 text boxes before nms
# test/166.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.05553793907165527
# 1866 text boxes before nms
# test/158. keralahouse_beefsaahil11.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09619617462158203
# 465 text boxes before nms
# test/137.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.051757097244262695
# 440 text boxes before nms
# test/116.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.047377586364746094
# 122 text boxes before nms
# test/124.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.03823399543762207
# 524 text boxes before nms
# test/229.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.04828786849975586
# 608 text boxes before nms
# test/143.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.053690433502197266
# 1485 text boxes before nms
# test/208.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.0824441909790039
# 126 text boxes before nms
# test/109. rajpath.jpg : net 13ms, restore 0ms, nms 0ms
# [timing] 0.016100168228149414
# 195 text boxes before nms
# test/284.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.038051605224609375
# 1407 text boxes before nms
# test/232.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.07919764518737793
# 1649 text boxes before nms
# test/50.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.09222602844238281
# 882 text boxes before nms
# test/306.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.06103515625
# 392 text boxes before nms
# test/243.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.0481564998626709
# 0 text boxes before nms
# test/2.jpg : net 26ms, restore 0ms, nms 0ms
# [timing] 0.030824899673461914
# 910 text boxes before nms
# test/188.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06411027908325195
# 819 text boxes before nms
# test/94.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06041264533996582
# 674 text boxes before nms
# test/80.jpg : net 28ms, restore 1ms, nms 0ms
# [timing] 0.05548715591430664
# 938 text boxes before nms
# test/227.jpg : net 26ms, restore 1ms, nms 0ms
# [timing] 0.06549191474914551
# 1066 text boxes before nms
# test/248.jpg : net 27ms, restore 1ms, nms 0ms
# [timing] 0.07150578498840332
# 2319 text boxes before nms
# test/133.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.11686468124389648
# 2272 text boxes before nms
# test/321.jpg : net 27ms, restore 2ms, nms 0ms
# [timing] 0.10901403427124023

# %% [markdown]
# ##Zipping and Downloading all the folders and files used

# %%
# !zip -r /content/EAST.zip /content/EAST/
# !zip -r /content/east_icdar2015_resnet_v1_50_rbox.zip /content/east_icdar2015_resnet_v1_50_rbox
# Out:
#   adding: content/EAST/ (stored 0%)
#   adding: content/EAST/test/ (stored 0%)
#   adding: content/EAST/test/24.jpg (deflated 4%)
#   adding: content/EAST/test/310.jpg (deflated 5%)
#   adding: content/EAST/test/51.jpg (deflated 6%)
#   adding: content/EAST/test/260.jpg (deflated 6%)
#   adding: content/EAST/test/32.jpg (deflated 5%)
#   adding: content/EAST/test/113.jpg (deflated 5%)
#   adding: content/EAST/test/16. _13527880332.jpg (deflated 3%)
#   adding: content/EAST/test/250.jpg (deflated 5%)
#   adding: content/EAST/test/64.jpg (deflated 5%)
#   adding: content/EAST/test/42.jpg (deflated 13%)
#   adding: content/EAST/test/268.jpg (deflated 5%)
#   adding: content/EAST/test/218.jpg (deflated 4%)
#   adding: content/EAST/test/0.jpg (deflated 6%)
#   adding: content/EAST/test/79.jpg (deflated 9%)
#   adding: content/EAST/test/427. 2018_3$largeimg18_mar_2018_231139550.jpg (deflated 8%)
#   adding: content/EAST/test/7.jpg (deflated 4%)
17. ghaziabad-hindustan-febuary-ghaziabad-tuesday-welcome-febuary_050296d0-29b7-11e6-a271-92fd27615944.jpg (deflated 5%)
#   adding: content/EAST/test/54.jpg (deflated 4%)
#   adding: content/EAST/test/119. img_9800-1.jpg (deflated 3%)
#   adding: content/EAST/test/127.jpg (deflated 5%)
#   adding: content/EAST/test/198.jpg (deflated 5%)
#   adding: content/EAST/test/12.jpg (deflated 9%)
#   adding: content/EAST/test/158.jpg (deflated 6%)
#   adding: content/EAST/test/104. election-commission.jpg (deflated 2%)
#   adding: content/EAST/test/96.jpg (deflated 5%)
#   adding: content/EAST/test/152.jpg (deflated 5%)
#   adding: content/EAST/test/223.jpg (deflated 5%)
#   adding: content/EAST/test/147.jpg (deflated 5%)
#   adding: content/EAST/test/97.jpg (deflated 7%)
#   adding: content/EAST/test/259.jpg (deflated 4%)
#   adding: content/EAST/test/43. palika-bazar.jpg (deflated 3%)
#   adding: content/EAST/test/46. videoblocks-india-tourism-delhi-sign-hindi-and-english-nighttime-new-delhi-india_rx3i43x6g_thumbnail-full01.jpg (deflated 0%)
#   adding: content/EAST/test/22.jpg (deflated 4%)
#   adding: content/EAST/test/40.jpg (deflated 6%)
#   adding: content/EAST/test/83.jpg (deflated 4%)
#   adding: content/EAST/test/11. india_delhi_metro_rail_flickr_linuskendal_750_572_80_s.jpg (deflated 4%)
#   adding: content/EAST/test/233.jpg (deflated 4%)
#   adding: content/EAST/test/67.jpg (deflated 6%)
#   adding: content/EAST/test/26.jpg (deflated 7%)
#   adding: content/EAST/test/280.jpg (deflated 5%)
#   adding: content/EAST/test/17.jpg (deflated 4%)
#   adding: content/EAST/test/215.jpg (deflated 9%)
#   adding: content/EAST/test/193.jpg (deflated 4%)
#   adding: content/EAST/test/114.jpg (deflated 5%)
#   adding: content/EAST/test/123. tropic-of-cancer-sponsored-by-the-government-of-madhya-pradesh.jpg (deflated 0%)
#   adding: content/EAST/test/149. hi369559685.jpg (deflated 1%)
#   adding: content/EAST/test/475. picsart03170990089.jpg (deflated 4%)
#   adding: content/EAST/test/258.jpg (deflated 4%)
#   adding: content/EAST/test/68.jpg (deflated 5%)
#   adding: content/EAST/test/85.jpg (deflated 7%)
#   adding: content/EAST/test/166.jpg (deflated 5%)
#   adding: content/EAST/test/158. keralahouse_beefsaahil11.jpg (deflated 0%)
#   adding: content/EAST/test/137.jpg (deflated 7%)
#   adding: content/EAST/test/116.jpg (deflated 6%)
#   adding: content/EAST/test/124.jpg (deflated 5%)
#   adding: content/EAST/test/229.jpg (deflated 4%)
#   adding: content/EAST/test/143.jpg (deflated 5%)
#   adding: content/EAST/test/208.jpg (deflated 5%)
#   adding: content/EAST/test/109. rajpath.jpg (deflated 3%)
#   adding: content/EAST/test/284.jpg (deflated 4%)
#   adding: content/EAST/test/232.jpg (deflated 6%)
#   adding: content/EAST/test/50.jpg (deflated 5%)
#   adding: content/EAST/test/306.jpg (deflated 10%)
#   adding: content/EAST/test/243.jpg (deflated 8%)
#   adding: content/EAST/test/2.jpg (deflated 6%)
#   adding: content/EAST/test/188.jpg (deflated 4%)
#   adding: content/EAST/test/94.jpg (deflated 6%)
#   adding: content/EAST/test/80.jpg (deflated 5%)
#   adding: content/EAST/test/227.jpg (deflated 5%)
#   adding: content/EAST/test/248.jpg (deflated 5%)
#   adding: content/EAST/test/133.jpg (deflated 4%)
#   adding: content/EAST/test/321.jpg (deflated 6%)
#   adding: content/EAST/nets/ (stored 0%)
#   adding: content/EAST/nets/resnet_v1.py (deflated 74%)
#   adding: content/EAST/nets/resnet_utils.py (deflated 67%)
#   adding: content/EAST/nets/__pycache__/ (stored 0%)
#   adding: content/EAST/nets/__pycache__/resnet_utils.cpython-36.pyc (deflated 55%)
#   adding: content/EAST/nets/__pycache__/__init__.cpython-36.pyc (deflated 24%)
#   adding: content/EAST/nets/__pycache__/resnet_v1.cpython-36.pyc (deflated 60%)
#   adding: content/EAST/nets/__init__.py (stored 0%)
#   adding: content/EAST/east_icdar2015_resnet_v1_50_rboxmodel.ckpt-1.data-00000-of-00001 (deflated 22%)
#   adding: content/EAST/static/ (stored 0%)
#   adding: content/EAST/static/css/ (stored 0%)
#   adding: content/EAST/static/css/app.css (deflated 32%)
#   adding: content/EAST/LICENSE (deflated 65%)
#   adding: content/EAST/lanms/ (stored 0%)
#   adding: content/EAST/lanms/.gitignore (stored 0%)
#   adding: content/EAST/lanms/.ycm_extra_conf.py (deflated 59%)
#   adding: content/EAST/lanms/Makefile (deflated 40%)
#   adding: content/EAST/lanms/__pycache__/ (stored 0%)
#   adding: content/EAST/lanms/__pycache__/__init__.cpython-36.pyc (deflated 26%)
#   adding: content/EAST/lanms/adaptor.so (deflated 72%)
#   adding: content/EAST/lanms/__init__.py (deflated 42%)
#   adding: content/EAST/lanms/__main__.py (deflated 33%)
#   adding: content/EAST/lanms/include/ (stored 0%)
#   adding: content/EAST/lanms/include/clipper/ (stored 0%)
#   adding: content/EAST/lanms/include/clipper/clipper.cpp (deflated 79%)
#   adding: content/EAST/lanms/include/clipper/clipper.hpp (deflated 71%)
#   adding: content/EAST/lanms/include/pybind11/ (stored 0%)
#   adding: content/EAST/lanms/include/pybind11/embed.h (deflated 67%)
#   adding: content/EAST/lanms/include/pybind11/descr.h (deflated 73%)
#   adding: content/EAST/lanms/include/pybind11/options.h (deflated 63%)
#   adding: content/EAST/lanms/include/pybind11/complex.h (deflated 57%)
#   adding: content/EAST/lanms/include/pybind11/pybind11.h (deflated 75%)
#   adding: content/EAST/lanms/include/pybind11/attr.h (deflated 73%)
#   adding: content/EAST/lanms/include/pybind11/typeid.h (deflated 50%)
#   adding: content/EAST/lanms/include/pybind11/numpy.h (deflated 76%)
#   adding: content/EAST/lanms/include/pybind11/eval.h (deflated 67%)
#   adding: content/EAST/lanms/include/pybind11/stl_bind.h (deflated 76%)
#   adding: content/EAST/lanms/include/pybind11/pytypes.h (deflated 77%)
#   adding: content/EAST/lanms/include/pybind11/stl.h (deflated 75%)
#   adding: content/EAST/lanms/include/pybind11/cast.h (deflated 75%)
#   adding: content/EAST/lanms/include/pybind11/functional.h (deflated 57%)
#   adding: content/EAST/lanms/include/pybind11/eigen.h (deflated 72%)
#   adding: content/EAST/lanms/include/pybind11/buffer_info.h (deflated 68%)
#   adding: content/EAST/lanms/include/pybind11/class_support.h (deflated 73%)
#   adding: content/EAST/lanms/include/pybind11/chrono.h (deflated 72%)
#   adding: content/EAST/lanms/include/pybind11/common.h (deflated 72%)
#   adding: content/EAST/lanms/include/pybind11/operators.h (deflated 77%)
#   adding: content/EAST/lanms/adaptor.cpp (deflated 57%)
#   adding: content/EAST/lanms/lanms.h (deflated 69%)
#   adding: content/EAST/multigpu_train.py (deflated 72%)
#   adding: content/EAST/run_demo_server.py (deflated 65%)
#   adding: content/EAST/deploy.sh (deflated 30%)
#   adding: content/EAST/.gitignore (deflated 45%)
#   adding: content/EAST/checkpoint (deflated 46%)
#   adding: content/EAST/__pycache__/ (stored 0%)
#   adding: content/EAST/__pycache__/locality_aware_nms.cpython-36.pyc (deflated 40%)
#   adding: content/EAST/__pycache__/icdar.cpython-36.pyc (deflated 57%)
#   adding: content/EAST/__pycache__/model.cpython-36.pyc (deflated 43%)
#   adding: content/EAST/__pycache__/data_util.cpython-36.pyc (deflated 47%)
#   adding: content/EAST/.ipynb_checkpoints/ (stored 0%)
#   adding: content/EAST/demo_images/ (stored 0%)
#   adding: content/EAST/demo_images/img_26.jpg (deflated 4%)
#   adding: content/EAST/demo_images/img_2.jpg (deflated 4%)
#   adding: content/EAST/demo_images/img_10.jpg (deflated 5%)
#   adding: content/EAST/demo_images/web-demo.png (deflated 0%)
#   adding: content/EAST/demo_images/img_14.jpg (deflated 6%)
#   adding: content/EAST/demo_images/img_75.jpg (deflated 4%)
#   adding: content/EAST/readme.md (deflated 51%)
#   adding: content/EAST/.git/ (stored 0%)
#   adding: content/EAST/.git/packed-refs (deflated 38%)
#   adding: content/EAST/.git/branches/ (stored 0%)
#   adding: content/EAST/.git/objects/ (stored 0%)
#   adding: content/EAST/.git/objects/info/ (stored 0%)
#   adding: content/EAST/.git/objects/pack/ (stored 0%)
#   adding: content/EAST/.git/objects/pack/pack-087e6550307e4023501ba4bd423e04aa963f1517.pack (deflated 0%)
#   adding: content/EAST/.git/objects/pack/pack-087e6550307e4023501ba4bd423e04aa963f1517.idx (deflated 9%)
#   adding: content/EAST/.git/description (deflated 14%)
#   adding: content/EAST/.git/refs/ (stored 0%)
#   adding: content/EAST/.git/refs/tags/ (stored 0%)
#   adding: content/EAST/.git/refs/heads/ (stored 0%)
#   adding: content/EAST/.git/refs/heads/master (deflated 2%)
#   adding: content/EAST/.git/refs/remotes/ (stored 0%)
#   adding: content/EAST/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/EAST/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/EAST/.git/hooks/ (stored 0%)
#   adding: content/EAST/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/EAST/.git/hooks/update.sample (deflated 68%)
#   adding: content/EAST/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/EAST/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: content/EAST/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/EAST/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/EAST/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: content/EAST/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/EAST/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/EAST/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/EAST/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/EAST/.git/index (deflated 51%)
#   adding: content/EAST/.git/info/ (stored 0%)
#   adding: content/EAST/.git/info/exclude (deflated 28%)
#   adding: content/EAST/.git/config (deflated 31%)
#   adding: content/EAST/.git/HEAD (stored 0%)
#   adding: content/EAST/.git/logs/ (stored 0%)
#   adding: content/EAST/.git/logs/refs/ (stored 0%)
#   adding: content/EAST/.git/logs/refs/heads/ (stored 0%)
#   adding: content/EAST/.git/logs/refs/heads/master (deflated 27%)
#   adding: content/EAST/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/EAST/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/EAST/.git/logs/refs/remotes/origin/HEAD (deflated 27%)
#   adding: content/EAST/.git/logs/HEAD (deflated 27%)
#   adding: content/EAST/data_util.py (deflated 70%)
#   adding: content/EAST/requirements.txt (deflated 18%)
#   adding: content/EAST/east_icdar2015_resnet_v1_50_rboxmodel.ckpt-1.meta (deflated 94%)
#   adding: content/EAST/model.py (deflated 67%)
#   adding: content/EAST/icdar.py (deflated 78%)
#   adding: content/EAST/eval.py (deflated 66%)
#   adding: content/EAST/training_samples/ (stored 0%)
#   adding: content/EAST/training_samples/131. citi-maas6-1024x768.txt (deflated 50%)
#   adding: content/EAST/training_samples/24.jpg (deflated 4%)
#   adding: content/EAST/training_samples/50.txt (deflated 42%)
#   adding: content/EAST/training_samples/152.txt (deflated 36%)
#   adding: content/EAST/training_samples/310.jpg (deflated 5%)
#   adding: content/EAST/training_samples/260.txt (deflated 51%)
#   adding: content/EAST/training_samples/13116615_1804919146396837_824128706_n.txt (deflated 53%)
#   adding: content/EAST/training_samples/51.jpg (deflated 6%)
#   adding: content/EAST/training_samples/260.jpg (deflated 6%)
#   adding: content/EAST/training_samples/32.jpg (deflated 5%)
#   adding: content/EAST/training_samples/232.txt (deflated 44%)
#   adding: content/EAST/training_samples/113.jpg (deflated 5%)
#   adding: content/EAST/training_samples/11. national-museum.txt (deflated 59%)
#   adding: content/EAST/training_samples/16. _13527880332.jpg (deflated 3%)
#   adding: content/EAST/training_samples/panchavati-gaurav-to-add-50-outl-807e888a81.txt (deflated 46%)
#   adding: content/EAST/training_samples/181.txt (deflated 50%)
#   adding: content/EAST/training_samples/37.txt (deflated 48%)
#   adding: content/EAST/training_samples/11. nyoooz_hindi1902_1507879752.txt (deflated 51%)
#   adding: content/EAST/training_samples/70.txt (deflated 55%)
#   adding: content/EAST/training_samples/139. ugc759.txt (deflated 51%)
#   adding: content/EAST/training_samples/317.txt (deflated 55%)
#   adding: content/EAST/training_samples/10.txt (deflated 42%)
#   adding: content/EAST/training_samples/46. videoblocks-india-tourism-delhi-sign-hindi-and-english-nighttime-new-delhi-india_rx3i43x6g_thumbnail-full01.txt (deflated 57%)
#   adding: content/EAST/training_samples/205.txt (deflated 55%)
#   adding: content/EAST/training_samples/245.txt (deflated 45%)
#   adding: content/EAST/training_samples/161. nlu-450x338.txt (deflated 52%)
#   adding: content/EAST/training_samples/239.txt (deflated 50%)
#   adding: content/EAST/training_samples/250.jpg (deflated 5%)
#   adding: content/EAST/training_samples/64.jpg (deflated 5%)
#   adding: content/EAST/training_samples/16. news_id_3162.txt (deflated 51%)
#   adding: content/EAST/training_samples/42.jpg (deflated 13%)
#   adding: content/EAST/training_samples/116.txt (deflated 51%)
#   adding: content/EAST/training_samples/Pandit-Kulfi-1.txt (deflated 37%)
#   adding: content/EAST/training_samples/268.jpg (deflated 5%)
#   adding: content/EAST/training_samples/218.jpg (deflated 4%)
#   adding: content/EAST/training_samples/311.txt (deflated 35%)
#   adding: content/EAST/training_samples/0.jpg (deflated 6%)
#   adding: content/EAST/training_samples/9. videoblocks-janpath-market-street-sign-hindi-and-english-new-delhi-india_sxqpwcxtx_thumbnail-full01.txt (deflated 41%)
#   adding: content/EAST/training_samples/79.jpg (deflated 9%)
#   adding: content/EAST/training_samples/240. temple-entrance-door-sign-english-and-hindi-languages-india_btx6gupxel_thumbnail-full01.txt (deflated 45%)
#   adding: content/EAST/training_samples/427. 2018_3$largeimg18_mar_2018_231139550.jpg (deflated 8%)
#   adding: content/EAST/training_samples/209.txt (deflated 29%)
#   adding: content/EAST/training_samples/7.jpg (deflated 4%)
#   adding: content/EAST/training_samples/297.jpg (deflated 4%)
#   adding: content/EAST/training_samples/277.jpg (deflated 5%)
#   adding: content/EAST/training_samples/321.txt (deflated 37%)
#   adding: content/EAST/training_samples/4.jpg (deflated 6%)
#   adding: content/EAST/training_samples/213.jpg (deflated 5%)
#   adding: content/EAST/training_samples/164. 52b9304db02d31499e48e18b58608e20--henry-miller-madhya-pradesh
#   adding: content/EAST/training_samples/166.jpg (deflated 5%)
#   adding: content/EAST/training_samples/158. ugc-1-759.txt (deflated 52%)
#   adding: content/EAST/training_samples/158. keralahouse_beefsaahil11.jpg (deflated 0%)
#   adding: content/EAST/training_samples/55.txt (deflated 35%)
#   adding: content/EAST/training_samples/133. 06102011266.txt (stored 0%)
#   adding: content/EAST/training_samples/137.jpg (deflated 7%)
#   adding: content/EAST/training_samples/248.txt (deflated 37%)
#   adding: content/EAST/training_samples/116.jpg (deflated 6%)
#   adding: content/EAST/training_samples/494. national-zoo-sign1_1413278727_540x540.txt (deflated 50%)
#   adding: content/EAST/training_samples/194.txt (deflated 52%)
#   adding: content/EAST/training_samples/124.jpg (deflated 5%)
#   adding: content/EAST/training_samples/229.jpg (deflated 4%)
#   adding: content/EAST/training_samples/143.jpg (deflated 5%)
#   adding: content/EAST/training_samples/92.txt (deflated 59%)
#   adding: content/EAST/training_samples/148.txt (deflated 46%)
#   adding: content/EAST/training_samples/208.jpg (deflated 5%)
#   adding: content/EAST/training_samples/109. rajpath.jpg (deflated 3%)
#   adding: content/EAST/training_samples/62. jantar-mantar-delhi-206694.txt (deflated 42%)
#   adding: content/EAST/training_samples/284.jpg (deflated 4%)
#   adding: content/EAST/training_samples/58.txt (deflated 43%)
#   adding: content/EAST/training_samples/244.txt (deflated 22%)
#   adding: content/EAST/training_samples/232.jpg (deflated 6%)
#   adding: content/EAST/training_samples/50.jpg (deflated 5%)
#   adding: content/EAST/training_samples/306.jpg (deflated 10%)
#   adding: content/EAST/training_samples/243.jpg (deflated 8%)
#   adding: content/EAST/training_samples/2.jpg (deflated 6%)
#   adding: content/EAST/training_samples/257.txt (deflated 16%)
#   adding: content/EAST/training_samples/188.jpg (deflated 4%)
#   adding: content/EAST/training_samples/54.txt (deflated 52%)
#   adding: content/EAST/training_samples/94.jpg (deflated 6%)
#   adding: content/EAST/training_samples/80.jpg (deflated 5%)
#   adding: content/EAST/training_samples/44.txt (deflated 45%)
#   adding: content/EAST/training_samples/164. 12243201_10153720744566585_194230972898132752_n.txt (deflated 47%)
#   adding: content/EAST/training_samples/227.jpg (deflated 5%)
#   adding: content/EAST/training_samples/264.txt (deflated 50%)
#   adding: content/EAST/training_samples/248.jpg (deflated 5%)
#   adding: content/EAST/training_samples/133.jpg (deflated 4%)
#   adding: content/EAST/training_samples/235.txt (deflated 55%)
#   adding: content/EAST/training_samples/24. sharda-ukil-school-of-art-janpath-delhi-fashion-designing-institutes-0k9l9.txt (deflated 55%)
#   adding: content/EAST/training_samples/56.txt (deflated 34%)
#   adding: content/EAST/training_samples/321.jpg (deflated 6%)
#   adding: content/EAST/weights.zip (stored 0%)
#   adding: content/EAST/templates/ (stored 0%)
#   adding: content/EAST/templates/index.html (deflated 67%)
#   adding: content/EAST/locality_aware_nms.py (deflated 58%)
#   adding: content/EAST/__init__.py (stored 0%)
#   adding: content/EAST/east_icdar2015_resnet_v1_50_rbox/ (stored 0%)
#   adding: content/EAST/east_icdar2015_resnet_v1_50_rbox/events.out.tfevents.1584871719.5e2f34910a3a (deflated 88%)
#   adding: content/EAST/real_Image_dataset_Detection/ (stored 0%)
#   adding: content/EAST/real_Image_dataset_Detection/Annotation/ (stored 0%)
#   adding: content/EAST/real_Image_dataset_Detection/Image/ (stored 0%)
#   adding: content/EAST/real_Image_dataset_Detection/readme.txt (deflated 53%)
#   adding: content/EAST/east_icdar2015_resnet_v1_50_rboxmodel.ckpt-1.index (deflated 72%)
#   adding: content/east_icdar2015_resnet_v1_50_rbox/ (stored 0%)
#   adding: content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491.data-00000-of-00001 (deflated 6%)
#   adding: content/east_icdar2015_resnet_v1_50_rbox/checkpoint (deflated 78%)
#   adding: content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491.meta (deflated 94%)
#   adding: content/east_icdar2015_resnet_v1_50_rbox/model.ckpt-49491.index (deflated 72%)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-81b37dede699> in <module>()
#       2 get_ipython().system('zip -r /content/east_icdar2015_resnet_v1_50_rbox.zip /content/east_icdar2015_resnet_v1_50_rbox')
#       3
# ----> 4 files.download('/content/east_icdar2015_resnet_v1_50_rbox.zip')
#       5 files.download('/content/EAST.zip')
#
# AttributeError: 'str' object has no attribute 'download'

# %%
zip -r /tmp.zip /tmp/

# %%
cd ..
# Out:
# /content

# %%
from google.colab import files
files.download("east_icdar2015_resnet_v1_50_rbox.zip")

# %%
file_metadata = {'name': 'EAST.zip'}
media = MediaFileUpload("EAST.zip", resumable=True)
created = drive_service.files().create(body=file_metadata,
media_body=media,
fields='id').execute()
print('File ID: {}'.format(created.get('id')))
# Out:
# File ID: 1hrK8GU6xwv3xh2CcGfV1Wj8MUh1cW5aY

# %%
# !zip -r /content/tmp.zip /tmp
# Out:
#   adding: tmp/ (stored 0%)
#   adding: tmp/24.jpg (deflated 3%)
#   adding: tmp/50.txt (deflated 76%)
#   adding: tmp/152.txt (deflated 73%)
#   adding: tmp/310.jpg (deflated 4%)
#   adding: tmp/260.txt (deflated 79%)
#   adding: tmp/13116615_1804919146396837_824128706_n.txt (deflated 70%)
#   adding: tmp/51.jpg (deflated 4%)
#   adding: tmp/260.jpg (deflated 4%)
#   adding: tmp/32.jpg (deflated 4%)
#   adding: tmp/232.txt (deflated 72%)
#   adding: tmp/113.jpg (deflated 4%)
#   adding: tmp/16. _13527880332.jpg (deflated 2%)
#   adding: tmp/panchavati-gaurav-to-add-50-outl-807e888a81.txt (deflated 72%)
#   adding: tmp/181.txt (deflated 78%)
#   adding: tmp/37.txt (deflated 77%)
#   adding: tmp/70.txt (deflated 70%)
#   adding: tmp/317.txt (deflated 78%)
#   adding: tmp/10.txt (deflated 78%)
#   adding: tmp/205.txt (deflated 79%)
#   adding: tmp/245.txt (deflated 71%)
#   adding: tmp/239.txt (deflated 75%)
#   adding: tmp/250.jpg (deflated 3%)
#   adding: tmp/64.jpg (deflated 3%)
#   adding: tmp/42.jpg (deflated 11%)
#   adding: tmp/116.txt (deflated 71%)
#   adding: tmp/Pandit-Kulfi-1.txt (deflated 76%)
#   adding: tmp/268.jpg (deflated 3%)
#   adding: tmp/218.jpg (deflated 3%)
#   adding: tmp/311.txt (deflated 76%)
